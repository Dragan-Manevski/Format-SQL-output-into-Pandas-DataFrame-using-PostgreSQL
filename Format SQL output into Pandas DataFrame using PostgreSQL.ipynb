# %% [markdown]
# ### 1. Import the Library

# %%
# Import Pandas library, psycopg2 to connect Python script to the PostgreSQL database, module’s OperationalError class
import pandas as pd
import psycopg2 as pg2
from psycopg2 import OperationalError

# %% [markdown]
# ### 2. Create connection to Database

# %%
# Function that connects to PostgreSQL database and returns connection object
def create_db_connection(host_name, user_name, db_pass, db_name, db_port):
    connection = None
    try:
        connection = pg2.connect(
            host = host_name,
            user = user_name,
            password = db_pass,
            database = db_name,
            port = db_port
        )
        print("PostgreSQL Database connection successful")
    except OperationalError as err:
        print(f"The error '{err}' occurred")
    
    return connection

# %%
# Root password for PostgreSQL Server
db_pass = "Dragan16**"

# Name of the created database
db_name = "dvdrental"

# Port number of the database server
db_port = 5432

# Create connection to PostgreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)
# Out:
# PostgreSQL Database connection successful

# %% [markdown]
# ### 3. Execute SQL Query

# %%
# Function that execute SQL query on PostgreSQL database server
def execute_query(connection, query):
    connection.autocommit = True
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        print("Query executed successfully")
    except OperationalError as err:
        print(f"The error '{err}' occurred")

# %% [markdown]
# ### 4. Read Query

# %%
# Function that selects (reads) records
def read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except OperationalError as err:
        print(f"The error '{err}' occurred")

# %% [markdown]
# ### 5. Show all Tables in Database

# %%
# Show all tables in PosgtreSQL database
show_tables = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema NOT IN ('pg_catalog', 'information_schema')
AND table_type = 'BASE TABLE';
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, show_tables)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# ('actor',)
# ('store',)
# ('address',)
# ('category',)
# ('city',)
# ('country',)
# ('customer',)
# ('film_actor',)
# ('film_category',)
# ('inventory',)
# ('language',)
# ('rental',)
# ('staff',)
# ('payment',)
# ('film',)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["table name"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head(20)
# Out:
#        table name
# 0           actor
# 1           store
# 2         address
# 3        category
# 4            city
# 5         country
# 6        customer
# 7      film_actor
# 8   film_category
# 9       inventory
# 10       language
# 11         rental
# 12          staff
# 13        payment
# 14           film

# %% [markdown]
# #### OR

# %%
# Show all tables in PosgtreSQL database (using pg_catalog schema (from pg_catalog.pg_tables catalog))
show_tables = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema';
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, show_tables)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# ('public', 'actor', 'postgres', None, True, False, True, False)
# ('public', 'store', 'postgres', None, True, False, True, False)
# ('public', 'address', 'postgres', None, True, False, True, False)
# ('public', 'category', 'postgres', None, True, False, True, False)
# ('public', 'city', 'postgres', None, True, False, True, False)
# ('public', 'country', 'postgres', None, True, False, True, False)
# ('public', 'customer', 'postgres', None, True, False, True, False)
# ('public', 'film_actor', 'postgres', None, True, False, True, False)
# ('public', 'film_category', 'postgres', None, True, False, True, False)
# ('public', 'inventory', 'postgres', None, True, False, True, False)
# ('public', 'language', 'postgres', None, True, False, True, False)
# ('public', 'rental', 'postgres', None, True, False, True, False)
# ('public', 'staff', 'postgres', None, True, False, True, False)
# ('public', 'payment', 'postgres', None, True, False, True, False)
# ('public', 'film', 'postgres', None, True, False, True, False)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["schema name", "table name", "table owner", "table space", "has indexes", "has rules", "has triggers", "row security"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head(20)
# Out:
#    schema name     table name table owner table space  has indexes  has rules  \
# 0       public          actor    postgres        None         True      False
# 1       public          store    postgres        None         True      False
# 2       public        address    postgres        None         True      False
# 3       public       category    postgres        None         True      False
# 4       public           city    postgres        None         True      False
# 5       public        country    postgres        None         True      False
# 6       public       customer    postgres        None         True      False
# 7       public     film_actor    postgres        None         True      False
# 8       public  film_category    postgres        None         True      False
# 9       public      inventory    postgres        None         True      False
# 10      public       language    postgres        None         True      False
# 11      public         rental    postgres        None         True      False
# 12      public          staff    postgres        None         True      False
# 13      public        payment    postgres        None         True      False
# 14      public           film    postgres        None         True      False
#
#     has triggers  row security
# 0           True         False
# 1           True         False
# 2           True         False
# 3           True         False
# 4           True         False
# 5           True         False
# 6           True         False
# 7           True         False
# 8           True         False
# 9           True         False
# 10          True         False
# 11          True         False
# 12          True         False
# 13          True         False
# 14          True         False

# %% [markdown]
# ### 6. Show Columns in Table

# %%
# Show all columns in PosgtreSQL table
show_columns = """
SELECT table_name, column_name, data_type 
FROM information_schema.columns
WHERE table_name = 'customer';
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, show_columns)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# ('customer', 'active', 'integer')
# ('customer', 'store_id', 'smallint')
# ('customer', 'create_date', 'date')
# ('customer', 'last_update', 'timestamp without time zone')
# ('customer', 'customer_id', 'integer')
# ('customer', 'address_id', 'smallint')
# ('customer', 'activebool', 'boolean')
# ('customer', 'first_name', 'character varying')
# ('customer', 'last_name', 'character varying')
# ('customer', 'email', 'character varying')

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["table name", "column name", "data type"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head(15)
# Out:
#   table name  column name                    data type
# 0   customer       active                      integer
# 1   customer     store_id                     smallint
# 2   customer  create_date                         date
# 3   customer  last_update  timestamp without time zone
# 4   customer  customer_id                      integer
# 5   customer   address_id                     smallint
# 6   customer   activebool                      boolean
# 7   customer   first_name            character varying
# 8   customer    last_name            character varying
# 9   customer        email            character varying

# %% [markdown]
# ### 7. Select (Read) Records

# %%
# Select (Read) records from PosgtreSQL table
# Show all records from table 'customer'
select_records = """
SELECT *
FROM customer
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (2, 1, 'Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org', 6, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (3, 1, 'Linda', 'Williams', 'linda.williams@sakilacustomer.org', 7, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (4, 2, 'Barbara', 'Jones', 'barbara.jones@sakilacustomer.org', 8, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (5, 1, 'Elizabeth', 'Brown', 'elizabeth.brown@sakilacustomer.org', 9, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (6, 2, 'Jennifer', 'Davis', 'jennifer.davis@sakilacustomer.org', 10, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (7, 1, 'Maria', 'Miller', 'maria.miller@sakilacustomer.org', 11, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (8, 2, 'Susan', 'Wilson', 'susan.wilson@sakilacustomer.org', 12, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (9, 2, 'Margaret', 'Moore', 'margaret.moore@sakilacustomer.org', 13, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (10, 1, 'Dorothy', 'Taylor', 'dorothy.taylor@sakilacustomer.org', 14, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (11, 2, 'Lisa', 'Anderson', 'lisa.anderson@sakilacustomer.org', 15, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (12, 1, 'Nancy', 'Thomas', 'nancy.thomas@sakilacustomer.org', 16, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (13, 2, 'Karen', 'Jackson', 'karen.jackson@sakilacustomer.org', 17, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (14, 2, 'Betty', 'White', 'betty.white@sakilacustomer.org', 18, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (15, 1, 'Helen', 'Harris', 'helen.harris@sakilacustomer.org', 19, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (16, 2, 'Sandra', 'Martin', 'sandra.martin@sakilacustomer.org', 20, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (17, 1, 'Donna', 'Thompson', 'donna.thompson@sakilacustomer.org', 21, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (18, 2, 'Carol', 'Garcia', 'carol.garcia@sakilacustomer.org', 22, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (19, 1, 'Ruth', 'Martinez', 'ruth.martinez@sakilacustomer.org', 23, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (20, 2, 'Sharon', 'Robinson', 'sharon.robinson@sakilacustomer.org', 24, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (21, 1, 'Michelle', 'Clark', 'michelle.clark@sakilacustomer.org', 25, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (22, 1, 'Laura', 'Rodriguez', 'laura.rodriguez@sakilacustomer.org', 26, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (23, 2, 'Sarah', 'Lewis', 'sarah.lewis@sakilacustomer.org', 27, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (24, 2, 'Kimberly', 'Lee', 'kimberly.lee@sakilacustomer.org', 28, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (25, 1, 'Deborah', 'Walker', 'deborah.walker@sakilacustomer.org', 29, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (26, 2, 'Jessica', 'Hall', 'jessica.hall@sakilacustomer.org', 30, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (27, 2, 'Shirley', 'Allen', 'shirley.allen@sakilacustomer.org', 31, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (28, 1, 'Cynthia', 'Young', 'cynthia.young@sakilacustomer.org', 32, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (29, 2, 'Angela', 'Hernandez', 'angela.hernandez@sakilacustomer.org', 33, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (30, 1, 'Melissa', 'King', 'melissa.king@sakilacustomer.org', 34, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (31, 2, 'Brenda', 'Wright', 'brenda.wright@sakilacustomer.org', 35, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (32, 1, 'Amy', 'Lopez', 'amy.lopez@sakilacustomer.org', 36, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (33, 2, 'Anna', 'Hill', 'anna.hill@sakilacustomer.org', 37, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (34, 2, 'Rebecca', 'Scott', 'rebecca.scott@sakilacustomer.org', 38, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (35, 2, 'Virginia', 'Green', 'virginia.green@sakilacustomer.org', 39, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (36, 2, 'Kathleen', 'Adams', 'kathleen.adams@sakilacustomer.org', 40, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (37, 1, 'Pamela', 'Baker', 'pamela.baker@sakilacustomer.org', 41, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (38, 1, 'Martha', 'Gonzalez', 'martha.gonzalez@sakilacustomer.org', 42, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (39, 1, 'Debra', 'Nelson', 'debra.nelson@sakilacustomer.org', 43, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (40, 2, 'Amanda', 'Carter', 'amanda.carter@sakilacustomer.org', 44, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (41, 1, 'Stephanie', 'Mitchell', 'stephanie.mitchell@sakilacustomer.org', 45, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (42, 2, 'Carolyn', 'Perez', 'carolyn.perez@sakilacustomer.org', 46, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (43, 2, 'Christine', 'Roberts', 'christine.roberts@sakilacustomer.org', 47, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (44, 1, 'Marie', 'Turner', 'marie.turner@sakilacustomer.org', 48, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (45, 1, 'Janet', 'Phillips', 'janet.phillips@sakilacustomer.org', 49, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (46, 2, 'Catherine', 'Campbell', 'catherine.campbell@sakilacustomer.org', 50, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (47, 1, 'Frances', 'Parker', 'frances.parker@sakilacustomer.org', 51, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (48, 1, 'Ann', 'Evans', 'ann.evans@sakilacustomer.org', 52, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (49, 2, 'Joyce', 'Edwards', 'joyce.edwards@sakilacustomer.org', 53, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (50, 1, 'Diane', 'Collins', 'diane.collins@sakilacustomer.org', 54, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (51, 1, 'Alice', 'Stewart', 'alice.stewart@sakilacustomer.org', 55, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (52, 1, 'Julie', 'Sanchez', 'julie.sanchez@sakilacustomer.org', 56, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (53, 1, 'Heather', 'Morris', 'heather.morris@sakilacustomer.org', 57, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (54, 1, 'Teresa', 'Rogers', 'teresa.rogers@sakilacustomer.org', 58, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (55, 2, 'Doris', 'Reed', 'doris.reed@sakilacustomer.org', 59, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (56, 1, 'Gloria', 'Cook', 'gloria.cook@sakilacustomer.org', 60, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (57, 2, 'Evelyn', 'Morgan', 'evelyn.morgan@sakilacustomer.org', 61, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (58, 1, 'Jean', 'Bell', 'jean.bell@sakilacustomer.org', 62, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (59, 1, 'Cheryl', 'Murphy', 'cheryl.murphy@sakilacustomer.org', 63, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (60, 1, 'Mildred', 'Bailey', 'mildred.bailey@sakilacustomer.org', 64, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (61, 2, 'Katherine', 'Rivera', 'katherine.rivera@sakilacustomer.org', 65, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (62, 1, 'Joan', 'Cooper', 'joan.cooper@sakilacustomer.org', 66, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (63, 1, 'Ashley', 'Richardson', 'ashley.richardson@sakilacustomer.org', 67, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (64, 2, 'Judith', 'Cox', 'judith.cox@sakilacustomer.org', 68, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (65, 2, 'Rose', 'Howard', 'rose.howard@sakilacustomer.org', 69, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (66, 2, 'Janice', 'Ward', 'janice.ward@sakilacustomer.org', 70, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (67, 1, 'Kelly', 'Torres', 'kelly.torres@sakilacustomer.org', 71, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (68, 1, 'Nicole', 'Peterson', 'nicole.peterson@sakilacustomer.org', 72, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (69, 2, 'Judy', 'Gray', 'judy.gray@sakilacustomer.org', 73, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (70, 2, 'Christina', 'Ramirez', 'christina.ramirez@sakilacustomer.org', 74, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (71, 1, 'Kathy', 'James', 'kathy.james@sakilacustomer.org', 75, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (72, 2, 'Theresa', 'Watson', 'theresa.watson@sakilacustomer.org', 76, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (73, 2, 'Beverly', 'Brooks', 'beverly.brooks@sakilacustomer.org', 77, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (74, 1, 'Denise', 'Kelly', 'denise.kelly@sakilacustomer.org', 78, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (75, 2, 'Tammy', 'Sanders', 'tammy.sanders@sakilacustomer.org', 79, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (76, 2, 'Irene', 'Price', 'irene.price@sakilacustomer.org', 80, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (77, 2, 'Jane', 'Bennett', 'jane.bennett@sakilacustomer.org', 81, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (78, 1, 'Lori', 'Wood', 'lori.wood@sakilacustomer.org', 82, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (79, 1, 'Rachel', 'Barnes', 'rachel.barnes@sakilacustomer.org', 83, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (80, 1, 'Marilyn', 'Ross', 'marilyn.ross@sakilacustomer.org', 84, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (81, 1, 'Andrea', 'Henderson', 'andrea.henderson@sakilacustomer.org', 85, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (82, 1, 'Kathryn', 'Coleman', 'kathryn.coleman@sakilacustomer.org', 86, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (83, 1, 'Louise', 'Jenkins', 'louise.jenkins@sakilacustomer.org', 87, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (84, 2, 'Sara', 'Perry', 'sara.perry@sakilacustomer.org', 88, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (85, 2, 'Anne', 'Powell', 'anne.powell@sakilacustomer.org', 89, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (86, 2, 'Jacqueline', 'Long', 'jacqueline.long@sakilacustomer.org', 90, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (87, 1, 'Wanda', 'Patterson', 'wanda.patterson@sakilacustomer.org', 91, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (88, 2, 'Bonnie', 'Hughes', 'bonnie.hughes@sakilacustomer.org', 92, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (89, 1, 'Julia', 'Flores', 'julia.flores@sakilacustomer.org', 93, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (90, 2, 'Ruby', 'Washington', 'ruby.washington@sakilacustomer.org', 94, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (91, 2, 'Lois', 'Butler', 'lois.butler@sakilacustomer.org', 95, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (92, 2, 'Tina', 'Simmons', 'tina.simmons@sakilacustomer.org', 96, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (93, 1, 'Phyllis', 'Foster', 'phyllis.foster@sakilacustomer.org', 97, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (94, 1, 'Norma', 'Gonzales', 'norma.gonzales@sakilacustomer.org', 98, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (95, 2, 'Paula', 'Bryant', 'paula.bryant@sakilacustomer.org', 99, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (96, 1, 'Diana', 'Alexander', 'diana.alexander@sakilacustomer.org', 100, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (97, 2, 'Annie', 'Russell', 'annie.russell@sakilacustomer.org', 101, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (98, 1, 'Lillian', 'Griffin', 'lillian.griffin@sakilacustomer.org', 102, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (99, 2, 'Emily', 'Diaz', 'emily.diaz@sakilacustomer.org', 103, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (100, 1, 'Robin', 'Hayes', 'robin.hayes@sakilacustomer.org', 104, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (101, 1, 'Peggy', 'Myers', 'peggy.myers@sakilacustomer.org', 105, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (102, 1, 'Crystal', 'Ford', 'crystal.ford@sakilacustomer.org', 106, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (103, 1, 'Gladys', 'Hamilton', 'gladys.hamilton@sakilacustomer.org', 107, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (104, 1, 'Rita', 'Graham', 'rita.graham@sakilacustomer.org', 108, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (105, 1, 'Dawn', 'Sullivan', 'dawn.sullivan@sakilacustomer.org', 109, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (106, 1, 'Connie', 'Wallace', 'connie.wallace@sakilacustomer.org', 110, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (107, 1, 'Florence', 'Woods', 'florence.woods@sakilacustomer.org', 111, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (108, 1, 'Tracy', 'Cole', 'tracy.cole@sakilacustomer.org', 112, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (109, 2, 'Edna', 'West', 'edna.west@sakilacustomer.org', 113, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (110, 2, 'Tiffany', 'Jordan', 'tiffany.jordan@sakilacustomer.org', 114, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (111, 1, 'Carmen', 'Owens', 'carmen.owens@sakilacustomer.org', 115, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (112, 2, 'Rosa', 'Reynolds', 'rosa.reynolds@sakilacustomer.org', 116, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (113, 2, 'Cindy', 'Fisher', 'cindy.fisher@sakilacustomer.org', 117, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (114, 2, 'Grace', 'Ellis', 'grace.ellis@sakilacustomer.org', 118, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (115, 1, 'Wendy', 'Harrison', 'wendy.harrison@sakilacustomer.org', 119, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (116, 1, 'Victoria', 'Gibson', 'victoria.gibson@sakilacustomer.org', 120, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (117, 1, 'Edith', 'Mcdonald', 'edith.mcdonald@sakilacustomer.org', 121, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (118, 1, 'Kim', 'Cruz', 'kim.cruz@sakilacustomer.org', 122, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (119, 1, 'Sherry', 'Marshall', 'sherry.marshall@sakilacustomer.org', 123, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (120, 2, 'Sylvia', 'Ortiz', 'sylvia.ortiz@sakilacustomer.org', 124, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (121, 1, 'Josephine', 'Gomez', 'josephine.gomez@sakilacustomer.org', 125, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (122, 1, 'Thelma', 'Murray', 'thelma.murray@sakilacustomer.org', 126, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (123, 2, 'Shannon', 'Freeman', 'shannon.freeman@sakilacustomer.org', 127, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (124, 1, 'Sheila', 'Wells', 'sheila.wells@sakilacustomer.org', 128, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (125, 1, 'Ethel', 'Webb', 'ethel.webb@sakilacustomer.org', 129, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (126, 1, 'Ellen', 'Simpson', 'ellen.simpson@sakilacustomer.org', 130, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (127, 2, 'Elaine', 'Stevens', 'elaine.stevens@sakilacustomer.org', 131, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (128, 1, 'Marjorie', 'Tucker', 'marjorie.tucker@sakilacustomer.org', 132, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (129, 1, 'Carrie', 'Porter', 'carrie.porter@sakilacustomer.org', 133, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (130, 1, 'Charlotte', 'Hunter', 'charlotte.hunter@sakilacustomer.org', 134, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (131, 2, 'Monica', 'Hicks', 'monica.hicks@sakilacustomer.org', 135, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (132, 2, 'Esther', 'Crawford', 'esther.crawford@sakilacustomer.org', 136, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (133, 1, 'Pauline', 'Henry', 'pauline.henry@sakilacustomer.org', 137, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (134, 1, 'Emma', 'Boyd', 'emma.boyd@sakilacustomer.org', 138, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (135, 2, 'Juanita', 'Mason', 'juanita.mason@sakilacustomer.org', 139, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (136, 2, 'Anita', 'Morales', 'anita.morales@sakilacustomer.org', 140, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (137, 2, 'Rhonda', 'Kennedy', 'rhonda.kennedy@sakilacustomer.org', 141, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (138, 1, 'Hazel', 'Warren', 'hazel.warren@sakilacustomer.org', 142, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (139, 1, 'Amber', 'Dixon', 'amber.dixon@sakilacustomer.org', 143, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (140, 1, 'Eva', 'Ramos', 'eva.ramos@sakilacustomer.org', 144, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (141, 1, 'Debbie', 'Reyes', 'debbie.reyes@sakilacustomer.org', 145, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (142, 1, 'April', 'Burns', 'april.burns@sakilacustomer.org', 146, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (143, 1, 'Leslie', 'Gordon', 'leslie.gordon@sakilacustomer.org', 147, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (144, 1, 'Clara', 'Shaw', 'clara.shaw@sakilacustomer.org', 148, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (145, 1, 'Lucille', 'Holmes', 'lucille.holmes@sakilacustomer.org', 149, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (146, 1, 'Jamie', 'Rice', 'jamie.rice@sakilacustomer.org', 150, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (147, 2, 'Joanne', 'Robertson', 'joanne.robertson@sakilacustomer.org', 151, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (148, 1, 'Eleanor', 'Hunt', 'eleanor.hunt@sakilacustomer.org', 152, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (149, 1, 'Valerie', 'Black', 'valerie.black@sakilacustomer.org', 153, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (150, 2, 'Danielle', 'Daniels', 'danielle.daniels@sakilacustomer.org', 154, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (151, 2, 'Megan', 'Palmer', 'megan.palmer@sakilacustomer.org', 155, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (152, 1, 'Alicia', 'Mills', 'alicia.mills@sakilacustomer.org', 156, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (153, 2, 'Suzanne', 'Nichols', 'suzanne.nichols@sakilacustomer.org', 157, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (154, 2, 'Michele', 'Grant', 'michele.grant@sakilacustomer.org', 158, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (155, 1, 'Gail', 'Knight', 'gail.knight@sakilacustomer.org', 159, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (156, 1, 'Bertha', 'Ferguson', 'bertha.ferguson@sakilacustomer.org', 160, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (157, 2, 'Darlene', 'Rose', 'darlene.rose@sakilacustomer.org', 161, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (158, 1, 'Veronica', 'Stone', 'veronica.stone@sakilacustomer.org', 162, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (159, 1, 'Jill', 'Hawkins', 'jill.hawkins@sakilacustomer.org', 163, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (160, 2, 'Erin', 'Dunn', 'erin.dunn@sakilacustomer.org', 164, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (161, 1, 'Geraldine', 'Perkins', 'geraldine.perkins@sakilacustomer.org', 165, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (162, 2, 'Lauren', 'Hudson', 'lauren.hudson@sakilacustomer.org', 166, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (163, 1, 'Cathy', 'Spencer', 'cathy.spencer@sakilacustomer.org', 167, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (164, 2, 'Joann', 'Gardner', 'joann.gardner@sakilacustomer.org', 168, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (165, 2, 'Lorraine', 'Stephens', 'lorraine.stephens@sakilacustomer.org', 169, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (166, 1, 'Lynn', 'Payne', 'lynn.payne@sakilacustomer.org', 170, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (167, 2, 'Sally', 'Pierce', 'sally.pierce@sakilacustomer.org', 171, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (168, 1, 'Regina', 'Berry', 'regina.berry@sakilacustomer.org', 172, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (169, 2, 'Erica', 'Matthews', 'erica.matthews@sakilacustomer.org', 173, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (170, 1, 'Beatrice', 'Arnold', 'beatrice.arnold@sakilacustomer.org', 174, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (171, 2, 'Dolores', 'Wagner', 'dolores.wagner@sakilacustomer.org', 175, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (172, 1, 'Bernice', 'Willis', 'bernice.willis@sakilacustomer.org', 176, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (173, 1, 'Audrey', 'Ray', 'audrey.ray@sakilacustomer.org', 177, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (174, 2, 'Yvonne', 'Watkins', 'yvonne.watkins@sakilacustomer.org', 178, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (175, 1, 'Annette', 'Olson', 'annette.olson@sakilacustomer.org', 179, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (176, 1, 'June', 'Carroll', 'june.carroll@sakilacustomer.org', 180, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (177, 2, 'Samantha', 'Duncan', 'samantha.duncan@sakilacustomer.org', 181, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (178, 2, 'Marion', 'Snyder', 'marion.snyder@sakilacustomer.org', 182, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (179, 1, 'Dana', 'Hart', 'dana.hart@sakilacustomer.org', 183, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (180, 2, 'Stacy', 'Cunningham', 'stacy.cunningham@sakilacustomer.org', 184, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (181, 2, 'Ana', 'Bradley', 'ana.bradley@sakilacustomer.org', 185, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (182, 1, 'Renee', 'Lane', 'renee.lane@sakilacustomer.org', 186, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (183, 2, 'Ida', 'Andrews', 'ida.andrews@sakilacustomer.org', 187, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (184, 1, 'Vivian', 'Ruiz', 'vivian.ruiz@sakilacustomer.org', 188, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (185, 1, 'Roberta', 'Harper', 'roberta.harper@sakilacustomer.org', 189, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (186, 2, 'Holly', 'Fox', 'holly.fox@sakilacustomer.org', 190, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (187, 2, 'Brittany', 'Riley', 'brittany.riley@sakilacustomer.org', 191, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (188, 1, 'Melanie', 'Armstrong', 'melanie.armstrong@sakilacustomer.org', 192, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (189, 1, 'Loretta', 'Carpenter', 'loretta.carpenter@sakilacustomer.org', 193, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (190, 2, 'Yolanda', 'Weaver', 'yolanda.weaver@sakilacustomer.org', 194, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (191, 1, 'Jeanette', 'Greene', 'jeanette.greene@sakilacustomer.org', 195, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (192, 1, 'Laurie', 'Lawrence', 'laurie.lawrence@sakilacustomer.org', 196, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (193, 2, 'Katie', 'Elliott', 'katie.elliott@sakilacustomer.org', 197, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (194, 2, 'Kristen', 'Chavez', 'kristen.chavez@sakilacustomer.org', 198, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (195, 1, 'Vanessa', 'Sims', 'vanessa.sims@sakilacustomer.org', 199, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (196, 1, 'Alma', 'Austin', 'alma.austin@sakilacustomer.org', 200, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (197, 2, 'Sue', 'Peters', 'sue.peters@sakilacustomer.org', 201, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (198, 2, 'Elsie', 'Kelley', 'elsie.kelley@sakilacustomer.org', 202, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (199, 2, 'Beth', 'Franklin', 'beth.franklin@sakilacustomer.org', 203, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (200, 2, 'Jeanne', 'Lawson', 'jeanne.lawson@sakilacustomer.org', 204, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (201, 1, 'Vicki', 'Fields', 'vicki.fields@sakilacustomer.org', 205, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (202, 2, 'Carla', 'Gutierrez', 'carla.gutierrez@sakilacustomer.org', 206, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (203, 1, 'Tara', 'Ryan', 'tara.ryan@sakilacustomer.org', 207, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (204, 1, 'Rosemary', 'Schmidt', 'rosemary.schmidt@sakilacustomer.org', 208, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (205, 2, 'Eileen', 'Carr', 'eileen.carr@sakilacustomer.org', 209, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (206, 1, 'Terri', 'Vasquez', 'terri.vasquez@sakilacustomer.org', 210, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (207, 1, 'Gertrude', 'Castillo', 'gertrude.castillo@sakilacustomer.org', 211, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (208, 1, 'Lucy', 'Wheeler', 'lucy.wheeler@sakilacustomer.org', 212, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (209, 2, 'Tonya', 'Chapman', 'tonya.chapman@sakilacustomer.org', 213, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (210, 2, 'Ella', 'Oliver', 'ella.oliver@sakilacustomer.org', 214, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (211, 1, 'Stacey', 'Montgomery', 'stacey.montgomery@sakilacustomer.org', 215, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (212, 2, 'Wilma', 'Richards', 'wilma.richards@sakilacustomer.org', 216, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (213, 1, 'Gina', 'Williamson', 'gina.williamson@sakilacustomer.org', 217, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (214, 1, 'Kristin', 'Johnston', 'kristin.johnston@sakilacustomer.org', 218, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (215, 2, 'Jessie', 'Banks', 'jessie.banks@sakilacustomer.org', 219, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (216, 1, 'Natalie', 'Meyer', 'natalie.meyer@sakilacustomer.org', 220, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (217, 2, 'Agnes', 'Bishop', 'agnes.bishop@sakilacustomer.org', 221, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (218, 1, 'Vera', 'Mccoy', 'vera.mccoy@sakilacustomer.org', 222, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (219, 2, 'Willie', 'Howell', 'willie.howell@sakilacustomer.org', 223, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (220, 2, 'Charlene', 'Alvarez', 'charlene.alvarez@sakilacustomer.org', 224, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (221, 1, 'Bessie', 'Morrison', 'bessie.morrison@sakilacustomer.org', 225, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (222, 2, 'Delores', 'Hansen', 'delores.hansen@sakilacustomer.org', 226, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (223, 1, 'Melinda', 'Fernandez', 'melinda.fernandez@sakilacustomer.org', 227, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (224, 2, 'Pearl', 'Garza', 'pearl.garza@sakilacustomer.org', 228, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (225, 1, 'Arlene', 'Harvey', 'arlene.harvey@sakilacustomer.org', 229, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (226, 2, 'Maureen', 'Little', 'maureen.little@sakilacustomer.org', 230, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (227, 1, 'Colleen', 'Burton', 'colleen.burton@sakilacustomer.org', 231, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (228, 2, 'Allison', 'Stanley', 'allison.stanley@sakilacustomer.org', 232, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (229, 1, 'Tamara', 'Nguyen', 'tamara.nguyen@sakilacustomer.org', 233, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (230, 2, 'Joy', 'George', 'joy.george@sakilacustomer.org', 234, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (231, 1, 'Georgia', 'Jacobs', 'georgia.jacobs@sakilacustomer.org', 235, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (232, 2, 'Constance', 'Reid', 'constance.reid@sakilacustomer.org', 236, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (233, 2, 'Lillie', 'Kim', 'lillie.kim@sakilacustomer.org', 237, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (234, 1, 'Claudia', 'Fuller', 'claudia.fuller@sakilacustomer.org', 238, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (235, 1, 'Jackie', 'Lynch', 'jackie.lynch@sakilacustomer.org', 239, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (236, 1, 'Marcia', 'Dean', 'marcia.dean@sakilacustomer.org', 240, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (237, 1, 'Tanya', 'Gilbert', 'tanya.gilbert@sakilacustomer.org', 241, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (238, 1, 'Nellie', 'Garrett', 'nellie.garrett@sakilacustomer.org', 242, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (239, 2, 'Minnie', 'Romero', 'minnie.romero@sakilacustomer.org', 243, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (240, 1, 'Marlene', 'Welch', 'marlene.welch@sakilacustomer.org', 244, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (241, 2, 'Heidi', 'Larson', 'heidi.larson@sakilacustomer.org', 245, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (242, 1, 'Glenda', 'Frazier', 'glenda.frazier@sakilacustomer.org', 246, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (243, 1, 'Lydia', 'Burke', 'lydia.burke@sakilacustomer.org', 247, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (244, 2, 'Viola', 'Hanson', 'viola.hanson@sakilacustomer.org', 248, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (245, 1, 'Courtney', 'Day', 'courtney.day@sakilacustomer.org', 249, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (246, 1, 'Marian', 'Mendoza', 'marian.mendoza@sakilacustomer.org', 250, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (247, 1, 'Stella', 'Moreno', 'stella.moreno@sakilacustomer.org', 251, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (248, 1, 'Caroline', 'Bowman', 'caroline.bowman@sakilacustomer.org', 252, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (249, 2, 'Dora', 'Medina', 'dora.medina@sakilacustomer.org', 253, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (250, 2, 'Jo', 'Fowler', 'jo.fowler@sakilacustomer.org', 254, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (251, 2, 'Vickie', 'Brewer', 'vickie.brewer@sakilacustomer.org', 255, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (252, 2, 'Mattie', 'Hoffman', 'mattie.hoffman@sakilacustomer.org', 256, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (253, 1, 'Terry', 'Carlson', 'terry.carlson@sakilacustomer.org', 258, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (254, 2, 'Maxine', 'Silva', 'maxine.silva@sakilacustomer.org', 259, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (255, 2, 'Irma', 'Pearson', 'irma.pearson@sakilacustomer.org', 260, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (256, 2, 'Mabel', 'Holland', 'mabel.holland@sakilacustomer.org', 261, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (257, 2, 'Marsha', 'Douglas', 'marsha.douglas@sakilacustomer.org', 262, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (258, 1, 'Myrtle', 'Fleming', 'myrtle.fleming@sakilacustomer.org', 263, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (259, 2, 'Lena', 'Jensen', 'lena.jensen@sakilacustomer.org', 264, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (260, 1, 'Christy', 'Vargas', 'christy.vargas@sakilacustomer.org', 265, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (261, 1, 'Deanna', 'Byrd', 'deanna.byrd@sakilacustomer.org', 266, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (262, 2, 'Patsy', 'Davidson', 'patsy.davidson@sakilacustomer.org', 267, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (263, 1, 'Hilda', 'Hopkins', 'hilda.hopkins@sakilacustomer.org', 268, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (264, 1, 'Gwendolyn', 'May', 'gwendolyn.may@sakilacustomer.org', 269, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (265, 2, 'Jennie', 'Terry', 'jennie.terry@sakilacustomer.org', 270, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (266, 2, 'Nora', 'Herrera', 'nora.herrera@sakilacustomer.org', 271, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (267, 1, 'Margie', 'Wade', 'margie.wade@sakilacustomer.org', 272, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (268, 1, 'Nina', 'Soto', 'nina.soto@sakilacustomer.org', 273, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (269, 1, 'Cassandra', 'Walters', 'cassandra.walters@sakilacustomer.org', 274, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (270, 1, 'Leah', 'Curtis', 'leah.curtis@sakilacustomer.org', 275, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (271, 1, 'Penny', 'Neal', 'penny.neal@sakilacustomer.org', 276, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (272, 1, 'Kay', 'Caldwell', 'kay.caldwell@sakilacustomer.org', 277, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (273, 2, 'Priscilla', 'Lowe', 'priscilla.lowe@sakilacustomer.org', 278, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (274, 1, 'Naomi', 'Jennings', 'naomi.jennings@sakilacustomer.org', 279, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (275, 2, 'Carole', 'Barnett', 'carole.barnett@sakilacustomer.org', 280, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (276, 1, 'Brandy', 'Graves', 'brandy.graves@sakilacustomer.org', 281, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (277, 2, 'Olga', 'Jimenez', 'olga.jimenez@sakilacustomer.org', 282, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (278, 2, 'Billie', 'Horton', 'billie.horton@sakilacustomer.org', 283, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (279, 2, 'Dianne', 'Shelton', 'dianne.shelton@sakilacustomer.org', 284, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (280, 2, 'Tracey', 'Barrett', 'tracey.barrett@sakilacustomer.org', 285, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (281, 2, 'Leona', 'Obrien', 'leona.obrien@sakilacustomer.org', 286, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (282, 2, 'Jenny', 'Castro', 'jenny.castro@sakilacustomer.org', 287, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (283, 1, 'Felicia', 'Sutton', 'felicia.sutton@sakilacustomer.org', 288, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (284, 1, 'Sonia', 'Gregory', 'sonia.gregory@sakilacustomer.org', 289, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (285, 1, 'Miriam', 'Mckinney', 'miriam.mckinney@sakilacustomer.org', 290, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (286, 1, 'Velma', 'Lucas', 'velma.lucas@sakilacustomer.org', 291, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (287, 2, 'Becky', 'Miles', 'becky.miles@sakilacustomer.org', 292, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (288, 1, 'Bobbie', 'Craig', 'bobbie.craig@sakilacustomer.org', 293, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (289, 1, 'Violet', 'Rodriquez', 'violet.rodriquez@sakilacustomer.org', 294, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (290, 1, 'Kristina', 'Chambers', 'kristina.chambers@sakilacustomer.org', 295, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (291, 1, 'Toni', 'Holt', 'toni.holt@sakilacustomer.org', 296, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (292, 2, 'Misty', 'Lambert', 'misty.lambert@sakilacustomer.org', 297, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (293, 2, 'Mae', 'Fletcher', 'mae.fletcher@sakilacustomer.org', 298, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (294, 2, 'Shelly', 'Watts', 'shelly.watts@sakilacustomer.org', 299, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (295, 1, 'Daisy', 'Bates', 'daisy.bates@sakilacustomer.org', 300, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (296, 2, 'Ramona', 'Hale', 'ramona.hale@sakilacustomer.org', 301, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (297, 1, 'Sherri', 'Rhodes', 'sherri.rhodes@sakilacustomer.org', 302, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (298, 1, 'Erika', 'Pena', 'erika.pena@sakilacustomer.org', 303, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (299, 2, 'James', 'Gannon', 'james.gannon@sakilacustomer.org', 304, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (300, 1, 'John', 'Farnsworth', 'john.farnsworth@sakilacustomer.org', 305, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (301, 2, 'Robert', 'Baughman', 'robert.baughman@sakilacustomer.org', 306, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (302, 1, 'Michael', 'Silverman', 'michael.silverman@sakilacustomer.org', 307, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# ...
# (499, 2, 'Marc', 'Outlaw', 'marc.outlaw@sakilacustomer.org', 504, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (500, 1, 'Reginald', 'Kinder', 'reginald.kinder@sakilacustomer.org', 505, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (501, 1, 'Ruben', 'Geary', 'ruben.geary@sakilacustomer.org', 506, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (502, 1, 'Brett', 'Cornwell', 'brett.cornwell@sakilacustomer.org', 507, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (503, 1, 'Angel', 'Barclay', 'angel.barclay@sakilacustomer.org', 508, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (504, 1, 'Nathaniel', 'Adam', 'nathaniel.adam@sakilacustomer.org', 509, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (505, 1, 'Rafael', 'Abney', 'rafael.abney@sakilacustomer.org', 510, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (506, 2, 'Leslie', 'Seward', 'leslie.seward@sakilacustomer.org', 511, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (507, 2, 'Edgar', 'Rhoads', 'edgar.rhoads@sakilacustomer.org', 512, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (508, 2, 'Milton', 'Howland', 'milton.howland@sakilacustomer.org', 513, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (509, 1, 'Raul', 'Fortier', 'raul.fortier@sakilacustomer.org', 514, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (510, 2, 'Ben', 'Easter', 'ben.easter@sakilacustomer.org', 515, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (511, 1, 'Chester', 'Benner', 'chester.benner@sakilacustomer.org', 516, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (512, 1, 'Cecil', 'Vines', 'cecil.vines@sakilacustomer.org', 517, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (513, 2, 'Duane', 'Tubbs', 'duane.tubbs@sakilacustomer.org', 519, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (514, 2, 'Franklin', 'Troutman', 'franklin.troutman@sakilacustomer.org', 520, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (515, 1, 'Andre', 'Rapp', 'andre.rapp@sakilacustomer.org', 521, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (516, 2, 'Elmer', 'Noe', 'elmer.noe@sakilacustomer.org', 522, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (517, 2, 'Brad', 'Mccurdy', 'brad.mccurdy@sakilacustomer.org', 523, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (518, 1, 'Gabriel', 'Harder', 'gabriel.harder@sakilacustomer.org', 524, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (519, 2, 'Ron', 'Deluca', 'ron.deluca@sakilacustomer.org', 525, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (520, 2, 'Mitchell', 'Westmoreland', 'mitchell.westmoreland@sakilacustomer.org', 526, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (521, 2, 'Roland', 'South', 'roland.south@sakilacustomer.org', 527, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (522, 2, 'Arnold', 'Havens', 'arnold.havens@sakilacustomer.org', 528, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (523, 1, 'Harvey', 'Guajardo', 'harvey.guajardo@sakilacustomer.org', 529, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (525, 2, 'Adrian', 'Clary', 'adrian.clary@sakilacustomer.org', 531, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (526, 2, 'Karl', 'Seal', 'karl.seal@sakilacustomer.org', 532, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (527, 1, 'Cory', 'Meehan', 'cory.meehan@sakilacustomer.org', 533, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (528, 1, 'Claude', 'Herzog', 'claude.herzog@sakilacustomer.org', 534, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (529, 2, 'Erik', 'Guillen', 'erik.guillen@sakilacustomer.org', 535, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (530, 2, 'Darryl', 'Ashcraft', 'darryl.ashcraft@sakilacustomer.org', 536, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (531, 2, 'Jamie', 'Waugh', 'jamie.waugh@sakilacustomer.org', 537, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (532, 2, 'Neil', 'Renner', 'neil.renner@sakilacustomer.org', 538, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (533, 1, 'Jessie', 'Milam', 'jessie.milam@sakilacustomer.org', 539, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (534, 1, 'Christian', 'Jung', 'christian.jung@sakilacustomer.org', 540, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (535, 1, 'Javier', 'Elrod', 'javier.elrod@sakilacustomer.org', 541, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (536, 2, 'Fernando', 'Churchill', 'fernando.churchill@sakilacustomer.org', 542, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (537, 2, 'Clinton', 'Buford', 'clinton.buford@sakilacustomer.org', 543, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (538, 2, 'Ted', 'Breaux', 'ted.breaux@sakilacustomer.org', 544, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (539, 1, 'Mathew', 'Bolin', 'mathew.bolin@sakilacustomer.org', 545, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (540, 1, 'Tyrone', 'Asher', 'tyrone.asher@sakilacustomer.org', 546, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (541, 2, 'Darren', 'Windham', 'darren.windham@sakilacustomer.org', 547, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (542, 2, 'Lonnie', 'Tirado', 'lonnie.tirado@sakilacustomer.org', 548, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (543, 1, 'Lance', 'Pemberton', 'lance.pemberton@sakilacustomer.org', 549, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (544, 2, 'Cody', 'Nolen', 'cody.nolen@sakilacustomer.org', 550, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (545, 2, 'Julio', 'Noland', 'julio.noland@sakilacustomer.org', 551, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (546, 1, 'Kelly', 'Knott', 'kelly.knott@sakilacustomer.org', 552, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (547, 1, 'Kurt', 'Emmons', 'kurt.emmons@sakilacustomer.org', 553, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (548, 1, 'Allan', 'Cornish', 'allan.cornish@sakilacustomer.org', 554, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (549, 1, 'Nelson', 'Christenson', 'nelson.christenson@sakilacustomer.org', 555, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (550, 2, 'Guy', 'Brownlee', 'guy.brownlee@sakilacustomer.org', 556, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (551, 2, 'Clayton', 'Barbee', 'clayton.barbee@sakilacustomer.org', 557, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (552, 2, 'Hugh', 'Waldrop', 'hugh.waldrop@sakilacustomer.org', 558, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (553, 1, 'Max', 'Pitt', 'max.pitt@sakilacustomer.org', 559, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (554, 1, 'Dwayne', 'Olvera', 'dwayne.olvera@sakilacustomer.org', 560, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (555, 1, 'Dwight', 'Lombardi', 'dwight.lombardi@sakilacustomer.org', 561, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (556, 2, 'Armando', 'Gruber', 'armando.gruber@sakilacustomer.org', 562, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (557, 1, 'Felix', 'Gaffney', 'felix.gaffney@sakilacustomer.org', 563, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (558, 1, 'Jimmie', 'Eggleston', 'jimmie.eggleston@sakilacustomer.org', 564, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (559, 2, 'Everett', 'Banda', 'everett.banda@sakilacustomer.org', 565, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (560, 1, 'Jordan', 'Archuleta', 'jordan.archuleta@sakilacustomer.org', 566, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (561, 2, 'Ian', 'Still', 'ian.still@sakilacustomer.org', 567, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (562, 1, 'Wallace', 'Slone', 'wallace.slone@sakilacustomer.org', 568, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (563, 2, 'Ken', 'Prewitt', 'ken.prewitt@sakilacustomer.org', 569, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (564, 2, 'Bob', 'Pfeiffer', 'bob.pfeiffer@sakilacustomer.org', 570, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (565, 2, 'Jaime', 'Nettles', 'jaime.nettles@sakilacustomer.org', 571, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (566, 1, 'Casey', 'Mena', 'casey.mena@sakilacustomer.org', 572, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (567, 2, 'Alfredo', 'Mcadams', 'alfredo.mcadams@sakilacustomer.org', 573, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (568, 2, 'Alberto', 'Henning', 'alberto.henning@sakilacustomer.org', 574, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (569, 2, 'Dave', 'Gardiner', 'dave.gardiner@sakilacustomer.org', 575, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (570, 2, 'Ivan', 'Cromwell', 'ivan.cromwell@sakilacustomer.org', 576, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (571, 2, 'Johnnie', 'Chisholm', 'johnnie.chisholm@sakilacustomer.org', 577, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (572, 1, 'Sidney', 'Burleson', 'sidney.burleson@sakilacustomer.org', 578, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (573, 1, 'Byron', 'Box', 'byron.box@sakilacustomer.org', 579, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (574, 2, 'Julian', 'Vest', 'julian.vest@sakilacustomer.org', 580, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (575, 2, 'Isaac', 'Oglesby', 'isaac.oglesby@sakilacustomer.org', 581, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (576, 2, 'Morris', 'Mccarter', 'morris.mccarter@sakilacustomer.org', 582, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (577, 2, 'Clifton', 'Malcolm', 'clifton.malcolm@sakilacustomer.org', 583, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (578, 2, 'Willard', 'Lumpkin', 'willard.lumpkin@sakilacustomer.org', 584, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (579, 2, 'Daryl', 'Larue', 'daryl.larue@sakilacustomer.org', 585, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (580, 1, 'Ross', 'Grey', 'ross.grey@sakilacustomer.org', 586, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (581, 1, 'Virgil', 'Wofford', 'virgil.wofford@sakilacustomer.org', 587, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (582, 2, 'Andy', 'Vanhorn', 'andy.vanhorn@sakilacustomer.org', 588, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (583, 1, 'Marshall', 'Thorn', 'marshall.thorn@sakilacustomer.org', 589, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (584, 2, 'Salvador', 'Teel', 'salvador.teel@sakilacustomer.org', 590, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (585, 1, 'Perry', 'Swafford', 'perry.swafford@sakilacustomer.org', 591, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (586, 1, 'Kirk', 'Stclair', 'kirk.stclair@sakilacustomer.org', 592, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (587, 1, 'Sergio', 'Stanfield', 'sergio.stanfield@sakilacustomer.org', 593, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (588, 1, 'Marion', 'Ocampo', 'marion.ocampo@sakilacustomer.org', 594, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (589, 1, 'Tracy', 'Herrmann', 'tracy.herrmann@sakilacustomer.org', 595, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (590, 2, 'Seth', 'Hannon', 'seth.hannon@sakilacustomer.org', 596, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (591, 1, 'Kent', 'Arsenault', 'kent.arsenault@sakilacustomer.org', 597, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (592, 1, 'Terrance', 'Roush', 'terrance.roush@sakilacustomer.org', 598, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0)
# (593, 2, 'Rene', 'Mcalister', 'rene.mcalister@sakilacustomer.org', 599, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (594, 1, 'Eduardo', 'Hiatt', 'eduardo.hiatt@sakilacustomer.org', 600, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (595, 1, 'Terrence', 'Gunderson', 'terrence.gunderson@sakilacustomer.org', 601, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (596, 1, 'Enrique', 'Forsythe', 'enrique.forsythe@sakilacustomer.org', 602, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (597, 1, 'Freddie', 'Duggan', 'freddie.duggan@sakilacustomer.org', 603, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (598, 1, 'Wade', 'Delvalle', 'wade.delvalle@sakilacustomer.org', 604, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (599, 2, 'Austin', 'Cintron', 'austin.cintron@sakilacustomer.org', 605, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["customer_id", "store_id", "first_name", "last_name", "email", "address_id", "activebool", "create_date", "last_update", "active"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0          524         1      Jared       Ely
# 1            1         1       Mary     Smith
# 2            2         1   Patricia   Johnson
# 3            3         1      Linda  Williams
# 4            4         2    Barbara     Jones
#
#                                  email  address_id  activebool create_date  \
# 0         jared.ely@sakilacustomer.org         530        True  2006-02-14
# 1        mary.smith@sakilacustomer.org           5        True  2006-02-14
# 2  patricia.johnson@sakilacustomer.org           6        True  2006-02-14
# 3    linda.williams@sakilacustomer.org           7        True  2006-02-14
# 4     barbara.jones@sakilacustomer.org           8        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1
# 1 2013-05-26 14:49:45.738       1
# 2 2013-05-26 14:49:45.738       1
# 3 2013-05-26 14:49:45.738       1
# 4 2013-05-26 14:49:45.738       1

# %% [markdown]
# #### SELECT DISTINCT statement

# %%
# Return distinct/unique values in single column
# What unique rental rates do we have inside of the 'film' table?
select_records = """
SELECT DISTINCT rental_rate
FROM film
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (Decimal('2.99'),)
# (Decimal('4.99'),)
# (Decimal('0.99'),)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["rental rate"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#   rental rate
# 0        2.99
# 1        4.99
# 2        0.99

# %% [markdown]
# #### WHERE clause

# %%
# Extract / filter only those records (input rows) that fulfill specified condition
# Find all the rental rates that are highr than 4.00 dollars and replacement costs are greater than and equal to 19.99 and rating is equal to R
select_records = """
SELECT *
FROM film
WHERE rental_rate > 4.00 AND replacement_cost >= 19.99 AND rating = 'R';
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (384, 'Grosse Wonderful', 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia', 2006, 1, 5, Decimal('4.99'), 49, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'australia':18 'cat':8 'drama':5 'epic':4 'explor':11 'gross':1 'moos':16 'must':13 'redeem':14 'wonder':2")
# (20, 'Amelie Hellfighters', 'A Boring Drama of a Woman And a Squirrel who must Conquer a Student in A Baloon', 2006, 1, 4, Decimal('4.99'), 79, Decimal('23.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'ameli':1 'baloon':19 'bore':4 'conquer':14 'drama':5 'hellfight':2 'must':13 'squirrel':11 'student':16 'woman':8")
# (60, 'Beast Hunchback', 'A Awe-Inspiring Epistle of a Student And a Squirrel who must Defeat a Boy in Ancient China', 2006, 1, 3, Decimal('4.99'), 89, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'ancient':20 'awe':5 'awe-inspir':4 'beast':1 'boy':18 'china':21 'defeat':16 'epistl':7 'hunchback':2 'inspir':6 'must':15 'squirrel':13 'student':10")
# (100, 'Brooklyn Desert', 'A Beautiful Drama of a Dentist And a Composer who must Battle a Sumo Wrestler in The First Manned Space Station', 2006, 1, 7, Decimal('4.99'), 161, Decimal('21.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'battl':14 'beauti':4 'brooklyn':1 'compos':11 'dentist':8 'desert':2 'drama':5 'first':20 'man':21 'must':13 'space':22 'station':23 'sumo':16 'wrestler':17")
# (102, 'Bubble Grosse', 'A Awe-Inspiring Panorama of a Crocodile And a Moose who must Confront a Girl in A Baloon', 2006, 1, 4, Decimal('4.99'), 60, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'awe':5 'awe-inspir':4 'baloon':21 'bubbl':1 'confront':16 'crocodil':10 'girl':18 'gross':2 'inspir':6 'moos':13 'must':15 'panorama':7")
# (177, 'Connecticut Tramp', 'A Unbelieveable Drama of a Crocodile And a Mad Cow who must Reach a Dentist in A Shark Tank', 2006, 1, 4, Decimal('4.99'), 172, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'connecticut':1 'cow':12 'crocodil':8 'dentist':17 'drama':5 'mad':11 'must':14 'reach':15 'shark':20 'tank':21 'tramp':2 'unbeliev':4")
# (192, 'Crossing Divorce', 'A Beautiful Documentary of a Dog And a Robot who must Redeem a Womanizer in Berlin', 2006, 1, 4, Decimal('4.99'), 50, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'beauti':4 'berlin':18 'cross':1 'divorc':2 'documentari':5 'dog':8 'must':13 'redeem':14 'robot':11 'woman':16")
# (222, 'Desert Poseidon', 'A Brilliant Documentary of a Butler And a Frisbee who must Build a Astronaut in New Orleans', 2006, 1, 4, Decimal('4.99'), 64, Decimal('27.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'astronaut':16 'brilliant':4 'build':14 'butler':8 'desert':1 'documentari':5 'frisbe':11 'must':13 'new':18 'orlean':19 'poseidon':2")
# (256, 'Drop Waterfront', 'A Fanciful Documentary of a Husband And a Explorer who must Reach a Madman in Ancient China', 2006, 1, 6, Decimal('4.99'), 178, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'ancient':18 'china':19 'documentari':5 'drop':1 'explor':11 'fanci':4 'husband':8 'madman':16 'must':13 'reach':14 'waterfront':2")
# (310, 'Fever Empire', 'A Insightful Panorama of a Cat And a Boat who must Defeat a Boat in The Gulf of Mexico', 2006, 1, 5, Decimal('4.99'), 158, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'boat':11,16 'cat':8 'defeat':14 'empir':2 'fever':1 'gulf':19 'insight':4 'mexico':21 'must':13 'panorama':5")
# (312, 'Fiddler Lost', 'A Boring Tale of a Squirrel And a Dog who must Challenge a Madman in The Gulf of Mexico', 2006, 1, 4, Decimal('4.99'), 75, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'bore':4 'challeng':14 'dog':11 'fiddler':1 'gulf':19 'lost':2 'madman':16 'mexico':21 'must':13 'squirrel':8 'tale':5")
# (323, 'Flight Lies', 'A Stunning Character Study of a Crocodile And a Pioneer who must Pursue a Teacher in New Orleans', 2006, 1, 7, Decimal('4.99'), 179, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'charact':5 'crocodil':9 'flight':1 'lie':2 'must':14 'new':19 'orlean':20 'pioneer':12 'pursu':15 'studi':6 'stun':4 'teacher':17")
# (342, 'Fugitive Maguire', 'A Taut Epistle of a Feminist And a Sumo Wrestler who must Battle a Crocodile in Australia', 2006, 1, 7, Decimal('4.99'), 83, Decimal('28.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'australia':19 'battl':15 'crocodil':17 'epistl':5 'feminist':8 'fugit':1 'maguir':2 'must':14 'sumo':11 'taut':4 'wrestler':12")
# (365, 'Gold River', 'A Taut Documentary of a Database Administrator And a Waitress who must Reach a Mad Scientist in A Baloon Factory', 2006, 1, 4, Decimal('4.99'), 154, Decimal('21.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'administr':9 'baloon':21 'databas':8 'documentari':5 'factori':22 'gold':1 'mad':17 'must':14 'reach':15 'river':2 'scientist':18 'taut':4 'waitress':12")
# (372, 'Graceland Dynamite', 'A Taut Display of a Cat And a Girl who must Overcome a Database Administrator in New Orleans', 2006, 1, 5, Decimal('4.99'), 140, Decimal('26.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'administr':17 'cat':8 'databas':16 'display':5 'dynamit':2 'girl':11 'graceland':1 'must':13 'new':19 'orlean':20 'overcom':14 'taut':4")
# (381, 'Grinch Massage', 'A Intrepid Display of a Madman And a Feminist who must Pursue a Pioneer in The First Manned Space Station', 2006, 1, 7, Decimal('4.99'), 150, Decimal('25.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'display':5 'feminist':11 'first':19 'grinch':1 'intrepid':4 'madman':8 'man':20 'massag':2 'must':13 'pioneer':16 'pursu':14 'space':21 'station':22")
# (390, 'Guys Falcon', 'A Boring Story of a Woman And a Feminist who must Redeem a Squirrel in A U-Boat', 2006, 1, 4, Decimal('4.99'), 84, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'boat':21 'bore':4 'falcon':2 'feminist':11 'guy':1 'must':13 'redeem':14 'squirrel':16 'stori':5 'u':20 'u-boat':19 'woman':8")
# (408, 'Head Stranger', 'A Thoughtful Saga of a Hunter And a Crocodile who must Confront a Dog in The Gulf of Mexico', 2006, 1, 4, Decimal('4.99'), 69, Decimal('28.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'confront':14 'crocodil':11 'dog':16 'gulf':19 'head':1 'hunter':8 'mexico':21 'must':13 'saga':5 'stranger':2 'thought':4")
# (470, 'Ishtar Rocketeer', 'A Astounding Saga of a Dog And a Squirrel who must Conquer a Dog in An Abandoned Fun House', 2006, 1, 4, Decimal('4.99'), 79, Decimal('24.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'abandon':19 'astound':4 'conquer':14 'dog':8,16 'fun':20 'hous':21 'ishtar':1 'must':13 'rocket':2 'saga':5 'squirrel':11")
# (543, 'Madigan Dorado', 'A Astounding Character Study of a A Shark And a A Shark who must Discover a Crocodile in The Outback', 2006, 1, 5, Decimal('4.99'), 116, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'astound':4 'charact':5 'crocodil':19 'discov':17 'dorado':2 'madigan':1 'must':16 'outback':22 'shark':10,14 'studi':6")
# (640, 'Opus Ice', 'A Fast-Paced Drama of a Hunter And a Boy who must Discover a Feminist in The Sahara Desert', 2006, 1, 5, Decimal('4.99'), 102, Decimal('21.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'boy':13 'desert':22 'discov':16 'drama':7 'fast':5 'fast-pac':4 'feminist':18 'hunter':10 'ice':2 'must':15 'opus':1 'pace':6 'sahara':21")
# (708, 'Quills Bull', 'A Thoughtful Story of a Pioneer And a Woman who must Reach a Moose in Australia', 2006, 1, 4, Decimal('4.99'), 112, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'australia':18 'bull':2 'moos':16 'must':13 'pioneer':8 'quill':1 'reach':14 'stori':5 'thought':4 'woman':11")
# (725, 'Requiem Tycoon', 'A Unbelieveable Character Study of a Cat And a Database Administrator who must Pursue a Teacher in A Monastery', 2006, 1, 6, Decimal('4.99'), 167, Decimal('25.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'administr':13 'cat':9 'charact':5 'databas':12 'monasteri':21 'must':15 'pursu':16 'requiem':1 'studi':6 'teacher':18 'tycoon':2 'unbeliev':4")
# (749, 'Rules Human', 'A Beautiful Epistle of a Astronaut And a Student who must Confront a Monkey in An Abandoned Fun House', 2006, 1, 6, Decimal('4.99'), 153, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'abandon':19 'astronaut':8 'beauti':4 'confront':14 'epistl':5 'fun':20 'hous':21 'human':2 'monkey':16 'must':13 'rule':1 'student':11")
# (779, 'Sense Greek', 'A Taut Saga of a Lumberjack And a Pastry Chef who must Escape a Sumo Wrestler in An Abandoned Fun House', 2006, 1, 4, Decimal('4.99'), 54, Decimal('23.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'abandon':21 'chef':12 'escap':15 'fun':22 'greek':2 'hous':23 'lumberjack':8 'must':14 'pastri':11 'saga':5 'sens':1 'sumo':17 'taut':4 'wrestler':18")
# (803, 'Slacker Liaisons', 'A Fast-Paced Tale of a A Shark And a Student who must Meet a Crocodile in Ancient China', 2006, 1, 7, Decimal('4.99'), 179, Decimal('29.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'ancient':21 'china':22 'crocodil':19 'fast':5 'fast-pac':4 'liaison':2 'meet':17 'must':16 'pace':6 'shark':11 'slacker':1 'student':14 'tale':7")
# (817, 'Soldiers Evolution', 'A Lacklusture Panorama of a A Shark And a Pioneer who must Confront a Student in The First Manned Space Station', 2006, 1, 7, Decimal('4.99'), 185, Decimal('27.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'confront':15 'evolut':2 'first':20 'lacklustur':4 'man':21 'must':14 'panorama':5 'pioneer':12 'shark':9 'soldier':1 'space':22 'station':23 'student':17")
# (838, 'Stagecoach Armageddon', 'A Touching Display of a Pioneer And a Butler who must Chase a Car in California', 2006, 1, 5, Decimal('4.99'), 112, Decimal('25.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'armageddon':2 'butler':11 'california':18 'car':16 'chase':14 'display':5 'must':13 'pioneer':8 'stagecoach':1 'touch':4")
# (854, 'Strangers Graffiti', 'A Brilliant Character Study of a Secret Agent And a Man who must Find a Cat in The Gulf of Mexico', 2006, 1, 4, Decimal('4.99'), 119, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'agent':10 'brilliant':4 'cat':18 'charact':5 'find':16 'graffiti':2 'gulf':21 'man':13 'mexico':23 'must':15 'secret':9 'stranger':1 'studi':6")
# (858, 'Submarine Bed', 'A Amazing Display of a Car And a Monkey who must Fight a Teacher in Soviet Georgia', 2006, 1, 5, Decimal('4.99'), 127, Decimal('21.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'amaz':4 'bed':2 'car':8 'display':5 'fight':14 'georgia':19 'monkey':11 'must':13 'soviet':18 'submarin':1 'teacher':16")
# (889, 'Ties Hunger', 'A Insightful Saga of a Astronaut And a Explorer who must Pursue a Mad Scientist in A U-Boat', 2006, 1, 3, Decimal('4.99'), 111, Decimal('28.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'astronaut':8 'boat':22 'explor':11 'hunger':2 'insight':4 'mad':16 'must':13 'pursu':14 'saga':5 'scientist':17 'tie':1 'u':21 'u-boat':20")
# (904, 'Train Bunch', 'A Thrilling Character Study of a Robot And a Squirrel who must Face a Dog in Ancient India', 2006, 1, 3, Decimal('4.99'), 71, Decimal('26.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'ancient':19 'bunch':2 'charact':5 'dog':17 'face':15 'india':20 'must':14 'robot':9 'squirrel':12 'studi':6 'thrill':4 'train':1")
# (961, 'Wash Heavenly', 'A Awe-Inspiring Reflection of a Cat And a Pioneer who must Escape a Hunter in Ancient China', 2006, 1, 7, Decimal('4.99'), 161, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'ancient':20 'awe':5 'awe-inspir':4 'cat':10 'china':21 'escap':16 'heaven':2 'hunter':18 'inspir':6 'must':15 'pioneer':13 'reflect':7 'wash':1")
# (989, 'Working Microcosmos', 'A Stunning Epistle of a Dentist And a Dog who must Kill a Madman in Ancient China', 2006, 1, 4, Decimal('4.99'), 74, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'ancient':18 'china':19 'dentist':8 'dog':11 'epistl':5 'kill':14 'madman':16 'microcosmo':2 'must':13 'stun':4 'work':1")

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ['film_id', 'title', 'description', 'release_year', 'last_update', 'language_id', 'rental_duration', 'rental_rate', 'length', 'replacement_cost', 'rating', 'special_features', 'fulltext']

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#    film_id                title  \
# 0      384     Grosse Wonderful
# 1       20  Amelie Hellfighters
# 2       60      Beast Hunchback
# 3      100      Brooklyn Desert
# 4      102        Bubble Grosse
#
#                                          description  release_year  \
# 0  A Epic Drama of a Cat And a Explorer who must ...          2006
# 1  A Boring Drama of a Woman And a Squirrel who m...          2006
# 2  A Awe-Inspiring Epistle of a Student And a Squ...          2006
# 3  A Beautiful Drama of a Dentist And a Composer ...          2006
# 4  A Awe-Inspiring Panorama of a Crocodile And a ...          2006
#
#    last_update  language_id rental_duration  rental_rate length  \
# 0            1            5            4.99           49  19.99
# 1            1            4            4.99           79  23.99
# 2            1            3            4.99           89  22.99
# 3            1            7            4.99          161  21.99
# 4            1            4            4.99           60  20.99
#
#   replacement_cost                  rating  \
# 0                R 2013-05-26 14:50:58.951
# 1                R 2013-05-26 14:50:58.951
# 2                R 2013-05-26 14:50:58.951
# 3                R 2013-05-26 14:50:58.951
# 4                R 2013-05-26 14:50:58.951
#
#                                     special_features  \
# 0                                [Behind the Scenes]
# 1  [Commentaries, Deleted Scenes, Behind the Scenes]
# 2                [Deleted Scenes, Behind the Scenes]
# 3                                     [Commentaries]
# 4  [Trailers, Commentaries, Deleted Scenes, Behin...
#
#                                             fulltext
# 0  'australia':18 'cat':8 'drama':5 'epic':4 'exp...
# 1  'ameli':1 'baloon':19 'bore':4 'conquer':14 'd...
# 2  'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...
# 3  'battl':14 'beauti':4 'brooklyn':1 'compos':11...
# 4  'awe':5 'awe-inspir':4 'baloon':21 'bubbl':1 '...

# %% [markdown]
# #### COUNT function

# %%
# Return the number of records (rows) in column
# What are the actual number of distinct/unique amounts being paid?
select_records = """
SELECT COUNT (DISTINCT amount)
FROM payment;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (19,)

# %% [markdown]
# #### ORDER BY clause

# %%
# Sort the result set returned from query in ascending or descending order
# Order everything based of the store id and first name of the user
select_records = """
SELECT store_id, first_name, last_name
FROM customer
ORDER BY store_id DESC, first_name ASC;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (2, 'Aaron', 'Selby')
# (2, 'Adrian', 'Clary')
# (2, 'Agnes', 'Bishop')
# (2, 'Alberto', 'Henning')
# (2, 'Alex', 'Gresham')
# (2, 'Alexander', 'Fennell')
# (2, 'Alfred', 'Casillas')
# (2, 'Alfredo', 'Mcadams')
# (2, 'Allen', 'Butterfield')
# (2, 'Allison', 'Stanley')
# (2, 'Alvin', 'Deloach')
# (2, 'Amanda', 'Carter')
# (2, 'Ana', 'Bradley')
# (2, 'Andrew', 'Purdy')
# (2, 'Andy', 'Vanhorn')
# (2, 'Angela', 'Hernandez')
# (2, 'Anita', 'Morales')
# (2, 'Anna', 'Hill')
# (2, 'Anne', 'Powell')
# (2, 'Annie', 'Russell')
# (2, 'Anthony', 'Schwab')
# (2, 'Armando', 'Gruber')
# (2, 'Arnold', 'Havens')
# (2, 'Austin', 'Cintron')
# (2, 'Barbara', 'Jones')
# (2, 'Becky', 'Miles')
# (2, 'Ben', 'Easter')
# (2, 'Beth', 'Franklin')
# (2, 'Betty', 'White')
# (2, 'Beverly', 'Brooks')
# (2, 'Bill', 'Gavin')
# (2, 'Billie', 'Horton')
# (2, 'Bob', 'Pfeiffer')
# (2, 'Bobby', 'Boudreau')
# (2, 'Bonnie', 'Hughes')
# (2, 'Brad', 'Mccurdy')
# (2, 'Brenda', 'Wright')
# (2, 'Brittany', 'Riley')
# (2, 'Bruce', 'Schwarz')
# (2, 'Bryan', 'Hardison')
# (2, 'Carla', 'Gutierrez')
# (2, 'Carol', 'Garcia')
# (2, 'Carole', 'Barnett')
# (2, 'Carolyn', 'Perez')
# (2, 'Catherine', 'Campbell')
# (2, 'Charlene', 'Alvarez')
# (2, 'Charlie', 'Bess')
# (2, 'Chris', 'Brothers')
# (2, 'Christina', 'Ramirez')
# (2, 'Christine', 'Roberts')
# (2, 'Cindy', 'Fisher')
# (2, 'Clayton', 'Barbee')
# (2, 'Clifton', 'Malcolm')
# (2, 'Clinton', 'Buford')
# (2, 'Cody', 'Nolen')
# (2, 'Constance', 'Reid')
# (2, 'Craig', 'Morrell')
# (2, 'Curtis', 'Irby')
# (2, 'Daniel', 'Cabral')
# (2, 'Danielle', 'Daniels')
# (2, 'Darlene', 'Rose')
# (2, 'Darrell', 'Power')
# (2, 'Darren', 'Windham')
# (2, 'Darryl', 'Ashcraft')
# (2, 'Daryl', 'Larue')
# (2, 'Dave', 'Gardiner')
# (2, 'David', 'Royal')
# (2, 'Delores', 'Hansen')
# (2, 'Dianne', 'Shelton')
# (2, 'Dolores', 'Wagner')
# (2, 'Donald', 'Mahon')
# (2, 'Dora', 'Medina')
# (2, 'Doris', 'Reed')
# (2, 'Duane', 'Tubbs')
# (2, 'Dustin', 'Gillette')
# (2, 'Edgar', 'Rhoads')
# (2, 'Edna', 'West')
# (2, 'Edward', 'Baugh')
# (2, 'Eileen', 'Carr')
# (2, 'Elaine', 'Stevens')
# (2, 'Ella', 'Oliver')
# (2, 'Elmer', 'Noe')
# (2, 'Elsie', 'Kelley')
# (2, 'Emily', 'Diaz')
# (2, 'Erica', 'Matthews')
# (2, 'Erik', 'Guillen')
# (2, 'Erin', 'Dunn')
# (2, 'Ernest', 'Stepp')
# (2, 'Esther', 'Crawford')
# (2, 'Evelyn', 'Morgan')
# (2, 'Everett', 'Banda')
# (2, 'Fernando', 'Churchill')
# (2, 'Francis', 'Sikes')
# (2, 'Francisco', 'Skidmore')
# (2, 'Frank', 'Waggoner')
# (2, 'Franklin', 'Troutman')
# (2, 'Fred', 'Wheat')
# (2, 'Frederick', 'Isbell')
# (2, 'Gary', 'Coy')
# (2, 'Gerald', 'Fultz')
# (2, 'Gilbert', 'Sledge')
# (2, 'Grace', 'Ellis')
# (2, 'Guy', 'Brownlee')
# (2, 'Hector', 'Poindexter')
# (2, 'Heidi', 'Larson')
# (2, 'Herbert', 'Kruger')
# (2, 'Holly', 'Fox')
# (2, 'Hugh', 'Waldrop')
# (2, 'Ian', 'Still')
# (2, 'Ida', 'Andrews')
# (2, 'Irene', 'Price')
# (2, 'Irma', 'Pearson')
# (2, 'Isaac', 'Oglesby')
# (2, 'Ivan', 'Cromwell')
# (2, 'Jacqueline', 'Long')
# (2, 'Jaime', 'Nettles')
# (2, 'James', 'Gannon')
# (2, 'Jamie', 'Waugh')
# (2, 'Jane', 'Bennett')
# (2, 'Janice', 'Ward')
# (2, 'Jeanne', 'Lawson')
# (2, 'Jeff', 'East')
# (2, 'Jeffery', 'Pinson')
# (2, 'Jeffrey', 'Spear')
# (2, 'Jennie', 'Terry')
# (2, 'Jennifer', 'Davis')
# (2, 'Jenny', 'Castro')
# (2, 'Jeremy', 'Hurtado')
# (2, 'Jesse', 'Schilling')
# (2, 'Jessica', 'Hall')
# (2, 'Jessie', 'Banks')
# (2, 'Jesus', 'Mccartney')
# (2, 'Jo', 'Fowler')
# (2, 'Joann', 'Gardner')
# (2, 'Joanne', 'Robertson')
# (2, 'Joe', 'Gilliland')
# (2, 'Joel', 'Francisco')
# (2, 'Johnnie', 'Chisholm')
# (2, 'Johnny', 'Turpin')
# (2, 'Jon', 'Wiles')
# (2, 'Jorge', 'Olivares')
# (2, 'Joseph', 'Joy')
# (2, 'Joy', 'George')
# (2, 'Joyce', 'Edwards')
# (2, 'Juanita', 'Mason')
# (2, 'Judith', 'Cox')
# (2, 'Judy', 'Gray')
# (2, 'Julian', 'Vest')
# (2, 'Julio', 'Noland')
# (2, 'Justin', 'Ngo')
# (2, 'Karen', 'Jackson')
# (2, 'Karl', 'Seal')
# (2, 'Katherine', 'Rivera')
# (2, 'Kathleen', 'Adams')
# (2, 'Katie', 'Elliott')
# (2, 'Ken', 'Prewitt')
# (2, 'Kenneth', 'Gooden')
# (2, 'Kimberly', 'Lee')
# (2, 'Kristen', 'Chavez')
# (2, 'Kyle', 'Spurlock')
# (2, 'Larry', 'Thrasher')
# (2, 'Lauren', 'Hudson')
# (2, 'Lawrence', 'Lawton')
# (2, 'Lena', 'Jensen')
# (2, 'Leona', 'Obrien')
# (2, 'Leslie', 'Seward')
# (2, 'Lester', 'Kraus')
# (2, 'Lillie', 'Kim')
# (2, 'Lisa', 'Anderson')
# (2, 'Lois', 'Butler')
# (2, 'Lonnie', 'Tirado')
# (2, 'Lorraine', 'Stephens')
# (2, 'Mabel', 'Holland')
# (2, 'Mae', 'Fletcher')
# (2, 'Marc', 'Outlaw')
# (2, 'Marcus', 'Hidalgo')
# (2, 'Margaret', 'Moore')
# (2, 'Marion', 'Snyder')
# (2, 'Mark', 'Rinehart')
# (2, 'Marsha', 'Douglas')
# (2, 'Marvin', 'Yee')
# (2, 'Matthew', 'Mahan')
# (2, 'Mattie', 'Hoffman')
# (2, 'Maureen', 'Little')
# (2, 'Maxine', 'Silva')
# (2, 'Megan', 'Palmer')
# (2, 'Michele', 'Grant')
# (2, 'Milton', 'Howland')
# (2, 'Minnie', 'Romero')
# (2, 'Misty', 'Lambert')
# (2, 'Mitchell', 'Westmoreland')
# (2, 'Monica', 'Hicks')
# (2, 'Morris', 'Mccarter')
# (2, 'Neil', 'Renner')
# (2, 'Nora', 'Herrera')
# (2, 'Olga', 'Jimenez')
# (2, 'Oscar', 'Aquino')
# (2, 'Patsy', 'Davidson')
# (2, 'Paul', 'Trout')
# (2, 'Paula', 'Bryant')
# (2, 'Pearl', 'Garza')
# (2, 'Pedro', 'Chestnut')
# (2, 'Priscilla', 'Lowe')
# (2, 'Ralph', 'Madrigal')
# (2, 'Ramon', 'Choate')
# (2, 'Ramona', 'Hale')
# (2, 'Randall', 'Neumann')
# (2, 'Raymond', 'Mcwhorter')
# (2, 'Rebecca', 'Scott')
# (2, 'Rene', 'Mcalister')
# (2, 'Rhonda', 'Kennedy')
# (2, 'Rick', 'Mattox')
# (2, 'Ricky', 'Shelby')
# (2, 'Robert', 'Baughman')
# (2, 'Rodney', 'Moeller')
# (2, 'Roger', 'Quintanilla')
# (2, 'Roland', 'South')
# (2, 'Ron', 'Deluca')
# (2, 'Ronald', 'Weiner')
# (2, 'Ronnie', 'Ricketts')
# (2, 'Rosa', 'Reynolds')
# (2, 'Rose', 'Howard')
# (2, 'Roy', 'Whiting')
# (2, 'Ruby', 'Washington')
# (2, 'Ryan', 'Salisbury')
# (2, 'Sally', 'Pierce')
# (2, 'Salvador', 'Teel')
# (2, 'Samantha', 'Duncan')
# (2, 'Samuel', 'Marlow')
# (2, 'Sandra', 'Martin')
# (2, 'Sara', 'Perry')
# (2, 'Sarah', 'Lewis')
# (2, 'Sean', 'Douglass')
# (2, 'Seth', 'Hannon')
# (2, 'Shane', 'Millard')
# (2, 'Shannon', 'Freeman')
# (2, 'Sharon', 'Robinson')
# (2, 'Shelly', 'Watts')
# (2, 'Shirley', 'Allen')
# (2, 'Stacy', 'Cunningham')
# (2, 'Stanley', 'Scroggins')
# (2, 'Steve', 'Mackenzie')
# (2, 'Sue', 'Peters')
# (2, 'Susan', 'Wilson')
# (2, 'Suzanne', 'Nichols')
# (2, 'Sylvia', 'Ortiz')
# (2, 'Tammy', 'Sanders')
# (2, 'Ted', 'Breaux')
# (2, 'Terry', 'Grissom')
# (2, 'Theodore', 'Culp')
# (2, 'Theresa', 'Watson')
# (2, 'Tiffany', 'Jordan')
# (2, 'Tina', 'Simmons')
# (2, 'Tony', 'Carranza')
# (2, 'Tonya', 'Chapman')
# (2, 'Tracey', 'Barrett')
# (2, 'Tyler', 'Wren')
# (2, 'Vernon', 'Chapa')
# (2, 'Vickie', 'Brewer')
# (2, 'Victor', 'Barkley')
# (2, 'Viola', 'Hanson')
# (2, 'Virginia', 'Green')
# (2, 'Walter', 'Perryman')
# (2, 'Warren', 'Sherrod')
# (2, 'Wayne', 'Truong')
# (2, 'Wesley', 'Bull')
# (2, 'Willard', 'Lumpkin')
# (2, 'William', 'Satterfield')
# (2, 'Willie', 'Howell')
# (2, 'Willie', 'Markham')
# (2, 'Wilma', 'Richards')
# (2, 'Yolanda', 'Weaver')
# (2, 'Yvonne', 'Watkins')
# (1, 'Adam', 'Gooch')
# (1, 'Alan', 'Kahn')
# (1, 'Albert', 'Crouse')
# (1, 'Alice', 'Stewart')
# (1, 'Alicia', 'Mills')
# (1, 'Allan', 'Cornish')
# (1, 'Alma', 'Austin')
# (1, 'Amber', 'Dixon')
# (1, 'Amy', 'Lopez')
# (1, 'Andre', 'Rapp')
# (1, 'Andrea', 'Henderson')
# (1, 'Angel', 'Barclay')
# (1, 'Ann', 'Evans')
# (1, 'Annette', 'Olson')
# (1, 'Antonio', 'Meek')
# (1, 'April', 'Burns')
# (1, 'Arlene', 'Harvey')
# (1, 'Arthur', 'Simpkins')
# (1, 'Ashley', 'Richardson')
# (1, 'Audrey', 'Ray')
# (1, 'Barry', 'Lovelace')
# (1, 'Beatrice', 'Arnold')
# (1, 'Benjamin', 'Varney')
# (1, 'Bernard', 'Colby')
# (1, 'Bernice', 'Willis')
# (1, 'Bertha', 'Ferguson')
# (1, 'Bessie', 'Morrison')
# (1, 'Billy', 'Poulin')
# (1, 'Bobbie', 'Craig')
# (1, 'Bradley', 'Motley')
# (1, 'Brandon', 'Huey')
# (1, 'Brandy', 'Graves')
# (1, 'Brent', 'Harkins')
# (1, 'Brett', 'Cornwell')
# (1, 'Brian', 'Wyman')
# (1, 'Byron', 'Box')
# (1, 'Calvin', 'Martel')
# (1, 'Carl', 'Artis')
# (1, 'Carlos', 'Coughlin')
# (1, 'Carmen', 'Owens')
# (1, 'Caroline', 'Bowman')
# (1, 'Carrie', 'Porter')
# (1, 'Casey', 'Mena')
# (1, 'Cassandra', 'Walters')
# (1, 'Cathy', 'Spencer')
# (1, 'Cecil', 'Vines')
# (1, 'Chad', 'Carbone')
# (1, 'Charles', 'Kowalski')
# (1, 'Charlotte', 'Hunter')
# (1, 'Cheryl', 'Murphy')
# (1, 'Chester', 'Benner')
# (1, 'Christian', 'Jung')
# (1, 'Christopher', 'Greco')
# (1, 'Christy', 'Vargas')
# (1, 'Clara', 'Shaw')
# (1, 'Clarence', 'Gamez')
# (1, 'Claude', 'Herzog')
# (1, 'Claudia', 'Fuller')
# (1, 'Clifford', 'Bowens')
# (1, 'Clyde', 'Tobias')
# (1, 'Colleen', 'Burton')
# (1, 'Connie', 'Wallace')
# (1, 'Corey', 'Hauser')
# (1, 'Cory', 'Meehan')
# (1, 'Courtney', 'Day')
# (1, 'Crystal', 'Ford')
# (1, 'Cynthia', 'Young')
# (1, 'Daisy', 'Bates')
# (1, 'Dale', 'Ratcliff')
# (1, 'Dan', 'Paine')
# (1, 'Dana', 'Hart')
# (1, 'Danny', 'Isom')
# (1, 'Dawn', 'Sullivan')
# (1, 'Dean', 'Sauer')
# (1, 'Deanna', 'Byrd')
# (1, 'Debbie', 'Reyes')
# (1, 'Deborah', 'Walker')
# (1, 'Debra', 'Nelson')
# (1, 'Denise', 'Kelly')
# (1, 'Dennis', 'Gilman')
# (1, 'Derek', 'Blakely')
# (1, 'Derrick', 'Bourque')
# (1, 'Diana', 'Alexander')
# (1, 'Diane', 'Collins')
# (1, 'Don', 'Bone')
# (1, 'Donna', 'Thompson')
# (1, 'Dorothy', 'Taylor')
# (1, 'Douglas', 'Graf')
# (1, 'Dwayne', 'Olvera')
# (1, 'Dwight', 'Lombardi')
# (1, 'Earl', 'Shanks')
# (1, 'Eddie', 'Tomlin')
# (1, 'Edith', 'Mcdonald')
# (1, 'Eduardo', 'Hiatt')
# (1, 'Edwin', 'Burk')
# (1, 'Eleanor', 'Hunt')
# (1, 'Elizabeth', 'Brown')
# (1, 'Ellen', 'Simpson')
# (1, 'Emma', 'Boyd')
# (1, 'Enrique', 'Forsythe')
# (1, 'Eric', 'Robert')
# (1, 'Erika', 'Pena')
# (1, 'Ethel', 'Webb')
# (1, 'Eugene', 'Culpepper')
# (1, 'Eva', 'Ramos')
# (1, 'Felicia', 'Sutton')
# (1, 'Felix', 'Gaffney')
# (1, 'Florence', 'Woods')
# (1, 'Floyd', 'Gandy')
# (1, 'Frances', 'Parker')
# (1, 'Freddie', 'Duggan')
# (1, 'Gabriel', 'Harder')
# (1, 'Gail', 'Knight')
# (1, 'Gene', 'Sanborn')
# (1, 'George', 'Linton')
# (1, 'Georgia', 'Jacobs')
# (1, 'Geraldine', 'Perkins')
# (1, 'Gertrude', 'Castillo')
# (1, 'Gina', 'Williamson')
# (1, 'Gladys', 'Hamilton')
# (1, 'Glen', 'Talbert')
# (1, 'Glenda', 'Frazier')
# (1, 'Glenn', 'Pullen')
# (1, 'Gloria', 'Cook')
# (1, 'Gordon', 'Allard')
# (1, 'Greg', 'Robins')
# (1, 'Gregory', 'Mauldin')
# (1, 'Gwendolyn', 'May')
# (1, 'Harold', 'Martino')
# (1, 'Harry', 'Arce')
# (1, 'Harvey', 'Guajardo')
# (1, 'Hazel', 'Warren')
# (1, 'Heather', 'Morris')
# (1, 'Helen', 'Harris')
# (1, 'Henry', 'Billingsley')
# (1, 'Herman', 'Devore')
# (1, 'Hilda', 'Hopkins')
# (1, 'Howard', 'Fortner')
# (1, 'Jack', 'Foust')
# (1, 'Jackie', 'Lynch')
# (1, 'Jacob', 'Lance')
# (1, 'Jamie', 'Rice')
# (1, 'Janet', 'Phillips')
# (1, 'Jared', 'Ely')
# (1, 'Jason', 'Morrissey')
# (1, 'Javier', 'Elrod')
# (1, 'Jay', 'Robb')
# (1, 'Jean', 'Bell')
# (1, 'Jeanette', 'Greene')
# (1, 'Jerome', 'Kenyon')
# (1, 'Jerry', 'Jordon')
# (1, 'Jessie', 'Milam')
# (1, 'Jill', 'Hawkins')
# (1, 'Jim', 'Rea')
# (1, 'Jimmie', 'Eggleston')
# (1, 'Jimmy', 'Schrader')
# (1, 'Joan', 'Cooper')
# (1, 'John', 'Farnsworth')
# (1, 'Jonathan', 'Scarborough')
# (1, 'Jordan', 'Archuleta')
# (1, 'Jose', 'Andrew')
# (1, 'Josephine', 'Gomez')
# (1, 'Joshua', 'Mark')
# (1, 'Juan', 'Fraley')
# (1, 'Julia', 'Flores')
# (1, 'Julie', 'Sanchez')
# (1, 'June', 'Carroll')
# (1, 'Kathryn', 'Coleman')
# (1, 'Kathy', 'James')
# (1, 'Kay', 'Caldwell')
# (1, 'Keith', 'Rico')
# (1, 'Kelly', 'Knott')
# (1, 'Kelly', 'Torres')
# (1, 'Kent', 'Arsenault')
# (1, 'Kevin', 'Schuler')
# (1, 'Kim', 'Cruz')
# (1, 'Kirk', 'Stclair')
# (1, 'Kristin', 'Johnston')
# (1, 'Kristina', 'Chambers')
# (1, 'Kurt', 'Emmons')
# (1, 'Lance', 'Pemberton')
# (1, 'Laura', 'Rodriguez')
# (1, 'Laurie', 'Lawrence')
# (1, 'Leah', 'Curtis')
# (1, 'Lee', 'Hawks')
# (1, 'Leo', 'Ebert')
# (1, 'Leon', 'Bostic')
# (1, 'Leonard', 'Schofield')
# (1, 'Leroy', 'Bustamante')
# (1, 'Leslie', 'Gordon')
# (1, 'Lewis', 'Lyman')
# (1, 'Lillian', 'Griffin')
# (1, 'Linda', 'Williams')
# (1, 'Lloyd', 'Dowd')
# (1, 'Loretta', 'Carpenter')
# (1, 'Lori', 'Wood')
# (1, 'Louis', 'Leone')
# (1, 'Louise', 'Jenkins')
# (1, 'Lucille', 'Holmes')
# (1, 'Lucy', 'Wheeler')
# (1, 'Luis', 'Yanez')
# (1, 'Lydia', 'Burke')
# (1, 'Lynn', 'Payne')
# (1, 'Manuel', 'Murrell')
# (1, 'Marcia', 'Dean')
# (1, 'Margie', 'Wade')
# (1, 'Maria', 'Miller')
# (1, 'Marian', 'Mendoza')
# (1, 'Marie', 'Turner')
# (1, 'Marilyn', 'Ross')
# (1, 'Mario', 'Cheatham')
# (1, 'Marion', 'Ocampo')
# (1, 'Marjorie', 'Tucker')
# (1, 'Marlene', 'Welch')
# (1, 'Marshall', 'Thorn')
# (1, 'Martha', 'Gonzalez')
# (1, 'Martin', 'Bales')
# (1, 'Mary', 'Smith')
# (1, 'Mathew', 'Bolin')
# (1, 'Maurice', 'Crawley')
# (1, 'Max', 'Pitt')
# (1, 'Melanie', 'Armstrong')
# (1, 'Melinda', 'Fernandez')
# (1, 'Melissa', 'King')
# (1, 'Melvin', 'Ellington')
# (1, 'Michael', 'Silverman')
# (1, 'Micheal', 'Forman')
# (1, 'Michelle', 'Clark')
# (1, 'Miguel', 'Betancourt')
# (1, 'Mike', 'Way')
# (1, 'Mildred', 'Bailey')
# (1, 'Miriam', 'Mckinney')
# (1, 'Myrtle', 'Fleming')
# (1, 'Nancy', 'Thomas')
# (1, 'Naomi', 'Jennings')
# (1, 'Natalie', 'Meyer')
# (1, 'Nathan', 'Runyon')
# (1, 'Nathaniel', 'Adam')
# (1, 'Nellie', 'Garrett')
# (1, 'Nelson', 'Christenson')
# (1, 'Nicholas', 'Barfield')
# (1, 'Nicole', 'Peterson')
# (1, 'Nina', 'Soto')
# (1, 'Norma', 'Gonzales')
# (1, 'Norman', 'Currier')
# (1, 'Pamela', 'Baker')
# (1, 'Patricia', 'Johnson')
# (1, 'Patrick', 'Newsom')
# (1, 'Pauline', 'Henry')
# (1, 'Peggy', 'Myers')
# (1, 'Penny', 'Neal')
# (1, 'Perry', 'Swafford')
# (1, 'Peter', 'Menard')
# (1, 'Philip', 'Causey')
# (1, 'Phillip', 'Holm')
# (1, 'Phyllis', 'Foster')
# (1, 'Rachel', 'Barnes')
# (1, 'Rafael', 'Abney')
# (1, 'Randy', 'Gaither')
# (1, 'Raul', 'Fortier')
# (1, 'Ray', 'Houle')
# (1, 'Regina', 'Berry')
# (1, 'Reginald', 'Kinder')
# (1, 'Renee', 'Lane')
# (1, 'Ricardo', 'Meador')
# (1, 'Richard', 'Mccrary')
# (1, 'Rita', 'Graham')
# (1, 'Roberta', 'Harper')
# (1, 'Roberto', 'Vu')
# (1, 'Robin', 'Hayes')
# (1, 'Rosemary', 'Schmidt')
# (1, 'Ross', 'Grey')
# (1, 'Ruben', 'Geary')
# (1, 'Russell', 'Brinson')
# (1, 'Ruth', 'Martinez')
# (1, 'Sam', 'Mcduffie')
# (1, 'Scott', 'Shelley')
# (1, 'Sergio', 'Stanfield')
# (1, 'Shawn', 'Heaton')
# (1, 'Sheila', 'Wells')
# (1, 'Sherri', 'Rhodes')
# (1, 'Sherry', 'Marshall')
# (1, 'Sidney', 'Burleson')
# (1, 'Sonia', 'Gregory')
# (1, 'Stacey', 'Montgomery')
# (1, 'Stella', 'Moreno')
# (1, 'Stephanie', 'Mitchell')
# (1, 'Stephen', 'Qualls')
# (1, 'Steven', 'Curley')
# (1, 'Tamara', 'Nguyen')
# (1, 'Tanya', 'Gilbert')
# (1, 'Tara', 'Ryan')
# (1, 'Teresa', 'Rogers')
# (1, 'Terrance', 'Roush')
# (1, 'Terrence', 'Gunderson')
# (1, 'Terri', 'Vasquez')
# (1, 'Terry', 'Carlson')
# (1, 'Thelma', 'Murray')
# (1, 'Thomas', 'Grigsby')
# (1, 'Tim', 'Cary')
# (1, 'Timothy', 'Bunn')
# (1, 'Todd', 'Tan')
# (1, 'Tom', 'Milner')
# (1, 'Tommy', 'Collazo')
# (1, 'Toni', 'Holt')
# (1, 'Tracy', 'Cole')
# (1, 'Tracy', 'Herrmann')
# (1, 'Travis', 'Estep')
# (1, 'Troy', 'Quigley')
# (1, 'Tyrone', 'Asher')
# (1, 'Valerie', 'Black')
# (1, 'Vanessa', 'Sims')
# (1, 'Velma', 'Lucas')
# (1, 'Vera', 'Mccoy')
# (1, 'Veronica', 'Stone')
# (1, 'Vicki', 'Fields')
# (1, 'Victoria', 'Gibson')
# (1, 'Vincent', 'Ralston')
# (1, 'Violet', 'Rodriquez')
# (1, 'Virgil', 'Wofford')
# (1, 'Vivian', 'Ruiz')
# (1, 'Wade', 'Delvalle')
# (1, 'Wallace', 'Slone')
# (1, 'Wanda', 'Patterson')
# (1, 'Wendy', 'Harrison')
# (1, 'Zachary', 'Hite')

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ['store_id', 'first_name', 'last_name']

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#    store_id first_name last_name
# 0         2      Aaron     Selby
# 1         2     Adrian     Clary
# 2         2      Agnes    Bishop
# 3         2    Alberto   Henning
# 4         2       Alex   Gresham

# %% [markdown]
# #### LIMIT clause

# %%
# Limit the number of rows (results) returned from query
# What are the first names and last names of the first 10 actors?
select_records = """
SELECT first_name, last_name
FROM actor
LIMIT 10;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# ('Penelope', 'Guiness')
# ('Nick', 'Wahlberg')
# ('Ed', 'Chase')
# ('Jennifer', 'Davis')
# ('Johnny', 'Lollobrigida')
# ('Bette', 'Nicholson')
# ('Grace', 'Mostel')
# ('Matthew', 'Johansson')
# ('Joe', 'Swank')
# ('Christian', 'Gable')

# %% [markdown]
# #### BETWEEN operator

# %%
# Match value against range of values
# Number of payments that were done between 8.00 and 9.00 dollars
select_records = """
SELECT COUNT (amount)
FROM payment
WHERE amount NOT BETWEEN 8.00 AND 9.00;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (14157,)

# %% [markdown]
# #### IN operator

# %%
# Check if value matches any value in list of multiple options
# How many customers are with first name 'John', 'Jake', 'Julie'?
select_records = """
SELECT *
FROM customer
WHERE first_name IN ('John', 'Jake', 'Julie');
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (52, 1, 'Julie', 'Sanchez', 'julie.sanchez@sakilacustomer.org', 56, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (300, 1, 'John', 'Farnsworth', 'john.farnsworth@sakilacustomer.org', 305, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["customer_id", "store_id", "first_name", "last_name", "email", "address_id", "activebool", "create_date", "last_update", "active"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#    customer_id  store_id first_name   last_name  \
# 0           52         1      Julie     Sanchez
# 1          300         1       John  Farnsworth
#
#                                 email  address_id  activebool create_date  \
# 0    julie.sanchez@sakilacustomer.org          56        True  2006-02-14
# 1  john.farnsworth@sakilacustomer.org         305        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1
# 1 2013-05-26 14:49:45.738       1

# %% [markdown]
# #### LIKE operator

# %%
# Query data using pattern matchings against string using wildcard characters (% and _)
# How many people have a first name that starts with 'J' and last name that starts with 'S'?
select_records = """
SELECT *
FROM customer
WHERE first_name LIKE 'J%' AND last_name LIKE 'S%';
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (52, 1, 'Julie', 'Sanchez', 'julie.sanchez@sakilacustomer.org', 56, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (328, 2, 'Jeffrey', 'Spear', 'jeffrey.spear@sakilacustomer.org', 333, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (353, 1, 'Jonathan', 'Scarborough', 'jonathan.scarborough@sakilacustomer.org', 358, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (387, 2, 'Jesse', 'Schilling', 'jesse.schilling@sakilacustomer.org', 392, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)
# (397, 1, 'Jimmy', 'Schrader', 'jimmy.schrader@sakilacustomer.org', 402, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["customer_id", "store_id", "first_name", "last_name", "email", "address_id", "activebool", "create_date", "last_update", "active"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#    customer_id  store_id first_name    last_name  \
# 0           52         1      Julie      Sanchez
# 1          328         2    Jeffrey        Spear
# 2          353         1   Jonathan  Scarborough
# 3          387         2      Jesse    Schilling
# 4          397         1      Jimmy     Schrader
#
#                                      email  address_id  activebool  \
# 0         julie.sanchez@sakilacustomer.org          56        True
# 1         jeffrey.spear@sakilacustomer.org         333        True
# 2  jonathan.scarborough@sakilacustomer.org         358        True
# 3       jesse.schilling@sakilacustomer.org         392        True
# 4        jimmy.schrader@sakilacustomer.org         402        True
#
#   create_date             last_update  active
# 0  2006-02-14 2013-05-26 14:49:45.738       1
# 1  2006-02-14 2013-05-26 14:49:45.738       1
# 2  2006-02-14 2013-05-26 14:49:45.738       1
# 3  2006-02-14 2013-05-26 14:49:45.738       1
# 4  2006-02-14 2013-05-26 14:49:45.738       1

# %% [markdown]
# #### GROUP BY clause

# %%
# Gather all rows in specified column(s), divide rows into groups and apply Aggregate Function on one or more columns
# What customer is spending a most money?
select_records = """
SELECT customer_id, SUM (amount)
FROM payment
GROUP BY customer_id
ORDER BY SUM (amount) DESC;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (148, Decimal('211.55'))
# (526, Decimal('208.58'))
# (178, Decimal('194.61'))
# (137, Decimal('191.62'))
# (144, Decimal('189.60'))
# (459, Decimal('183.63'))
# (181, Decimal('167.67'))
# (410, Decimal('167.62'))
# (236, Decimal('166.61'))
# (403, Decimal('162.67'))
# (522, Decimal('161.68'))
# (469, Decimal('158.65'))
# (470, Decimal('157.69'))
# (373, Decimal('156.66'))
# (259, Decimal('154.70'))
# (468, Decimal('154.66'))
# (462, Decimal('152.69'))
# (372, Decimal('152.68'))
# (187, Decimal('151.73'))
# (550, Decimal('151.69'))
# (176, Decimal('151.68'))
# (532, Decimal('149.69'))
# (75, Decimal('149.61'))
# (209, Decimal('147.71'))
# (86, Decimal('146.68'))
# (26, Decimal('146.68'))
# (21, Decimal('146.68'))
# (211, Decimal('146.67'))
# (346, Decimal('145.70'))
# (366, Decimal('145.64'))
# (50, Decimal('144.70'))
# (360, Decimal('144.68'))
# (348, Decimal('144.66'))
# (513, Decimal('143.70'))
# (454, Decimal('143.68'))
# (347, Decimal('142.70'))
# (390, Decimal('142.69'))
# (267, Decimal('142.67'))
# (257, Decimal('142.66'))
# (39, Decimal('141.71'))
# (78, Decimal('141.69'))
# (362, Decimal('140.69'))
# (363, Decimal('139.72'))
# (368, Decimal('139.69'))
# (119, Decimal('139.69'))
# (66, Decimal('139.67'))
# (237, Decimal('138.69'))
# (29, Decimal('138.65'))
# (87, Decimal('137.72'))
# (80, Decimal('137.70'))
# (439, Decimal('137.67'))
# (558, Decimal('135.72'))
# (494, Decimal('135.70'))
# (576, Decimal('135.68'))
# (591, Decimal('134.73'))
# (467, Decimal('134.72'))
# (479, Decimal('134.71'))
# (210, Decimal('134.70'))
# (120, Decimal('134.70'))
# (204, Decimal('134.69'))
# (15, Decimal('134.68'))
# (5, Decimal('134.65'))
# (349, Decimal('133.72'))
# (404, Decimal('133.71'))
# (172, Decimal('133.70'))
# (197, Decimal('133.68'))
# (265, Decimal('132.72'))
# (533, Decimal('132.70'))
# (380, Decimal('132.65'))
# (472, Decimal('131.74'))
# (13, Decimal('131.73'))
# (46, Decimal('131.69'))
# (125, Decimal('131.69'))
# (3, Decimal('130.76'))
# (273, Decimal('130.72'))
# (7, Decimal('130.72'))
# (502, Decimal('130.70'))
# (566, Decimal('130.68'))
# (342, Decimal('130.68'))
# (112, Decimal('129.72'))
# (560, Decimal('129.71'))
# (102, Decimal('129.70'))
# (168, Decimal('129.68'))
# (484, Decimal('128.73'))
# (103, Decimal('128.71'))
# (242, Decimal('128.71'))
# (84, Decimal('128.70'))
# (196, Decimal('128.69'))
# (448, Decimal('127.73'))
# (221, Decimal('127.73'))
# (520, Decimal('127.69'))
# (141, Decimal('127.69'))
# (38, Decimal('127.66'))
# (200, Decimal('126.74'))
# (206, Decimal('126.73'))
# (146, Decimal('126.73'))
# (436, Decimal('126.73'))
# (108, Decimal('126.72'))
# (114, Decimal('126.70'))
# (426, Decimal('125.74'))
# (482, Decimal('125.74'))
# (295, Decimal('125.72'))
# (147, Decimal('125.68'))
# (354, Decimal('125.67'))
# (45, Decimal('124.74'))
# (89, Decimal('124.71'))
# (198, Decimal('124.68'))
# (129, Decimal('124.66'))
# (2, Decimal('123.74'))
# (300, Decimal('123.74'))
# (506, Decimal('123.72'))
# (371, Decimal('123.71'))
# (51, Decimal('123.70'))
# (27, Decimal('123.70'))
# (30, Decimal('123.66'))
# (434, Decimal('122.74'))
# (92, Decimal('122.74'))
# (535, Decimal('122.72'))
# (163, Decimal('122.71'))
# (244, Decimal('122.70'))
# (473, Decimal('122.69'))
# (508, Decimal('121.77'))
# (166, Decimal('121.73'))
# (497, Decimal('121.73'))
# (451, Decimal('121.70'))
# (438, Decimal('121.70'))
# (406, Decimal('121.69'))
# (491, Decimal('120.75'))
# (423, Decimal('120.74'))
# (179, Decimal('120.74'))
# (499, Decimal('120.71'))
# (122, Decimal('120.70'))
# (59, Decimal('119.76'))
# (389, Decimal('119.75'))
# (487, Decimal('119.74'))
# (306, Decimal('119.72'))
# (207, Decimal('119.72'))
# (82, Decimal('118.76'))
# (41, Decimal('118.75'))
# (589, Decimal('118.75'))
# (565, Decimal('118.73'))
# (128, Decimal('118.70'))
# (35, Decimal('118.70'))
# (230, Decimal('118.69'))
# (583, Decimal('117.77'))
# (285, Decimal('117.77'))
# (585, Decimal('117.76'))
# (504, Decimal('117.75'))
# (421, Decimal('117.75'))
# (573, Decimal('117.72'))
# (49, Decimal('116.76'))
# (149, Decimal('116.75'))
# (253, Decimal('116.74'))
# (274, Decimal('116.73'))
# (263, Decimal('116.73'))
# (71, Decimal('116.72'))
# (356, Decimal('116.71'))
# (512, Decimal('115.74'))
# (56, Decimal('115.74'))
# (529, Decimal('115.72'))
# (393, Decimal('115.71'))
# (158, Decimal('115.70'))
# (279, Decimal('114.76'))
# (54, Decimal('114.74'))
# (584, Decimal('114.73'))
# (262, Decimal('114.73'))
# (107, Decimal('114.72'))
# (388, Decimal('114.72'))
# (1, Decimal('114.70'))
# (433, Decimal('113.77'))
# (309, Decimal('113.75'))
# (266, Decimal('113.74'))
# (302, Decimal('113.74'))
# (139, Decimal('113.73'))
# (569, Decimal('113.73'))
# (416, Decimal('113.72'))
# (314, Decimal('113.71'))
# (260, Decimal('113.70'))
# (540, Decimal('112.76'))
# (582, Decimal('112.76'))
# (63, Decimal('112.75'))
# (32, Decimal('112.74'))
# (131, Decimal('112.73'))
# (485, Decimal('112.72'))
# (453, Decimal('111.77'))
# (337, Decimal('111.76'))
# (225, Decimal('111.76'))
# (577, Decimal('111.74'))
# (173, Decimal('111.73'))
# (579, Decimal('111.73'))
# (113, Decimal('111.73'))
# (186, Decimal('111.71'))
# (592, Decimal('111.71'))
# (42, Decimal('111.71'))
# (531, Decimal('110.77'))
# (258, Decimal('110.76'))
# (495, Decimal('110.76'))
# (515, Decimal('110.74'))
# (154, Decimal('110.73'))
# (213, Decimal('110.73'))
# (559, Decimal('110.72'))
# (90, Decimal('110.72'))
# (595, Decimal('110.71'))
# (241, Decimal('110.68'))
# (170, Decimal('109.77'))
# (536, Decimal('109.77'))
# (575, Decimal('109.76'))
# (220, Decimal('109.75'))
# (16, Decimal('109.75'))
# (538, Decimal('109.73'))
# (376, Decimal('109.73'))
# (447, Decimal('109.73'))
# (386, Decimal('109.72'))
# (446, Decimal('109.72'))
# (481, Decimal('109.72'))
# (424, Decimal('109.71'))
# (284, Decimal('108.78'))
# (594, Decimal('108.77'))
# (590, Decimal('108.76'))
# (277, Decimal('108.76'))
# (518, Decimal('108.75'))
# (334, Decimal('108.75'))
# (574, Decimal('108.73'))
# (239, Decimal('108.72'))
# (167, Decimal('108.71'))
# (293, Decimal('107.79'))
# (571, Decimal('107.78'))
# (427, Decimal('107.77'))
# (332, Decimal('107.74'))
# (441, Decimal('107.73'))
# (145, Decimal('107.73'))
# (588, Decimal('107.73'))
# (157, Decimal('107.71'))
# (254, Decimal('107.70'))
# (418, Decimal('107.70'))
# (91, Decimal('107.66'))
# (477, Decimal('106.79'))
# (343, Decimal('106.77'))
# (240, Decimal('106.77'))
# (155, Decimal('106.76'))
# (234, Decimal('106.75'))
# (471, Decimal('106.74'))
# (116, Decimal('106.74'))
# (23, Decimal('106.73'))
# (457, Decimal('106.73'))
# (160, Decimal('106.73'))
# (52, Decimal('106.72'))
# (138, Decimal('106.68'))
# (127, Decimal('105.78'))
# (490, Decimal('105.78'))
# (331, Decimal('105.78'))
# (193, Decimal('105.77'))
# (294, Decimal('105.77'))
# (58, Decimal('105.76'))
# (400, Decimal('105.76'))
# (396, Decimal('105.74'))
# (40, Decimal('105.74'))
# (96, Decimal('105.73'))
# (444, Decimal('105.72'))
# (28, Decimal('105.70'))
# (345, Decimal('104.79'))
# (493, Decimal('104.78'))
# (289, Decimal('104.76'))
# (121, Decimal('104.75'))
# (171, Decimal('104.75'))
# (407, Decimal('104.74'))
# (31, Decimal('104.74'))
# (25, Decimal('104.73'))
# (397, Decimal('104.72'))
# (442, Decimal('104.71'))
# (341, Decimal('103.78'))
# (296, Decimal('103.77'))
# (280, Decimal('103.77'))
# (214, Decimal('103.74'))
# (202, Decimal('103.74'))
# (245, Decimal('103.74'))
# (20, Decimal('103.73'))
# (408, Decimal('103.73'))
# (292, Decimal('102.78'))
# (553, Decimal('102.77'))
# (510, Decimal('102.77'))
# (587, Decimal('102.76'))
# (98, Decimal('102.76'))
# (126, Decimal('102.75'))
# (190, Decimal('102.75'))
# (44, Decimal('101.79'))
# (466, Decimal('101.78'))
# (100, Decimal('101.77'))
# (593, Decimal('101.76'))
# (405, Decimal('101.70'))
# (486, Decimal('100.77'))
# (517, Decimal('100.76'))
# (572, Decimal('100.76'))
# (219, Decimal('100.75'))
# (251, Decimal('100.75'))
# (135, Decimal('100.72'))
# (519, Decimal('99.78'))
# (11, Decimal('99.77'))
# (57, Decimal('99.74'))
# (297, Decimal('99.74'))
# (563, Decimal('99.73'))
# (503, Decimal('99.72'))
# (452, Decimal('99.71'))
# (381, Decimal('99.68'))
# (19, Decimal('98.82'))
# (329, Decimal('98.77'))
# (537, Decimal('98.76'))
# (175, Decimal('98.76'))
# (264, Decimal('98.75'))
# (425, Decimal('98.75'))
# (374, Decimal('98.75'))
# (580, Decimal('98.74'))
# (65, Decimal('97.80'))
# (367, Decimal('97.80'))
# (460, Decimal('97.79'))
# (409, Decimal('97.78'))
# (192, Decimal('97.78'))
# (475, Decimal('97.78'))
# (562, Decimal('97.78'))
# (123, Decimal('97.77'))
# (256, Decimal('97.75'))
# (581, Decimal('97.75'))
# (268, Decimal('96.79'))
# (379, Decimal('96.79'))
# (269, Decimal('96.79'))
# (352, Decimal('96.78'))
# (83, Decimal('96.78'))
# (14, Decimal('96.77'))
# (414, Decimal('96.77'))
# (286, Decimal('96.76'))
# (445, Decimal('96.76'))
# (317, Decimal('96.76'))
# (500, Decimal('96.75'))
# (422, Decimal('96.75'))
# (74, Decimal('96.74'))
# (554, Decimal('95.80'))
# (578, Decimal('95.79'))
# (106, Decimal('95.79'))
# (180, Decimal('95.78'))
# (324, Decimal('95.78'))
# (541, Decimal('95.78'))
# (488, Decimal('95.78'))
# (339, Decimal('95.76'))
# (199, Decimal('95.76'))
# (456, Decimal('95.76'))
# (132, Decimal('95.72'))
# (22, Decimal('94.81'))
# (150, Decimal('94.78'))
# (68, Decimal('94.78'))
# (276, Decimal('94.77'))
# (161, Decimal('94.76'))
# (546, Decimal('94.76'))
# (153, Decimal('94.76'))
# (10, Decimal('94.76'))
# (111, Decimal('94.75'))
# (321, Decimal('93.83'))
# (432, Decimal('93.80'))
# (528, Decimal('93.80'))
# (319, Decimal('93.79'))
# (443, Decimal('93.79'))
# (105, Decimal('93.78'))
# (336, Decimal('93.78'))
# (385, Decimal('93.76'))
# (383, Decimal('93.75'))
# (229, Decimal('93.75'))
# (377, Decimal('93.74'))
# (12, Decimal('93.74'))
# (47, Decimal('92.81'))
# (307, Decimal('92.80'))
# (544, Decimal('92.80'))
# (81, Decimal('92.79'))
# (365, Decimal('92.79'))
# (511, Decimal('92.78'))
# (431, Decimal('92.78'))
# (516, Decimal('92.76'))
# (182, Decimal('92.76'))
# (474, Decimal('92.75'))
# (188, Decimal('92.75'))
# (275, Decimal('92.75'))
# (505, Decimal('91.81'))
# (489, Decimal('91.81'))
# (212, Decimal('91.80'))
# (37, Decimal('91.79'))
# (201, Decimal('91.78'))
# (417, Decimal('91.78'))
# (392, Decimal('91.77'))
# (323, Decimal('91.75'))
# (570, Decimal('91.75'))
# (64, Decimal('91.70'))
# (261, Decimal('90.78'))
# (216, Decimal('90.78'))
# (99, Decimal('90.77'))
# (36, Decimal('90.75'))
# (461, Decimal('90.73'))
# (552, Decimal('89.80'))
# (43, Decimal('89.78'))
# (364, Decimal('89.78'))
# (333, Decimal('89.78'))
# (73, Decimal('89.78'))
# (235, Decimal('89.77'))
# (233, Decimal('89.77'))
# (507, Decimal('89.77'))
# (156, Decimal('89.77'))
# (69, Decimal('89.77'))
# (463, Decimal('89.76'))
# (34, Decimal('89.76'))
# (361, Decimal('89.71'))
# (247, Decimal('88.81'))
# (249, Decimal('88.81'))
# (33, Decimal('88.80'))
# (375, Decimal('88.80'))
# (415, Decimal('88.78'))
# (60, Decimal('88.78'))
# (231, Decimal('88.77'))
# (53, Decimal('88.76'))
# (133, Decimal('88.75'))
# (72, Decimal('88.73'))
# (17, Decimal('87.82'))
# (203, Decimal('87.81'))
# (523, Decimal('87.80'))
# (305, Decimal('87.80'))
# (476, Decimal('87.80'))
# (547, Decimal('87.80'))
# (226, Decimal('87.79'))
# (189, Decimal('87.79'))
# (130, Decimal('87.78'))
# (597, Decimal('87.77'))
# (351, Decimal('87.77'))
# (509, Decimal('86.82'))
# (478, Decimal('86.81'))
# (501, Decimal('86.81'))
# (238, Decimal('86.81'))
# (195, Decimal('86.81'))
# (67, Decimal('86.80'))
# (169, Decimal('86.80'))
# (217, Decimal('86.79'))
# (232, Decimal('86.77'))
# (101, Decimal('86.77'))
# (419, Decimal('86.76'))
# (228, Decimal('86.75'))
# (561, Decimal('86.75'))
# (208, Decimal('86.75'))
# (115, Decimal('86.73'))
# (567, Decimal('85.80'))
# (437, Decimal('85.80'))
# (382, Decimal('85.78'))
# (359, Decimal('85.78'))
# (455, Decimal('85.78'))
# (24, Decimal('85.77'))
# (8, Decimal('85.77'))
# (77, Decimal('85.77'))
# (450, Decimal('85.75'))
# (542, Decimal('84.84'))
# (55, Decimal('84.81'))
# (545, Decimal('84.81'))
# (539, Decimal('84.80'))
# (88, Decimal('84.80'))
# (299, Decimal('84.79'))
# (6, Decimal('84.75'))
# (140, Decimal('83.82'))
# (480, Decimal('83.81'))
# (143, Decimal('83.80'))
# (440, Decimal('83.79'))
# (598, Decimal('83.78'))
# (340, Decimal('83.77'))
# (496, Decimal('82.81'))
# (564, Decimal('82.78'))
# (498, Decimal('82.76'))
# (524, Decimal('81.83'))
# (483, Decimal('81.83'))
# (322, Decimal('81.81'))
# (308, Decimal('81.81'))
# (174, Decimal('81.81'))
# (165, Decimal('81.80'))
# (312, Decimal('81.80'))
# (4, Decimal('81.78'))
# (534, Decimal('81.78'))
# (527, Decimal('81.76'))
# (215, Decimal('81.76'))
# (151, Decimal('81.75'))
# (311, Decimal('80.85'))
# (449, Decimal('80.83'))
# (205, Decimal('80.82'))
# (316, Decimal('80.81'))
# (184, Decimal('80.80'))
# (287, Decimal('80.78'))
# (290, Decimal('80.78'))
# (521, Decimal('80.77'))
# (357, Decimal('80.77'))
# (304, Decimal('79.81'))
# (109, Decimal('79.81'))
# (282, Decimal('79.80'))
# (185, Decimal('79.80'))
# (387, Decimal('79.78'))
# (391, Decimal('79.75'))
# (429, Decimal('78.84'))
# (599, Decimal('78.82'))
# (18, Decimal('78.81'))
# (338, Decimal('78.80'))
# (9, Decimal('78.80'))
# (298, Decimal('78.79'))
# (62, Decimal('78.79'))
# (227, Decimal('78.78'))
# (435, Decimal('78.77'))
# (223, Decimal('77.84'))
# (402, Decimal('77.81'))
# (134, Decimal('77.81'))
# (394, Decimal('77.80'))
# (384, Decimal('77.79'))
# (104, Decimal('77.78'))
# (243, Decimal('77.77'))
# (246, Decimal('76.82'))
# (93, Decimal('76.80'))
# (118, Decimal('76.80'))
# (224, Decimal('76.78'))
# (70, Decimal('75.83'))
# (270, Decimal('75.81'))
# (358, Decimal('75.80'))
# (551, Decimal('75.79'))
# (183, Decimal('75.78'))
# (530, Decimal('75.78'))
# (194, Decimal('74.84'))
# (412, Decimal('74.83'))
# (555, Decimal('74.83'))
# (327, Decimal('74.81'))
# (420, Decimal('74.80'))
# (76, Decimal('74.79'))
# (142, Decimal('74.77'))
# (398, Decimal('73.85'))
# (291, Decimal('73.83'))
# (399, Decimal('73.82'))
# (152, Decimal('73.81'))
# (79, Decimal('73.81'))
# (428, Decimal('73.81'))
# (543, Decimal('73.80'))
# (596, Decimal('73.78'))
# (335, Decimal('73.78'))
# (411, Decimal('73.76'))
# (95, Decimal('72.83'))
# (556, Decimal('72.82'))
# (325, Decimal('72.82'))
# (85, Decimal('72.79'))
# (301, Decimal('71.85'))
# (222, Decimal('71.84'))
# (94, Decimal('71.81'))
# (430, Decimal('71.80'))
# (278, Decimal('71.79'))
# (177, Decimal('71.77'))
# (255, Decimal('70.82'))
# (378, Decimal('70.82'))
# (370, Decimal('70.81'))
# (303, Decimal('70.81'))
# (117, Decimal('69.83'))
# (369, Decimal('69.79'))
# (514, Decimal('69.79'))
# (310, Decimal('68.87'))
# (465, Decimal('68.84'))
# (525, Decimal('68.82'))
# (355, Decimal('68.81'))
# (283, Decimal('68.77'))
# (48, Decimal('67.86'))
# (464, Decimal('67.86'))
# (315, Decimal('67.86'))
# (218, Decimal('67.82'))
# (191, Decimal('66.82'))
# (458, Decimal('66.81'))
# (568, Decimal('66.79'))
# (272, Decimal('65.87'))
# (353, Decimal('65.83'))
# (328, Decimal('65.83'))
# (413, Decimal('65.81'))
# (164, Decimal('64.85'))
# (344, Decimal('64.84'))
# (326, Decimal('64.82'))
# (313, Decimal('63.84'))
# (548, Decimal('63.84'))
# (350, Decimal('63.79'))
# (557, Decimal('63.78'))
# (492, Decimal('62.85'))
# (549, Decimal('62.84'))
# (401, Decimal('62.81'))
# (330, Decimal('60.82'))
# (136, Decimal('59.86'))
# (162, Decimal('59.83'))
# (159, Decimal('58.83'))
# (97, Decimal('58.82'))
# (252, Decimal('58.80'))
# (61, Decimal('57.87'))
# (124, Decimal('57.86'))
# (395, Decimal('57.81'))
# (271, Decimal('56.84'))
# (250, Decimal('54.85'))
# (288, Decimal('52.81'))
# (586, Decimal('50.83'))
# (110, Decimal('49.88'))
# (320, Decimal('47.85'))
# (248, Decimal('37.87'))
# (281, Decimal('32.90'))
# (318, Decimal('27.93'))

# %% [markdown]
# #### HAVING clause

# %%
# Specify search condition for groups of results or aggregated results
# What are the total sum amounts per customer id with amount greater than 100?
select_records = """
SELECT customer_id, SUM (amount)
FROM payment
GROUP BY customer_id
HAVING SUM (amount) > 100
ORDER BY SUM (amount) DESC;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (148, Decimal('211.55'))
# (526, Decimal('208.58'))
# (178, Decimal('194.61'))
# (137, Decimal('191.62'))
# (144, Decimal('189.60'))
# (459, Decimal('183.63'))
# (181, Decimal('167.67'))
# (410, Decimal('167.62'))
# (236, Decimal('166.61'))
# (403, Decimal('162.67'))
# (522, Decimal('161.68'))
# (469, Decimal('158.65'))
# (470, Decimal('157.69'))
# (373, Decimal('156.66'))
# (259, Decimal('154.70'))
# (468, Decimal('154.66'))
# (462, Decimal('152.69'))
# (372, Decimal('152.68'))
# (187, Decimal('151.73'))
# (550, Decimal('151.69'))
# (176, Decimal('151.68'))
# (532, Decimal('149.69'))
# (75, Decimal('149.61'))
# (209, Decimal('147.71'))
# (26, Decimal('146.68'))
# (21, Decimal('146.68'))
# (86, Decimal('146.68'))
# (211, Decimal('146.67'))
# (346, Decimal('145.70'))
# (366, Decimal('145.64'))
# (50, Decimal('144.70'))
# (360, Decimal('144.68'))
# (348, Decimal('144.66'))
# (513, Decimal('143.70'))
# (454, Decimal('143.68'))
# (347, Decimal('142.70'))
# (390, Decimal('142.69'))
# (267, Decimal('142.67'))
# (257, Decimal('142.66'))
# (39, Decimal('141.71'))
# (78, Decimal('141.69'))
# (362, Decimal('140.69'))
# (363, Decimal('139.72'))
# (368, Decimal('139.69'))
# (119, Decimal('139.69'))
# (66, Decimal('139.67'))
# (237, Decimal('138.69'))
# (29, Decimal('138.65'))
# (87, Decimal('137.72'))
# (80, Decimal('137.70'))
# (439, Decimal('137.67'))
# (558, Decimal('135.72'))
# (494, Decimal('135.70'))
# (576, Decimal('135.68'))
# (591, Decimal('134.73'))
# (467, Decimal('134.72'))
# (479, Decimal('134.71'))
# (210, Decimal('134.70'))
# (120, Decimal('134.70'))
# (204, Decimal('134.69'))
# (15, Decimal('134.68'))
# (5, Decimal('134.65'))
# (349, Decimal('133.72'))
# (404, Decimal('133.71'))
# (172, Decimal('133.70'))
# (197, Decimal('133.68'))
# (265, Decimal('132.72'))
# (533, Decimal('132.70'))
# (380, Decimal('132.65'))
# (472, Decimal('131.74'))
# (13, Decimal('131.73'))
# (125, Decimal('131.69'))
# (46, Decimal('131.69'))
# (3, Decimal('130.76'))
# (273, Decimal('130.72'))
# (7, Decimal('130.72'))
# (502, Decimal('130.70'))
# (342, Decimal('130.68'))
# (566, Decimal('130.68'))
# (112, Decimal('129.72'))
# (560, Decimal('129.71'))
# (102, Decimal('129.70'))
# (168, Decimal('129.68'))
# (484, Decimal('128.73'))
# (242, Decimal('128.71'))
# (103, Decimal('128.71'))
# (84, Decimal('128.70'))
# (196, Decimal('128.69'))
# (448, Decimal('127.73'))
# (221, Decimal('127.73'))
# (141, Decimal('127.69'))
# (520, Decimal('127.69'))
# (38, Decimal('127.66'))
# (200, Decimal('126.74'))
# (146, Decimal('126.73'))
# (436, Decimal('126.73'))
# (206, Decimal('126.73'))
# (108, Decimal('126.72'))
# (114, Decimal('126.70'))
# (426, Decimal('125.74'))
# (482, Decimal('125.74'))
# (295, Decimal('125.72'))
# (147, Decimal('125.68'))
# (354, Decimal('125.67'))
# (45, Decimal('124.74'))
# (89, Decimal('124.71'))
# (198, Decimal('124.68'))
# (129, Decimal('124.66'))
# (300, Decimal('123.74'))
# (2, Decimal('123.74'))
# (506, Decimal('123.72'))
# (371, Decimal('123.71'))
# (51, Decimal('123.70'))
# (27, Decimal('123.70'))
# (30, Decimal('123.66'))
# (434, Decimal('122.74'))
# (92, Decimal('122.74'))
# (535, Decimal('122.72'))
# (163, Decimal('122.71'))
# (244, Decimal('122.70'))
# (473, Decimal('122.69'))
# (508, Decimal('121.77'))
# (166, Decimal('121.73'))
# (497, Decimal('121.73'))
# (438, Decimal('121.70'))
# (451, Decimal('121.70'))
# (406, Decimal('121.69'))
# (491, Decimal('120.75'))
# (179, Decimal('120.74'))
# (423, Decimal('120.74'))
# (499, Decimal('120.71'))
# (122, Decimal('120.70'))
# (59, Decimal('119.76'))
# (389, Decimal('119.75'))
# (487, Decimal('119.74'))
# (207, Decimal('119.72'))
# (306, Decimal('119.72'))
# (82, Decimal('118.76'))
# (41, Decimal('118.75'))
# (589, Decimal('118.75'))
# (565, Decimal('118.73'))
# (35, Decimal('118.70'))
# (128, Decimal('118.70'))
# (230, Decimal('118.69'))
# (285, Decimal('117.77'))
# (583, Decimal('117.77'))
# (585, Decimal('117.76'))
# (504, Decimal('117.75'))
# (421, Decimal('117.75'))
# (573, Decimal('117.72'))
# (49, Decimal('116.76'))
# (149, Decimal('116.75'))
# (253, Decimal('116.74'))
# (263, Decimal('116.73'))
# (274, Decimal('116.73'))
# (71, Decimal('116.72'))
# (356, Decimal('116.71'))
# (512, Decimal('115.74'))
# (56, Decimal('115.74'))
# (529, Decimal('115.72'))
# (393, Decimal('115.71'))
# (158, Decimal('115.70'))
# (279, Decimal('114.76'))
# (54, Decimal('114.74'))
# (584, Decimal('114.73'))
# (262, Decimal('114.73'))
# (107, Decimal('114.72'))
# (388, Decimal('114.72'))
# (1, Decimal('114.70'))
# (433, Decimal('113.77'))
# (309, Decimal('113.75'))
# (302, Decimal('113.74'))
# (266, Decimal('113.74'))
# (569, Decimal('113.73'))
# (139, Decimal('113.73'))
# (416, Decimal('113.72'))
# (314, Decimal('113.71'))
# (260, Decimal('113.70'))
# (540, Decimal('112.76'))
# (582, Decimal('112.76'))
# (63, Decimal('112.75'))
# (32, Decimal('112.74'))
# (131, Decimal('112.73'))
# (485, Decimal('112.72'))
# (453, Decimal('111.77'))
# (225, Decimal('111.76'))
# (337, Decimal('111.76'))
# (577, Decimal('111.74'))
# (579, Decimal('111.73'))
# (113, Decimal('111.73'))
# (173, Decimal('111.73'))
# (186, Decimal('111.71'))
# (592, Decimal('111.71'))
# (42, Decimal('111.71'))
# (531, Decimal('110.77'))
# (258, Decimal('110.76'))
# (495, Decimal('110.76'))
# (515, Decimal('110.74'))
# (213, Decimal('110.73'))
# (154, Decimal('110.73'))
# (90, Decimal('110.72'))
# (559, Decimal('110.72'))
# (595, Decimal('110.71'))
# (241, Decimal('110.68'))
# (170, Decimal('109.77'))
# (536, Decimal('109.77'))
# (575, Decimal('109.76'))
# (16, Decimal('109.75'))
# (220, Decimal('109.75'))
# (447, Decimal('109.73'))
# (376, Decimal('109.73'))
# (538, Decimal('109.73'))
# (446, Decimal('109.72'))
# (386, Decimal('109.72'))
# (481, Decimal('109.72'))
# (424, Decimal('109.71'))
# (284, Decimal('108.78'))
# (594, Decimal('108.77'))
# (590, Decimal('108.76'))
# (277, Decimal('108.76'))
# (334, Decimal('108.75'))
# (518, Decimal('108.75'))
# (574, Decimal('108.73'))
# (239, Decimal('108.72'))
# (167, Decimal('108.71'))
# (293, Decimal('107.79'))
# (571, Decimal('107.78'))
# (427, Decimal('107.77'))
# (332, Decimal('107.74'))
# (145, Decimal('107.73'))
# (441, Decimal('107.73'))
# (588, Decimal('107.73'))
# (157, Decimal('107.71'))
# (418, Decimal('107.70'))
# (254, Decimal('107.70'))
# (91, Decimal('107.66'))
# (477, Decimal('106.79'))
# (240, Decimal('106.77'))
# (343, Decimal('106.77'))
# (155, Decimal('106.76'))
# (234, Decimal('106.75'))
# (471, Decimal('106.74'))
# (116, Decimal('106.74'))
# (23, Decimal('106.73'))
# (457, Decimal('106.73'))
# (160, Decimal('106.73'))
# (52, Decimal('106.72'))
# (138, Decimal('106.68'))
# (490, Decimal('105.78'))
# (127, Decimal('105.78'))
# (331, Decimal('105.78'))
# (193, Decimal('105.77'))
# (294, Decimal('105.77'))
# (400, Decimal('105.76'))
# (58, Decimal('105.76'))
# (40, Decimal('105.74'))
# (396, Decimal('105.74'))
# (96, Decimal('105.73'))
# (444, Decimal('105.72'))
# (28, Decimal('105.70'))
# (345, Decimal('104.79'))
# (493, Decimal('104.78'))
# (289, Decimal('104.76'))
# (171, Decimal('104.75'))
# (121, Decimal('104.75'))
# (31, Decimal('104.74'))
# (407, Decimal('104.74'))
# (25, Decimal('104.73'))
# (397, Decimal('104.72'))
# (442, Decimal('104.71'))
# (341, Decimal('103.78'))
# (296, Decimal('103.77'))
# (280, Decimal('103.77'))
# (214, Decimal('103.74'))
# (245, Decimal('103.74'))
# (202, Decimal('103.74'))
# (20, Decimal('103.73'))
# (408, Decimal('103.73'))
# (292, Decimal('102.78'))
# (553, Decimal('102.77'))
# (510, Decimal('102.77'))
# (98, Decimal('102.76'))
# (587, Decimal('102.76'))
# (126, Decimal('102.75'))
# (190, Decimal('102.75'))
# (44, Decimal('101.79'))
# (466, Decimal('101.78'))
# (100, Decimal('101.77'))
# (593, Decimal('101.76'))
# (405, Decimal('101.70'))
# (486, Decimal('100.77'))
# (517, Decimal('100.76'))
# (572, Decimal('100.76'))
# (251, Decimal('100.75'))
# (219, Decimal('100.75'))
# (135, Decimal('100.72'))

# %% [markdown]
# #### AS command

# %%
# Assign temporary names (alias) to columns or result in queries
select_records = """
SELECT SUM (amount) AS rental_price
FROM payment;
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (Decimal('61312.04'),)

# %% [markdown]
# #### Format output into Pandas DataFrame

# %%
# Create empty list
output_db = []

# Loop over the results
for result in results:
    result = list(result)
    output_db.append(result)

# %%
# Column names
columns = ["rental_price"]

# Create Pandas DataFrame from database (SQL query) output
df = pd.DataFrame(output_db, columns = columns)

# %%
# Display the few top rows of Pandas DataFrame
df.head()
# Out:
#   rental_price
# 0     61312.04

# %% [markdown]
# #### INNER JOIN clause

# %%
# Get data (set of records / rows) that is intersection of tables
# Join Customer table and Payment table in order to get customer e-mail associated to specific payment_id
select_records = """
SELECT payment_id, payment.customer_id, email
FROM payment
INNER JOIN customer
ON payment.customer_id = customer.customer_id
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (17503, 341, 'peter.menard@sakilacustomer.org')
# (17504, 341, 'peter.menard@sakilacustomer.org')
# (17505, 341, 'peter.menard@sakilacustomer.org')
# (17506, 341, 'peter.menard@sakilacustomer.org')
# (17507, 341, 'peter.menard@sakilacustomer.org')
# (17508, 341, 'peter.menard@sakilacustomer.org')
# (17509, 342, 'harold.martino@sakilacustomer.org')
# (17510, 342, 'harold.martino@sakilacustomer.org')
# (17511, 342, 'harold.martino@sakilacustomer.org')
# (17512, 343, 'douglas.graf@sakilacustomer.org')
# (17513, 343, 'douglas.graf@sakilacustomer.org')
# (17514, 343, 'douglas.graf@sakilacustomer.org')
# (17515, 343, 'douglas.graf@sakilacustomer.org')
# (17516, 343, 'douglas.graf@sakilacustomer.org')
# (17517, 343, 'douglas.graf@sakilacustomer.org')
# (17518, 343, 'douglas.graf@sakilacustomer.org')
# (17519, 344, 'henry.billingsley@sakilacustomer.org')
# (17520, 344, 'henry.billingsley@sakilacustomer.org')
# (17521, 344, 'henry.billingsley@sakilacustomer.org')
# (17522, 345, 'carl.artis@sakilacustomer.org')
# (17523, 345, 'carl.artis@sakilacustomer.org')
# (17524, 345, 'carl.artis@sakilacustomer.org')
# (17525, 345, 'carl.artis@sakilacustomer.org')
# (17526, 346, 'arthur.simpkins@sakilacustomer.org')
# (17527, 346, 'arthur.simpkins@sakilacustomer.org')
# (17528, 346, 'arthur.simpkins@sakilacustomer.org')
# (17529, 347, 'ryan.salisbury@sakilacustomer.org')
# (17530, 347, 'ryan.salisbury@sakilacustomer.org')
# (17531, 347, 'ryan.salisbury@sakilacustomer.org')
# (17532, 347, 'ryan.salisbury@sakilacustomer.org')
# (17533, 347, 'ryan.salisbury@sakilacustomer.org')
# (17534, 348, 'roger.quintanilla@sakilacustomer.org')
# (17535, 348, 'roger.quintanilla@sakilacustomer.org')
# (17536, 348, 'roger.quintanilla@sakilacustomer.org')
# (17537, 349, 'joe.gilliland@sakilacustomer.org')
# (17538, 349, 'joe.gilliland@sakilacustomer.org')
# (17539, 349, 'joe.gilliland@sakilacustomer.org')
# (17540, 349, 'joe.gilliland@sakilacustomer.org')
# (17541, 350, 'juan.fraley@sakilacustomer.org')
# (17542, 350, 'juan.fraley@sakilacustomer.org')
# (17543, 350, 'juan.fraley@sakilacustomer.org')
# (17544, 350, 'juan.fraley@sakilacustomer.org')
# (17545, 351, 'jack.foust@sakilacustomer.org')
# (17546, 351, 'jack.foust@sakilacustomer.org')
# (17547, 351, 'jack.foust@sakilacustomer.org')
# (17548, 352, 'albert.crouse@sakilacustomer.org')
# (17549, 352, 'albert.crouse@sakilacustomer.org')
# (17550, 352, 'albert.crouse@sakilacustomer.org')
# (17551, 352, 'albert.crouse@sakilacustomer.org')
# (17552, 352, 'albert.crouse@sakilacustomer.org')
# (17553, 353, 'jonathan.scarborough@sakilacustomer.org')
# (17554, 353, 'jonathan.scarborough@sakilacustomer.org')
# (17555, 353, 'jonathan.scarborough@sakilacustomer.org')
# (17556, 354, 'justin.ngo@sakilacustomer.org')
# (17557, 354, 'justin.ngo@sakilacustomer.org')
# (17558, 354, 'justin.ngo@sakilacustomer.org')
# (17559, 354, 'justin.ngo@sakilacustomer.org')
# (17560, 355, 'terry.grissom@sakilacustomer.org')
# (17561, 355, 'terry.grissom@sakilacustomer.org')
# (17562, 356, 'gerald.fultz@sakilacustomer.org')
# (17563, 356, 'gerald.fultz@sakilacustomer.org')
# (17564, 356, 'gerald.fultz@sakilacustomer.org')
# (17565, 357, 'keith.rico@sakilacustomer.org')
# (17566, 357, 'keith.rico@sakilacustomer.org')
# (17567, 357, 'keith.rico@sakilacustomer.org')
# (17568, 357, 'keith.rico@sakilacustomer.org')
# (17569, 358, 'samuel.marlow@sakilacustomer.org')
# (17570, 358, 'samuel.marlow@sakilacustomer.org')
# (17571, 358, 'samuel.marlow@sakilacustomer.org')
# (17572, 358, 'samuel.marlow@sakilacustomer.org')
# (17573, 358, 'samuel.marlow@sakilacustomer.org')
# (17574, 358, 'samuel.marlow@sakilacustomer.org')
# (17575, 359, 'willie.markham@sakilacustomer.org')
# (17576, 359, 'willie.markham@sakilacustomer.org')
# (17577, 359, 'willie.markham@sakilacustomer.org')
# (17578, 359, 'willie.markham@sakilacustomer.org')
# (17579, 360, 'ralph.madrigal@sakilacustomer.org')
# (17580, 360, 'ralph.madrigal@sakilacustomer.org')
# (17581, 360, 'ralph.madrigal@sakilacustomer.org')
# (17582, 360, 'ralph.madrigal@sakilacustomer.org')
# (17583, 361, 'lawrence.lawton@sakilacustomer.org')
# (17584, 361, 'lawrence.lawton@sakilacustomer.org')
# (17585, 361, 'lawrence.lawton@sakilacustomer.org')
# (17586, 361, 'lawrence.lawton@sakilacustomer.org')
# (17587, 362, 'nicholas.barfield@sakilacustomer.org')
# (17588, 362, 'nicholas.barfield@sakilacustomer.org')
# (17589, 362, 'nicholas.barfield@sakilacustomer.org')
# (17590, 362, 'nicholas.barfield@sakilacustomer.org')
# (17591, 362, 'nicholas.barfield@sakilacustomer.org')
# (17592, 363, 'roy.whiting@sakilacustomer.org')
# (17593, 363, 'roy.whiting@sakilacustomer.org')
# (17594, 363, 'roy.whiting@sakilacustomer.org')
# (17595, 363, 'roy.whiting@sakilacustomer.org')
# (17596, 363, 'roy.whiting@sakilacustomer.org')
# (17597, 364, 'benjamin.varney@sakilacustomer.org')
# (17598, 364, 'benjamin.varney@sakilacustomer.org')
# (17599, 364, 'benjamin.varney@sakilacustomer.org')
# (17600, 364, 'benjamin.varney@sakilacustomer.org')
# (17601, 364, 'benjamin.varney@sakilacustomer.org')
# (17602, 365, 'bruce.schwarz@sakilacustomer.org')
# (17603, 365, 'bruce.schwarz@sakilacustomer.org')
# (17604, 365, 'bruce.schwarz@sakilacustomer.org')
# (17605, 365, 'bruce.schwarz@sakilacustomer.org')
# (17606, 365, 'bruce.schwarz@sakilacustomer.org')
# (17607, 366, 'brandon.huey@sakilacustomer.org')
# (17608, 366, 'brandon.huey@sakilacustomer.org')
# (17609, 367, 'adam.gooch@sakilacustomer.org')
# (17610, 368, 'harry.arce@sakilacustomer.org')
# (17611, 368, 'harry.arce@sakilacustomer.org')
# (17612, 368, 'harry.arce@sakilacustomer.org')
# (17613, 368, 'harry.arce@sakilacustomer.org')
# (17614, 368, 'harry.arce@sakilacustomer.org')
# (17615, 368, 'harry.arce@sakilacustomer.org')
# (17616, 369, 'fred.wheat@sakilacustomer.org')
# (17617, 370, 'wayne.truong@sakilacustomer.org')
# (17618, 371, 'billy.poulin@sakilacustomer.org')
# (17619, 371, 'billy.poulin@sakilacustomer.org')
# (17620, 371, 'billy.poulin@sakilacustomer.org')
# (17621, 371, 'billy.poulin@sakilacustomer.org')
# (17622, 371, 'billy.poulin@sakilacustomer.org')
# (17623, 371, 'billy.poulin@sakilacustomer.org')
# (17624, 371, 'billy.poulin@sakilacustomer.org')
# (17625, 372, 'steve.mackenzie@sakilacustomer.org')
# (17626, 372, 'steve.mackenzie@sakilacustomer.org')
# (17627, 372, 'steve.mackenzie@sakilacustomer.org')
# (17628, 373, 'louis.leone@sakilacustomer.org')
# (17629, 373, 'louis.leone@sakilacustomer.org')
# (17630, 374, 'jeremy.hurtado@sakilacustomer.org')
# (17631, 374, 'jeremy.hurtado@sakilacustomer.org')
# (17632, 374, 'jeremy.hurtado@sakilacustomer.org')
# (17633, 374, 'jeremy.hurtado@sakilacustomer.org')
# (17634, 375, 'aaron.selby@sakilacustomer.org')
# (17635, 375, 'aaron.selby@sakilacustomer.org')
# (17636, 375, 'aaron.selby@sakilacustomer.org')
# (17637, 376, 'randy.gaither@sakilacustomer.org')
# (17638, 376, 'randy.gaither@sakilacustomer.org')
# (17639, 377, 'howard.fortner@sakilacustomer.org')
# (17640, 377, 'howard.fortner@sakilacustomer.org')
# (17641, 377, 'howard.fortner@sakilacustomer.org')
# (17642, 377, 'howard.fortner@sakilacustomer.org')
# (17643, 377, 'howard.fortner@sakilacustomer.org')
# (17644, 378, 'eugene.culpepper@sakilacustomer.org')
# (17645, 378, 'eugene.culpepper@sakilacustomer.org')
# (17646, 378, 'eugene.culpepper@sakilacustomer.org')
# (17647, 378, 'eugene.culpepper@sakilacustomer.org')
# (17648, 379, 'carlos.coughlin@sakilacustomer.org')
# (17649, 379, 'carlos.coughlin@sakilacustomer.org')
# (17650, 379, 'carlos.coughlin@sakilacustomer.org')
# (17651, 380, 'russell.brinson@sakilacustomer.org')
# (17652, 380, 'russell.brinson@sakilacustomer.org')
# (17653, 380, 'russell.brinson@sakilacustomer.org')
# (17654, 380, 'russell.brinson@sakilacustomer.org')
# (17655, 380, 'russell.brinson@sakilacustomer.org')
# (17656, 380, 'russell.brinson@sakilacustomer.org')
# (17657, 380, 'russell.brinson@sakilacustomer.org')
# (17658, 380, 'russell.brinson@sakilacustomer.org')
# (17659, 381, 'bobby.boudreau@sakilacustomer.org')
# (17660, 381, 'bobby.boudreau@sakilacustomer.org')
# (17661, 381, 'bobby.boudreau@sakilacustomer.org')
# (17662, 381, 'bobby.boudreau@sakilacustomer.org')
# (17663, 381, 'bobby.boudreau@sakilacustomer.org')
# (17664, 382, 'victor.barkley@sakilacustomer.org')
# (17665, 382, 'victor.barkley@sakilacustomer.org')
# (17666, 382, 'victor.barkley@sakilacustomer.org')
# (17667, 382, 'victor.barkley@sakilacustomer.org')
# (17668, 382, 'victor.barkley@sakilacustomer.org')
# (17669, 383, 'martin.bales@sakilacustomer.org')
# (17670, 383, 'martin.bales@sakilacustomer.org')
# (17671, 383, 'martin.bales@sakilacustomer.org')
# (17672, 383, 'martin.bales@sakilacustomer.org')
# (17673, 383, 'martin.bales@sakilacustomer.org')
# (17674, 383, 'martin.bales@sakilacustomer.org')
# (17675, 384, 'ernest.stepp@sakilacustomer.org')
# (17676, 384, 'ernest.stepp@sakilacustomer.org')
# (17677, 384, 'ernest.stepp@sakilacustomer.org')
# (17678, 384, 'ernest.stepp@sakilacustomer.org')
# (17679, 384, 'ernest.stepp@sakilacustomer.org')
# (17680, 384, 'ernest.stepp@sakilacustomer.org')
# (17681, 384, 'ernest.stepp@sakilacustomer.org')
# (17682, 385, 'phillip.holm@sakilacustomer.org')
# (17683, 385, 'phillip.holm@sakilacustomer.org')
# (17684, 385, 'phillip.holm@sakilacustomer.org')
# (17685, 386, 'todd.tan@sakilacustomer.org')
# (17686, 386, 'todd.tan@sakilacustomer.org')
# (17687, 386, 'todd.tan@sakilacustomer.org')
# (17688, 386, 'todd.tan@sakilacustomer.org')
# (17689, 386, 'todd.tan@sakilacustomer.org')
# (17690, 387, 'jesse.schilling@sakilacustomer.org')
# (17691, 387, 'jesse.schilling@sakilacustomer.org')
# (17692, 387, 'jesse.schilling@sakilacustomer.org')
# (17693, 387, 'jesse.schilling@sakilacustomer.org')
# (17694, 387, 'jesse.schilling@sakilacustomer.org')
# (17695, 387, 'jesse.schilling@sakilacustomer.org')
# (17696, 388, 'craig.morrell@sakilacustomer.org')
# (17697, 388, 'craig.morrell@sakilacustomer.org')
# (17698, 388, 'craig.morrell@sakilacustomer.org')
# (17699, 388, 'craig.morrell@sakilacustomer.org')
# (17700, 388, 'craig.morrell@sakilacustomer.org')
# (17701, 389, 'alan.kahn@sakilacustomer.org')
# (17702, 389, 'alan.kahn@sakilacustomer.org')
# (17703, 389, 'alan.kahn@sakilacustomer.org')
# (17704, 390, 'shawn.heaton@sakilacustomer.org')
# (17705, 390, 'shawn.heaton@sakilacustomer.org')
# (17706, 390, 'shawn.heaton@sakilacustomer.org')
# (17707, 390, 'shawn.heaton@sakilacustomer.org')
# (17708, 390, 'shawn.heaton@sakilacustomer.org')
# (17709, 391, 'clarence.gamez@sakilacustomer.org')
# (17710, 391, 'clarence.gamez@sakilacustomer.org')
# (17711, 391, 'clarence.gamez@sakilacustomer.org')
# (17712, 391, 'clarence.gamez@sakilacustomer.org')
# (17713, 391, 'clarence.gamez@sakilacustomer.org')
# (17714, 392, 'sean.douglass@sakilacustomer.org')
# (17715, 392, 'sean.douglass@sakilacustomer.org')
# (17716, 392, 'sean.douglass@sakilacustomer.org')
# (17717, 392, 'sean.douglass@sakilacustomer.org')
# (17718, 393, 'philip.causey@sakilacustomer.org')
# (17719, 393, 'philip.causey@sakilacustomer.org')
# (17720, 393, 'philip.causey@sakilacustomer.org')
# (17721, 393, 'philip.causey@sakilacustomer.org')
# (17722, 393, 'philip.causey@sakilacustomer.org')
# (17723, 394, 'chris.brothers@sakilacustomer.org')
# (17724, 395, 'johnny.turpin@sakilacustomer.org')
# (17725, 395, 'johnny.turpin@sakilacustomer.org')
# (17726, 395, 'johnny.turpin@sakilacustomer.org')
# (17727, 395, 'johnny.turpin@sakilacustomer.org')
# (17728, 395, 'johnny.turpin@sakilacustomer.org')
# (17729, 395, 'johnny.turpin@sakilacustomer.org')
# (17730, 396, 'earl.shanks@sakilacustomer.org')
# (17731, 396, 'earl.shanks@sakilacustomer.org')
# (17732, 396, 'earl.shanks@sakilacustomer.org')
# (17733, 397, 'jimmy.schrader@sakilacustomer.org')
# (17734, 397, 'jimmy.schrader@sakilacustomer.org')
# (17735, 398, 'antonio.meek@sakilacustomer.org')
# (17736, 398, 'antonio.meek@sakilacustomer.org')
# (17737, 398, 'antonio.meek@sakilacustomer.org')
# (17738, 399, 'danny.isom@sakilacustomer.org')
# (17739, 399, 'danny.isom@sakilacustomer.org')
# (17740, 400, 'bryan.hardison@sakilacustomer.org')
# (17741, 400, 'bryan.hardison@sakilacustomer.org')
# (17742, 400, 'bryan.hardison@sakilacustomer.org')
# (17743, 402, 'luis.yanez@sakilacustomer.org')
# (17744, 402, 'luis.yanez@sakilacustomer.org')
# (17745, 402, 'luis.yanez@sakilacustomer.org')
# (17746, 403, 'mike.way@sakilacustomer.org')
# (17747, 403, 'mike.way@sakilacustomer.org')
# (17748, 403, 'mike.way@sakilacustomer.org')
# (17749, 403, 'mike.way@sakilacustomer.org')
# (17750, 403, 'mike.way@sakilacustomer.org')
# (17751, 403, 'mike.way@sakilacustomer.org')
# (17752, 404, 'stanley.scroggins@sakilacustomer.org')
# (17753, 404, 'stanley.scroggins@sakilacustomer.org')
# (17754, 404, 'stanley.scroggins@sakilacustomer.org')
# (17755, 404, 'stanley.scroggins@sakilacustomer.org')
# (17756, 405, 'leonard.schofield@sakilacustomer.org')
# (17757, 405, 'leonard.schofield@sakilacustomer.org')
# (17758, 405, 'leonard.schofield@sakilacustomer.org')
# (17759, 405, 'leonard.schofield@sakilacustomer.org')
# (17760, 405, 'leonard.schofield@sakilacustomer.org')
# (17761, 405, 'leonard.schofield@sakilacustomer.org')
# (17762, 406, 'nathan.runyon@sakilacustomer.org')
# (17763, 406, 'nathan.runyon@sakilacustomer.org')
# (17764, 406, 'nathan.runyon@sakilacustomer.org')
# (17765, 406, 'nathan.runyon@sakilacustomer.org')
# (17766, 406, 'nathan.runyon@sakilacustomer.org')
# (17767, 406, 'nathan.runyon@sakilacustomer.org')
# (17768, 406, 'nathan.runyon@sakilacustomer.org')
# (17769, 407, 'dale.ratcliff@sakilacustomer.org')
# (17770, 407, 'dale.ratcliff@sakilacustomer.org')
# (17771, 408, 'manuel.murrell@sakilacustomer.org')
# (17772, 408, 'manuel.murrell@sakilacustomer.org')
# (17773, 408, 'manuel.murrell@sakilacustomer.org')
# (17774, 409, 'rodney.moeller@sakilacustomer.org')
# (17775, 409, 'rodney.moeller@sakilacustomer.org')
# (17776, 410, 'curtis.irby@sakilacustomer.org')
# (17777, 410, 'curtis.irby@sakilacustomer.org')
# (17778, 410, 'curtis.irby@sakilacustomer.org')
# (17779, 410, 'curtis.irby@sakilacustomer.org')
# (17780, 410, 'curtis.irby@sakilacustomer.org')
# (17781, 410, 'curtis.irby@sakilacustomer.org')
# (17782, 411, 'norman.currier@sakilacustomer.org')
# (17783, 411, 'norman.currier@sakilacustomer.org')
# (17784, 411, 'norman.currier@sakilacustomer.org')
# (17785, 412, 'allen.butterfield@sakilacustomer.org')
# (17786, 413, 'marvin.yee@sakilacustomer.org')
# (17787, 413, 'marvin.yee@sakilacustomer.org')
# (17788, 414, 'vincent.ralston@sakilacustomer.org')
# (17789, 414, 'vincent.ralston@sakilacustomer.org')
# (17790, 414, 'vincent.ralston@sakilacustomer.org')
# (17791, 415, 'glenn.pullen@sakilacustomer.org')
# (17792, 415, 'glenn.pullen@sakilacustomer.org')
# (17793, 416, 'jeffery.pinson@sakilacustomer.org')
# (17794, 416, 'jeffery.pinson@sakilacustomer.org')
# (17795, 416, 'jeffery.pinson@sakilacustomer.org')
# (17796, 416, 'jeffery.pinson@sakilacustomer.org')
# (17797, 416, 'jeffery.pinson@sakilacustomer.org')
# (17798, 417, 'travis.estep@sakilacustomer.org')
# (17799, 418, 'jeff.east@sakilacustomer.org')
# (17800, 418, 'jeff.east@sakilacustomer.org')
# (17801, 418, 'jeff.east@sakilacustomer.org')
# (17802, 419, 'chad.carbone@sakilacustomer.org')
# (17803, 420, 'jacob.lance@sakilacustomer.org')
# (17804, 420, 'jacob.lance@sakilacustomer.org')
# (17805, 420, 'jacob.lance@sakilacustomer.org')
# (17806, 421, 'lee.hawks@sakilacustomer.org')
# (17807, 421, 'lee.hawks@sakilacustomer.org')
# (17808, 421, 'lee.hawks@sakilacustomer.org')
# (17809, 422, 'melvin.ellington@sakilacustomer.org')
# (17810, 422, 'melvin.ellington@sakilacustomer.org')
# (17811, 422, 'melvin.ellington@sakilacustomer.org')
# (17812, 422, 'melvin.ellington@sakilacustomer.org')
# (17813, 423, 'alfred.casillas@sakilacustomer.org')
# (17814, 423, 'alfred.casillas@sakilacustomer.org')
# (17815, 423, 'alfred.casillas@sakilacustomer.org')
# (17816, 423, 'alfred.casillas@sakilacustomer.org')
# (17817, 423, 'alfred.casillas@sakilacustomer.org')
# (17818, 424, 'kyle.spurlock@sakilacustomer.org')
# (17819, 424, 'kyle.spurlock@sakilacustomer.org')
# (17820, 424, 'kyle.spurlock@sakilacustomer.org')
# (17821, 425, 'francis.sikes@sakilacustomer.org')
# (17822, 426, 'bradley.motley@sakilacustomer.org')
# (17823, 426, 'bradley.motley@sakilacustomer.org')
# (17824, 426, 'bradley.motley@sakilacustomer.org')
# (17825, 426, 'bradley.motley@sakilacustomer.org')
# (17826, 426, 'bradley.motley@sakilacustomer.org')
# (17827, 427, 'jesus.mccartney@sakilacustomer.org')
# (17828, 427, 'jesus.mccartney@sakilacustomer.org')
# (17829, 427, 'jesus.mccartney@sakilacustomer.org')
# (17830, 427, 'jesus.mccartney@sakilacustomer.org')
# (17831, 427, 'jesus.mccartney@sakilacustomer.org')
# (17832, 428, 'herbert.kruger@sakilacustomer.org')
# (17833, 428, 'herbert.kruger@sakilacustomer.org')
# (17834, 428, 'herbert.kruger@sakilacustomer.org')
# (17835, 428, 'herbert.kruger@sakilacustomer.org')
# (17836, 428, 'herbert.kruger@sakilacustomer.org')
# (17837, 429, 'frederick.isbell@sakilacustomer.org')
# (17838, 429, 'frederick.isbell@sakilacustomer.org')
# (17839, 429, 'frederick.isbell@sakilacustomer.org')
# (17840, 429, 'frederick.isbell@sakilacustomer.org')
# (17841, 430, 'ray.houle@sakilacustomer.org')
# (17842, 430, 'ray.houle@sakilacustomer.org')
# (17843, 430, 'ray.houle@sakilacustomer.org')
# (17844, 430, 'ray.houle@sakilacustomer.org')
# (17845, 430, 'ray.houle@sakilacustomer.org')
# (17846, 430, 'ray.houle@sakilacustomer.org')
# (17847, 431, 'joel.francisco@sakilacustomer.org')
# (17848, 431, 'joel.francisco@sakilacustomer.org')
# (17849, 431, 'joel.francisco@sakilacustomer.org')
# (17850, 431, 'joel.francisco@sakilacustomer.org')
# (17851, 431, 'joel.francisco@sakilacustomer.org')
# (17852, 431, 'joel.francisco@sakilacustomer.org')
# (17853, 431, 'joel.francisco@sakilacustomer.org')
# (17854, 432, 'edwin.burk@sakilacustomer.org')
# (17855, 432, 'edwin.burk@sakilacustomer.org')
# (17856, 432, 'edwin.burk@sakilacustomer.org')
# (17857, 434, 'eddie.tomlin@sakilacustomer.org')
# (17858, 434, 'eddie.tomlin@sakilacustomer.org')
# (17859, 434, 'eddie.tomlin@sakilacustomer.org')
# (17860, 434, 'eddie.tomlin@sakilacustomer.org')
# (17861, 434, 'eddie.tomlin@sakilacustomer.org')
# (17862, 434, 'eddie.tomlin@sakilacustomer.org')
# (17863, 434, 'eddie.tomlin@sakilacustomer.org')
# (17864, 435, 'ricky.shelby@sakilacustomer.org')
# (17865, 435, 'ricky.shelby@sakilacustomer.org')
# (17866, 436, 'troy.quigley@sakilacustomer.org')
# (17867, 437, 'randall.neumann@sakilacustomer.org')
# (17868, 437, 'randall.neumann@sakilacustomer.org')
# (17869, 437, 'randall.neumann@sakilacustomer.org')
# (17870, 438, 'barry.lovelace@sakilacustomer.org')
# (17871, 438, 'barry.lovelace@sakilacustomer.org')
# (17872, 438, 'barry.lovelace@sakilacustomer.org')
# (17873, 438, 'barry.lovelace@sakilacustomer.org')
# (17874, 438, 'barry.lovelace@sakilacustomer.org')
# (17875, 438, 'barry.lovelace@sakilacustomer.org')
# (17876, 439, 'alexander.fennell@sakilacustomer.org')
# (17877, 439, 'alexander.fennell@sakilacustomer.org')
# (17878, 439, 'alexander.fennell@sakilacustomer.org')
# (17879, 439, 'alexander.fennell@sakilacustomer.org')
# (17880, 439, 'alexander.fennell@sakilacustomer.org')
# (17881, 439, 'alexander.fennell@sakilacustomer.org')
# (17882, 441, 'mario.cheatham@sakilacustomer.org')
# (17883, 441, 'mario.cheatham@sakilacustomer.org')
# (17884, 442, 'leroy.bustamante@sakilacustomer.org')
# (17885, 442, 'leroy.bustamante@sakilacustomer.org')
# (17886, 442, 'leroy.bustamante@sakilacustomer.org')
# (17887, 442, 'leroy.bustamante@sakilacustomer.org')
# (17888, 443, 'francisco.skidmore@sakilacustomer.org')
# (17889, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17890, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17891, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17892, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17893, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17894, 444, 'marcus.hidalgo@sakilacustomer.org')
# (17895, 446, 'theodore.culp@sakilacustomer.org')
# (17896, 446, 'theodore.culp@sakilacustomer.org')
# (17897, 446, 'theodore.culp@sakilacustomer.org')
# (17898, 446, 'theodore.culp@sakilacustomer.org')
# (17899, 446, 'theodore.culp@sakilacustomer.org')
# (17900, 446, 'theodore.culp@sakilacustomer.org')
# (17901, 447, 'clifford.bowens@sakilacustomer.org')
# (17902, 447, 'clifford.bowens@sakilacustomer.org')
# (17903, 447, 'clifford.bowens@sakilacustomer.org')
# (17904, 447, 'clifford.bowens@sakilacustomer.org')
# (17905, 448, 'miguel.betancourt@sakilacustomer.org')
# (17906, 448, 'miguel.betancourt@sakilacustomer.org')
# (17907, 448, 'miguel.betancourt@sakilacustomer.org')
# (17908, 448, 'miguel.betancourt@sakilacustomer.org')
# (17909, 448, 'miguel.betancourt@sakilacustomer.org')
# (17910, 449, 'oscar.aquino@sakilacustomer.org')
# (17911, 449, 'oscar.aquino@sakilacustomer.org')
# (17912, 449, 'oscar.aquino@sakilacustomer.org')
# (17913, 450, 'jay.robb@sakilacustomer.org')
# (17914, 450, 'jay.robb@sakilacustomer.org')
# (17915, 450, 'jay.robb@sakilacustomer.org')
# (17916, 450, 'jay.robb@sakilacustomer.org')
# (17917, 450, 'jay.robb@sakilacustomer.org')
# (17918, 450, 'jay.robb@sakilacustomer.org')
# (17919, 450, 'jay.robb@sakilacustomer.org')
# (17920, 451, 'jim.rea@sakilacustomer.org')
# (17921, 451, 'jim.rea@sakilacustomer.org')
# (17922, 451, 'jim.rea@sakilacustomer.org')
# (17923, 451, 'jim.rea@sakilacustomer.org')
# (17924, 451, 'jim.rea@sakilacustomer.org')
# (17925, 451, 'jim.rea@sakilacustomer.org')
# (17926, 451, 'jim.rea@sakilacustomer.org')
# (17927, 452, 'tom.milner@sakilacustomer.org')
# (17928, 452, 'tom.milner@sakilacustomer.org')
# (17929, 452, 'tom.milner@sakilacustomer.org')
# (17930, 452, 'tom.milner@sakilacustomer.org')
# (17931, 452, 'tom.milner@sakilacustomer.org')
# (17932, 452, 'tom.milner@sakilacustomer.org')
# (17933, 452, 'tom.milner@sakilacustomer.org')
# (17934, 453, 'calvin.martel@sakilacustomer.org')
# (17935, 453, 'calvin.martel@sakilacustomer.org')
# (17936, 453, 'calvin.martel@sakilacustomer.org')
# (17937, 454, 'alex.gresham@sakilacustomer.org')
# (17938, 454, 'alex.gresham@sakilacustomer.org')
# (17939, 454, 'alex.gresham@sakilacustomer.org')
# (17940, 454, 'alex.gresham@sakilacustomer.org')
# (17941, 454, 'alex.gresham@sakilacustomer.org')
# (17942, 454, 'alex.gresham@sakilacustomer.org')
# (17943, 454, 'alex.gresham@sakilacustomer.org')
# (17944, 454, 'alex.gresham@sakilacustomer.org')
# (17945, 454, 'alex.gresham@sakilacustomer.org')
# (17946, 454, 'alex.gresham@sakilacustomer.org')
# (17947, 455, 'jon.wiles@sakilacustomer.org')
# (17948, 455, 'jon.wiles@sakilacustomer.org')
# (17949, 455, 'jon.wiles@sakilacustomer.org')
# (17950, 455, 'jon.wiles@sakilacustomer.org')
# (17951, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17952, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17953, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17954, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17955, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17956, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17957, 456, 'ronnie.ricketts@sakilacustomer.org')
# (17958, 457, 'bill.gavin@sakilacustomer.org')
# (17959, 457, 'bill.gavin@sakilacustomer.org')
# (17960, 457, 'bill.gavin@sakilacustomer.org')
# (17961, 457, 'bill.gavin@sakilacustomer.org')
# (17962, 457, 'bill.gavin@sakilacustomer.org')
# (17963, 457, 'bill.gavin@sakilacustomer.org')
# (17964, 457, 'bill.gavin@sakilacustomer.org')
# (17965, 457, 'bill.gavin@sakilacustomer.org')
# (17966, 457, 'bill.gavin@sakilacustomer.org')
# (17967, 458, 'lloyd.dowd@sakilacustomer.org')
# (17968, 458, 'lloyd.dowd@sakilacustomer.org')
# (17969, 459, 'tommy.collazo@sakilacustomer.org')
# (17970, 459, 'tommy.collazo@sakilacustomer.org')
# (17971, 459, 'tommy.collazo@sakilacustomer.org')
# (17972, 459, 'tommy.collazo@sakilacustomer.org')
# (17973, 459, 'tommy.collazo@sakilacustomer.org')
# (17974, 459, 'tommy.collazo@sakilacustomer.org')
# (17975, 459, 'tommy.collazo@sakilacustomer.org')
# (17976, 460, 'leon.bostic@sakilacustomer.org')
# (17977, 461, 'derek.blakely@sakilacustomer.org')
# (17978, 461, 'derek.blakely@sakilacustomer.org')
# (17979, 462, 'warren.sherrod@sakilacustomer.org')
# (17980, 462, 'warren.sherrod@sakilacustomer.org')
# (17981, 462, 'warren.sherrod@sakilacustomer.org')
# (17982, 463, 'darrell.power@sakilacustomer.org')
# (17983, 463, 'darrell.power@sakilacustomer.org')
# (17984, 463, 'darrell.power@sakilacustomer.org')
# (17985, 463, 'darrell.power@sakilacustomer.org')
# (17986, 464, 'jerome.kenyon@sakilacustomer.org')
# (17987, 464, 'jerome.kenyon@sakilacustomer.org')
# (17988, 465, 'floyd.gandy@sakilacustomer.org')
# (17989, 465, 'floyd.gandy@sakilacustomer.org')
# (17990, 465, 'floyd.gandy@sakilacustomer.org')
# (17991, 465, 'floyd.gandy@sakilacustomer.org')
# (17992, 466, 'leo.ebert@sakilacustomer.org')
# (17993, 466, 'leo.ebert@sakilacustomer.org')
# (17994, 466, 'leo.ebert@sakilacustomer.org')
# (17995, 466, 'leo.ebert@sakilacustomer.org')
# (17996, 466, 'leo.ebert@sakilacustomer.org')
# (17997, 467, 'alvin.deloach@sakilacustomer.org')
# (17998, 467, 'alvin.deloach@sakilacustomer.org')
# (17999, 467, 'alvin.deloach@sakilacustomer.org')
# (18000, 467, 'alvin.deloach@sakilacustomer.org')
# (18001, 468, 'tim.cary@sakilacustomer.org')
# (18002, 468, 'tim.cary@sakilacustomer.org')
# (18003, 468, 'tim.cary@sakilacustomer.org')
# (18004, 468, 'tim.cary@sakilacustomer.org')
# (18005, 468, 'tim.cary@sakilacustomer.org')
# (18006, 468, 'tim.cary@sakilacustomer.org')
# (18007, 469, 'wesley.bull@sakilacustomer.org')
# (18008, 469, 'wesley.bull@sakilacustomer.org')
# (18009, 470, 'gordon.allard@sakilacustomer.org')
# (18010, 470, 'gordon.allard@sakilacustomer.org')
# (18011, 470, 'gordon.allard@sakilacustomer.org')
# (18012, 471, 'dean.sauer@sakilacustomer.org')
# (18013, 471, 'dean.sauer@sakilacustomer.org')
# (18014, 471, 'dean.sauer@sakilacustomer.org')
# (18015, 471, 'dean.sauer@sakilacustomer.org')
# (18016, 471, 'dean.sauer@sakilacustomer.org')
# (18017, 472, 'greg.robins@sakilacustomer.org')
# (18018, 472, 'greg.robins@sakilacustomer.org')
# (18019, 472, 'greg.robins@sakilacustomer.org')
# (18020, 472, 'greg.robins@sakilacustomer.org')
# (18021, 472, 'greg.robins@sakilacustomer.org')
# (18022, 472, 'greg.robins@sakilacustomer.org')
# (18023, 473, 'jorge.olivares@sakilacustomer.org')
# (18024, 473, 'jorge.olivares@sakilacustomer.org')
# (18025, 473, 'jorge.olivares@sakilacustomer.org')
# (18026, 473, 'jorge.olivares@sakilacustomer.org')
# (18027, 474, 'dustin.gillette@sakilacustomer.org')
# (18028, 474, 'dustin.gillette@sakilacustomer.org')
# (18029, 476, 'derrick.bourque@sakilacustomer.org')
# (18030, 476, 'derrick.bourque@sakilacustomer.org')
# (18031, 476, 'derrick.bourque@sakilacustomer.org')
# (18032, 476, 'derrick.bourque@sakilacustomer.org')
# (18033, 477, 'dan.paine@sakilacustomer.org')
# (18034, 477, 'dan.paine@sakilacustomer.org')
# (18035, 477, 'dan.paine@sakilacustomer.org')
# (18036, 477, 'dan.paine@sakilacustomer.org')
# (18037, 478, 'lewis.lyman@sakilacustomer.org')
# (18038, 478, 'lewis.lyman@sakilacustomer.org')
# (18039, 478, 'lewis.lyman@sakilacustomer.org')
# (18040, 478, 'lewis.lyman@sakilacustomer.org')
# (18041, 478, 'lewis.lyman@sakilacustomer.org')
# (18042, 478, 'lewis.lyman@sakilacustomer.org')
# (18043, 479, 'zachary.hite@sakilacustomer.org')
# (18044, 479, 'zachary.hite@sakilacustomer.org')
# (18045, 479, 'zachary.hite@sakilacustomer.org')
# (18046, 479, 'zachary.hite@sakilacustomer.org')
# (18047, 479, 'zachary.hite@sakilacustomer.org')
# (18048, 479, 'zachary.hite@sakilacustomer.org')
# (18049, 480, 'corey.hauser@sakilacustomer.org')
# (18050, 480, 'corey.hauser@sakilacustomer.org')
# (18051, 481, 'herman.devore@sakilacustomer.org')
# (18052, 481, 'herman.devore@sakilacustomer.org')
# (18053, 481, 'herman.devore@sakilacustomer.org')
# (18054, 481, 'herman.devore@sakilacustomer.org')
# (18055, 482, 'maurice.crawley@sakilacustomer.org')
# (18056, 482, 'maurice.crawley@sakilacustomer.org')
# (18057, 483, 'vernon.chapa@sakilacustomer.org')
# (18058, 483, 'vernon.chapa@sakilacustomer.org')
# (18059, 483, 'vernon.chapa@sakilacustomer.org')
# (18060, 484, 'roberto.vu@sakilacustomer.org')
# (18061, 484, 'roberto.vu@sakilacustomer.org')
# (18062, 484, 'roberto.vu@sakilacustomer.org')
# (18063, 484, 'roberto.vu@sakilacustomer.org')
# (18064, 485, 'clyde.tobias@sakilacustomer.org')
# (18065, 485, 'clyde.tobias@sakilacustomer.org')
# (18066, 486, 'glen.talbert@sakilacustomer.org')
# (18067, 486, 'glen.talbert@sakilacustomer.org')
# (18068, 486, 'glen.talbert@sakilacustomer.org')
# (18069, 486, 'glen.talbert@sakilacustomer.org')
# (18070, 487, 'hector.poindexter@sakilacustomer.org')
# (18071, 488, 'shane.millard@sakilacustomer.org')
# (18072, 488, 'shane.millard@sakilacustomer.org')
# (18073, 489, 'ricardo.meador@sakilacustomer.org')
# (18074, 489, 'ricardo.meador@sakilacustomer.org')
# (18075, 489, 'ricardo.meador@sakilacustomer.org')
# (18076, 489, 'ricardo.meador@sakilacustomer.org')
# (18077, 490, 'sam.mcduffie@sakilacustomer.org')
# (18078, 491, 'rick.mattox@sakilacustomer.org')
# (18079, 491, 'rick.mattox@sakilacustomer.org')
# (18080, 491, 'rick.mattox@sakilacustomer.org')
# (18081, 491, 'rick.mattox@sakilacustomer.org')
# (18082, 491, 'rick.mattox@sakilacustomer.org')
# (18083, 491, 'rick.mattox@sakilacustomer.org')
# (18084, 491, 'rick.mattox@sakilacustomer.org')
# (18085, 492, 'lester.kraus@sakilacustomer.org')
# (18086, 492, 'lester.kraus@sakilacustomer.org')
# (18087, 492, 'lester.kraus@sakilacustomer.org')
# (18088, 492, 'lester.kraus@sakilacustomer.org')
# (18089, 493, 'brent.harkins@sakilacustomer.org')
# (18090, 493, 'brent.harkins@sakilacustomer.org')
# (18091, 493, 'brent.harkins@sakilacustomer.org')
# (18092, 493, 'brent.harkins@sakilacustomer.org')
# (18093, 494, 'ramon.choate@sakilacustomer.org')
# (18094, 495, 'charlie.bess@sakilacustomer.org')
# (18095, 495, 'charlie.bess@sakilacustomer.org')
# (18096, 495, 'charlie.bess@sakilacustomer.org')
# (18097, 495, 'charlie.bess@sakilacustomer.org')
# (18098, 496, 'tyler.wren@sakilacustomer.org')
# (18099, 497, 'gilbert.sledge@sakilacustomer.org')
# (18100, 497, 'gilbert.sledge@sakilacustomer.org')
# (18101, 497, 'gilbert.sledge@sakilacustomer.org')
# (18102, 497, 'gilbert.sledge@sakilacustomer.org')
# (18103, 498, 'gene.sanborn@sakilacustomer.org')
# (18104, 498, 'gene.sanborn@sakilacustomer.org')
# (18105, 498, 'gene.sanborn@sakilacustomer.org')
# (18106, 498, 'gene.sanborn@sakilacustomer.org')
# (18107, 498, 'gene.sanborn@sakilacustomer.org')
# (18108, 498, 'gene.sanborn@sakilacustomer.org')
# (18109, 499, 'marc.outlaw@sakilacustomer.org')
# (18110, 499, 'marc.outlaw@sakilacustomer.org')
# (18111, 499, 'marc.outlaw@sakilacustomer.org')
# (18112, 499, 'marc.outlaw@sakilacustomer.org')
# (18113, 500, 'reginald.kinder@sakilacustomer.org')
# (18114, 500, 'reginald.kinder@sakilacustomer.org')
# (18115, 500, 'reginald.kinder@sakilacustomer.org')
# (18116, 500, 'reginald.kinder@sakilacustomer.org')
# (18117, 500, 'reginald.kinder@sakilacustomer.org')
# (18118, 501, 'ruben.geary@sakilacustomer.org')
# (18119, 501, 'ruben.geary@sakilacustomer.org')
# (18120, 502, 'brett.cornwell@sakilacustomer.org')
# (18121, 502, 'brett.cornwell@sakilacustomer.org')
# (18122, 502, 'brett.cornwell@sakilacustomer.org')
# (18123, 503, 'angel.barclay@sakilacustomer.org')
# (18124, 503, 'angel.barclay@sakilacustomer.org')
# (18125, 503, 'angel.barclay@sakilacustomer.org')
# (18126, 504, 'nathaniel.adam@sakilacustomer.org')
# (18127, 504, 'nathaniel.adam@sakilacustomer.org')
# (18128, 505, 'rafael.abney@sakilacustomer.org')
# (18129, 505, 'rafael.abney@sakilacustomer.org')
# (18130, 505, 'rafael.abney@sakilacustomer.org')
# (18131, 505, 'rafael.abney@sakilacustomer.org')
# (18132, 506, 'leslie.seward@sakilacustomer.org')
# (18133, 506, 'leslie.seward@sakilacustomer.org')
# (18134, 506, 'leslie.seward@sakilacustomer.org')
# (18135, 506, 'leslie.seward@sakilacustomer.org')
# (18136, 506, 'leslie.seward@sakilacustomer.org')
# (18137, 507, 'edgar.rhoads@sakilacustomer.org')
# (18138, 507, 'edgar.rhoads@sakilacustomer.org')
# (18139, 507, 'edgar.rhoads@sakilacustomer.org')
# (18140, 508, 'milton.howland@sakilacustomer.org')
# (18141, 509, 'raul.fortier@sakilacustomer.org')
# (18142, 509, 'raul.fortier@sakilacustomer.org')
# (18143, 510, 'ben.easter@sakilacustomer.org')
# (18144, 510, 'ben.easter@sakilacustomer.org')
# (18145, 510, 'ben.easter@sakilacustomer.org')
# (18146, 510, 'ben.easter@sakilacustomer.org')
# (18147, 510, 'ben.easter@sakilacustomer.org')
# (18148, 510, 'ben.easter@sakilacustomer.org')
# (18149, 510, 'ben.easter@sakilacustomer.org')
# (18150, 510, 'ben.easter@sakilacustomer.org')
# (18151, 511, 'chester.benner@sakilacustomer.org')
# (18152, 511, 'chester.benner@sakilacustomer.org')
# (18153, 511, 'chester.benner@sakilacustomer.org')
# (18154, 511, 'chester.benner@sakilacustomer.org')
# (18155, 512, 'cecil.vines@sakilacustomer.org')
# (18156, 512, 'cecil.vines@sakilacustomer.org')
# (18157, 512, 'cecil.vines@sakilacustomer.org')
# (18158, 513, 'duane.tubbs@sakilacustomer.org')
# (18159, 513, 'duane.tubbs@sakilacustomer.org')
# (18160, 513, 'duane.tubbs@sakilacustomer.org')
# (18161, 514, 'franklin.troutman@sakilacustomer.org')
# (18162, 514, 'franklin.troutman@sakilacustomer.org')
# (18163, 514, 'franklin.troutman@sakilacustomer.org')
# (18164, 514, 'franklin.troutman@sakilacustomer.org')
# (18165, 514, 'franklin.troutman@sakilacustomer.org')
# (18166, 514, 'franklin.troutman@sakilacustomer.org')
# (18167, 515, 'andre.rapp@sakilacustomer.org')
# (18168, 515, 'andre.rapp@sakilacustomer.org')
# (18169, 515, 'andre.rapp@sakilacustomer.org')
# (18170, 515, 'andre.rapp@sakilacustomer.org')
# (18171, 515, 'andre.rapp@sakilacustomer.org')
# (18172, 515, 'andre.rapp@sakilacustomer.org')
# (18173, 516, 'elmer.noe@sakilacustomer.org')
# (18174, 516, 'elmer.noe@sakilacustomer.org')
# (18175, 516, 'elmer.noe@sakilacustomer.org')
# (18176, 516, 'elmer.noe@sakilacustomer.org')
# (18177, 516, 'elmer.noe@sakilacustomer.org')
# (18178, 516, 'elmer.noe@sakilacustomer.org')
# (18179, 517, 'brad.mccurdy@sakilacustomer.org')
# (18180, 517, 'brad.mccurdy@sakilacustomer.org')
# (18181, 517, 'brad.mccurdy@sakilacustomer.org')
# (18182, 517, 'brad.mccurdy@sakilacustomer.org')
# (18183, 517, 'brad.mccurdy@sakilacustomer.org')
# (18184, 518, 'gabriel.harder@sakilacustomer.org')
# (18185, 518, 'gabriel.harder@sakilacustomer.org')
# (18186, 519, 'ron.deluca@sakilacustomer.org')
# (18187, 519, 'ron.deluca@sakilacustomer.org')
# (18188, 519, 'ron.deluca@sakilacustomer.org')
# (18189, 520, 'mitchell.westmoreland@sakilacustomer.org')
# (18190, 520, 'mitchell.westmoreland@sakilacustomer.org')
# (18191, 520, 'mitchell.westmoreland@sakilacustomer.org')
# (18192, 521, 'roland.south@sakilacustomer.org')
# (18193, 521, 'roland.south@sakilacustomer.org')
# (18194, 522, 'arnold.havens@sakilacustomer.org')
# (18195, 522, 'arnold.havens@sakilacustomer.org')
# (18196, 522, 'arnold.havens@sakilacustomer.org')
# (18197, 522, 'arnold.havens@sakilacustomer.org')
# (18198, 523, 'harvey.guajardo@sakilacustomer.org')
# (18199, 523, 'harvey.guajardo@sakilacustomer.org')
# (18200, 523, 'harvey.guajardo@sakilacustomer.org')
# (18201, 523, 'harvey.guajardo@sakilacustomer.org')
# (18202, 524, 'jared.ely@sakilacustomer.org')
# (18203, 524, 'jared.ely@sakilacustomer.org')
# (18204, 524, 'jared.ely@sakilacustomer.org')
# (18205, 525, 'adrian.clary@sakilacustomer.org')
# (18206, 526, 'karl.seal@sakilacustomer.org')
# (18207, 526, 'karl.seal@sakilacustomer.org')
# (18208, 526, 'karl.seal@sakilacustomer.org')
# (18209, 526, 'karl.seal@sakilacustomer.org')
# (18210, 526, 'karl.seal@sakilacustomer.org')
# (18211, 526, 'karl.seal@sakilacustomer.org')
# (18212, 526, 'karl.seal@sakilacustomer.org')
# (18213, 526, 'karl.seal@sakilacustomer.org')
# (18214, 526, 'karl.seal@sakilacustomer.org')
# (18215, 527, 'cory.meehan@sakilacustomer.org')
# (18216, 527, 'cory.meehan@sakilacustomer.org')
# (18217, 527, 'cory.meehan@sakilacustomer.org')
# (18218, 527, 'cory.meehan@sakilacustomer.org')
# (18219, 528, 'claude.herzog@sakilacustomer.org')
# (18220, 528, 'claude.herzog@sakilacustomer.org')
# (18221, 529, 'erik.guillen@sakilacustomer.org')
# (18222, 529, 'erik.guillen@sakilacustomer.org')
# (18223, 529, 'erik.guillen@sakilacustomer.org')
# (18224, 530, 'darryl.ashcraft@sakilacustomer.org')
# (18225, 530, 'darryl.ashcraft@sakilacustomer.org')
# (18226, 530, 'darryl.ashcraft@sakilacustomer.org')
# (18227, 531, 'jamie.waugh@sakilacustomer.org')
# (18228, 532, 'neil.renner@sakilacustomer.org')
# (18229, 532, 'neil.renner@sakilacustomer.org')
# (18230, 533, 'jessie.milam@sakilacustomer.org')
# (18231, 533, 'jessie.milam@sakilacustomer.org')
# (18232, 533, 'jessie.milam@sakilacustomer.org')
# (18233, 533, 'jessie.milam@sakilacustomer.org')
# (18234, 533, 'jessie.milam@sakilacustomer.org')
# (18235, 533, 'jessie.milam@sakilacustomer.org')
# (18236, 534, 'christian.jung@sakilacustomer.org')
# (18237, 534, 'christian.jung@sakilacustomer.org')
# (18238, 534, 'christian.jung@sakilacustomer.org')
# (18239, 534, 'christian.jung@sakilacustomer.org')
# (18240, 534, 'christian.jung@sakilacustomer.org')
# (18241, 535, 'javier.elrod@sakilacustomer.org')
# (18242, 535, 'javier.elrod@sakilacustomer.org')
# (18243, 536, 'fernando.churchill@sakilacustomer.org')
# (18244, 536, 'fernando.churchill@sakilacustomer.org')
# (18245, 536, 'fernando.churchill@sakilacustomer.org')
# (18246, 537, 'clinton.buford@sakilacustomer.org')
# (18247, 537, 'clinton.buford@sakilacustomer.org')
# (18248, 537, 'clinton.buford@sakilacustomer.org')
# (18249, 537, 'clinton.buford@sakilacustomer.org')
# (18250, 538, 'ted.breaux@sakilacustomer.org')
# (18251, 538, 'ted.breaux@sakilacustomer.org')
# (18252, 538, 'ted.breaux@sakilacustomer.org')
# (18253, 538, 'ted.breaux@sakilacustomer.org')
# (18254, 539, 'mathew.bolin@sakilacustomer.org')
# (18255, 539, 'mathew.bolin@sakilacustomer.org')
# (18256, 539, 'mathew.bolin@sakilacustomer.org')
# (18257, 540, 'tyrone.asher@sakilacustomer.org')
# (18258, 540, 'tyrone.asher@sakilacustomer.org')
# (18259, 540, 'tyrone.asher@sakilacustomer.org')
# (18260, 540, 'tyrone.asher@sakilacustomer.org')
# (18261, 540, 'tyrone.asher@sakilacustomer.org')
# (18262, 541, 'darren.windham@sakilacustomer.org')
# (18263, 541, 'darren.windham@sakilacustomer.org')
# (18264, 542, 'lonnie.tirado@sakilacustomer.org')
# (18265, 542, 'lonnie.tirado@sakilacustomer.org')
# (18266, 543, 'lance.pemberton@sakilacustomer.org')
# (18267, 543, 'lance.pemberton@sakilacustomer.org')
# (18268, 543, 'lance.pemberton@sakilacustomer.org')
# (18269, 543, 'lance.pemberton@sakilacustomer.org')
# (18270, 543, 'lance.pemberton@sakilacustomer.org')
# (18271, 544, 'cody.nolen@sakilacustomer.org')
# (18272, 544, 'cody.nolen@sakilacustomer.org')
# (18273, 544, 'cody.nolen@sakilacustomer.org')
# (18274, 544, 'cody.nolen@sakilacustomer.org')
# (18275, 545, 'julio.noland@sakilacustomer.org')
# (18276, 546, 'kelly.knott@sakilacustomer.org')
# (18277, 546, 'kelly.knott@sakilacustomer.org')
# (18278, 546, 'kelly.knott@sakilacustomer.org')
# (18279, 546, 'kelly.knott@sakilacustomer.org')
# (18280, 547, 'kurt.emmons@sakilacustomer.org')
# (18281, 548, 'allan.cornish@sakilacustomer.org')
# (18282, 548, 'allan.cornish@sakilacustomer.org')
# (18283, 548, 'allan.cornish@sakilacustomer.org')
# (18284, 549, 'nelson.christenson@sakilacustomer.org')
# (18285, 550, 'guy.brownlee@sakilacustomer.org')
# (18286, 550, 'guy.brownlee@sakilacustomer.org')
# (18287, 550, 'guy.brownlee@sakilacustomer.org')
# (18288, 550, 'guy.brownlee@sakilacustomer.org')
# (18289, 550, 'guy.brownlee@sakilacustomer.org')
# (18290, 550, 'guy.brownlee@sakilacustomer.org')
# (18291, 551, 'clayton.barbee@sakilacustomer.org')
# (18292, 551, 'clayton.barbee@sakilacustomer.org')
# (18293, 552, 'hugh.waldrop@sakilacustomer.org')
# (18294, 552, 'hugh.waldrop@sakilacustomer.org')
# (18295, 553, 'max.pitt@sakilacustomer.org')
# (18296, 553, 'max.pitt@sakilacustomer.org')
# (18297, 553, 'max.pitt@sakilacustomer.org')
# (18298, 554, 'dwayne.olvera@sakilacustomer.org')
# (18299, 554, 'dwayne.olvera@sakilacustomer.org')
# (18300, 554, 'dwayne.olvera@sakilacustomer.org')
# (18301, 554, 'dwayne.olvera@sakilacustomer.org')
# (18302, 555, 'dwight.lombardi@sakilacustomer.org')
# (18303, 556, 'armando.gruber@sakilacustomer.org')
# (18304, 556, 'armando.gruber@sakilacustomer.org')
# (18305, 556, 'armando.gruber@sakilacustomer.org')
# (18306, 556, 'armando.gruber@sakilacustomer.org')
# (18307, 556, 'armando.gruber@sakilacustomer.org')
# (18308, 557, 'felix.gaffney@sakilacustomer.org')
# (18309, 557, 'felix.gaffney@sakilacustomer.org')
# (18310, 557, 'felix.gaffney@sakilacustomer.org')
# (18311, 558, 'jimmie.eggleston@sakilacustomer.org')
# (18312, 558, 'jimmie.eggleston@sakilacustomer.org')
# (18313, 558, 'jimmie.eggleston@sakilacustomer.org')
# (18314, 558, 'jimmie.eggleston@sakilacustomer.org')
# (18315, 558, 'jimmie.eggleston@sakilacustomer.org')
# (18316, 559, 'everett.banda@sakilacustomer.org')
# (18317, 559, 'everett.banda@sakilacustomer.org')
# (18318, 559, 'everett.banda@sakilacustomer.org')
# (18319, 559, 'everett.banda@sakilacustomer.org')
# (18320, 560, 'jordan.archuleta@sakilacustomer.org')
# (18321, 560, 'jordan.archuleta@sakilacustomer.org')
# (18322, 561, 'ian.still@sakilacustomer.org')
# (18323, 561, 'ian.still@sakilacustomer.org')
# (18324, 561, 'ian.still@sakilacustomer.org')
# (18325, 561, 'ian.still@sakilacustomer.org')
# (18326, 561, 'ian.still@sakilacustomer.org')
# (18327, 561, 'ian.still@sakilacustomer.org')
# (18328, 561, 'ian.still@sakilacustomer.org')
# (18329, 561, 'ian.still@sakilacustomer.org')
# (18330, 561, 'ian.still@sakilacustomer.org')
# (18331, 562, 'wallace.slone@sakilacustomer.org')
# (18332, 562, 'wallace.slone@sakilacustomer.org')
# (18333, 562, 'wallace.slone@sakilacustomer.org')
# (18334, 562, 'wallace.slone@sakilacustomer.org')
# (18335, 563, 'ken.prewitt@sakilacustomer.org')
# (18336, 563, 'ken.prewitt@sakilacustomer.org')
# (18337, 564, 'bob.pfeiffer@sakilacustomer.org')
# (18338, 565, 'jaime.nettles@sakilacustomer.org')
# (18339, 565, 'jaime.nettles@sakilacustomer.org')
# (18340, 565, 'jaime.nettles@sakilacustomer.org')
# (18341, 566, 'casey.mena@sakilacustomer.org')
# (18342, 566, 'casey.mena@sakilacustomer.org')
# (18343, 566, 'casey.mena@sakilacustomer.org')
# (18344, 566, 'casey.mena@sakilacustomer.org')
# (18345, 567, 'alfredo.mcadams@sakilacustomer.org')
# (18346, 567, 'alfredo.mcadams@sakilacustomer.org')
# (18347, 568, 'alberto.henning@sakilacustomer.org')
# (18348, 568, 'alberto.henning@sakilacustomer.org')
# (18349, 568, 'alberto.henning@sakilacustomer.org')
# (18350, 568, 'alberto.henning@sakilacustomer.org')
# (18351, 568, 'alberto.henning@sakilacustomer.org')
# (18352, 569, 'dave.gardiner@sakilacustomer.org')
# (18353, 569, 'dave.gardiner@sakilacustomer.org')
# (18354, 570, 'ivan.cromwell@sakilacustomer.org')
# (18355, 570, 'ivan.cromwell@sakilacustomer.org')
# (18356, 570, 'ivan.cromwell@sakilacustomer.org')
# (18357, 570, 'ivan.cromwell@sakilacustomer.org')
# (18358, 570, 'ivan.cromwell@sakilacustomer.org')
# (18359, 570, 'ivan.cromwell@sakilacustomer.org')
# (18360, 570, 'ivan.cromwell@sakilacustomer.org')
# (18361, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18362, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18363, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18364, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18365, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18366, 571, 'johnnie.chisholm@sakilacustomer.org')
# (18367, 572, 'sidney.burleson@sakilacustomer.org')
# (18368, 572, 'sidney.burleson@sakilacustomer.org')
# (18369, 572, 'sidney.burleson@sakilacustomer.org')
# (18370, 573, 'byron.box@sakilacustomer.org')
# (18371, 573, 'byron.box@sakilacustomer.org')
# (18372, 573, 'byron.box@sakilacustomer.org')
# (18373, 573, 'byron.box@sakilacustomer.org')
# (18374, 574, 'julian.vest@sakilacustomer.org')
# (18375, 574, 'julian.vest@sakilacustomer.org')
# (18376, 574, 'julian.vest@sakilacustomer.org')
# (18377, 574, 'julian.vest@sakilacustomer.org')
# (18378, 574, 'julian.vest@sakilacustomer.org')
# (18379, 575, 'isaac.oglesby@sakilacustomer.org')
# (18380, 575, 'isaac.oglesby@sakilacustomer.org')
# (18381, 575, 'isaac.oglesby@sakilacustomer.org')
# (18382, 576, 'morris.mccarter@sakilacustomer.org')
# (18383, 576, 'morris.mccarter@sakilacustomer.org')
# (18384, 576, 'morris.mccarter@sakilacustomer.org')
# (18385, 576, 'morris.mccarter@sakilacustomer.org')
# (18386, 576, 'morris.mccarter@sakilacustomer.org')
# (18387, 576, 'morris.mccarter@sakilacustomer.org')
# (18388, 576, 'morris.mccarter@sakilacustomer.org')
# (18389, 577, 'clifton.malcolm@sakilacustomer.org')
# (18390, 577, 'clifton.malcolm@sakilacustomer.org')
# (18391, 577, 'clifton.malcolm@sakilacustomer.org')
# (18392, 578, 'willard.lumpkin@sakilacustomer.org')
# (18393, 578, 'willard.lumpkin@sakilacustomer.org')
# (18394, 578, 'willard.lumpkin@sakilacustomer.org')
# (18395, 579, 'daryl.larue@sakilacustomer.org')
# (18396, 579, 'daryl.larue@sakilacustomer.org')
# (18397, 579, 'daryl.larue@sakilacustomer.org')
# (18398, 580, 'ross.grey@sakilacustomer.org')
# (18399, 581, 'virgil.wofford@sakilacustomer.org')
# (18400, 581, 'virgil.wofford@sakilacustomer.org')
# (18401, 581, 'virgil.wofford@sakilacustomer.org')
# (18402, 582, 'andy.vanhorn@sakilacustomer.org')
# (18403, 582, 'andy.vanhorn@sakilacustomer.org')
# (18404, 582, 'andy.vanhorn@sakilacustomer.org')
# (18405, 583, 'marshall.thorn@sakilacustomer.org')
# (18406, 583, 'marshall.thorn@sakilacustomer.org')
# (18407, 583, 'marshall.thorn@sakilacustomer.org')
# (18408, 583, 'marshall.thorn@sakilacustomer.org')
# (18409, 583, 'marshall.thorn@sakilacustomer.org')
# (18410, 583, 'marshall.thorn@sakilacustomer.org')
# (18411, 584, 'salvador.teel@sakilacustomer.org')
# (18412, 584, 'salvador.teel@sakilacustomer.org')
# (18413, 585, 'perry.swafford@sakilacustomer.org')
# (18414, 585, 'perry.swafford@sakilacustomer.org')
# (18415, 585, 'perry.swafford@sakilacustomer.org')
# (18416, 585, 'perry.swafford@sakilacustomer.org')
# (18417, 586, 'kirk.stclair@sakilacustomer.org')
# (18418, 586, 'kirk.stclair@sakilacustomer.org')
# (18419, 587, 'sergio.stanfield@sakilacustomer.org')
# (18420, 587, 'sergio.stanfield@sakilacustomer.org')
# (18421, 587, 'sergio.stanfield@sakilacustomer.org')
# (18422, 587, 'sergio.stanfield@sakilacustomer.org')
# (18423, 588, 'marion.ocampo@sakilacustomer.org')
# (18424, 588, 'marion.ocampo@sakilacustomer.org')
# (18425, 588, 'marion.ocampo@sakilacustomer.org')
# (18426, 588, 'marion.ocampo@sakilacustomer.org')
# (18427, 588, 'marion.ocampo@sakilacustomer.org')
# (18428, 589, 'tracy.herrmann@sakilacustomer.org')
# (18429, 589, 'tracy.herrmann@sakilacustomer.org')
# (18430, 589, 'tracy.herrmann@sakilacustomer.org')
# (18431, 589, 'tracy.herrmann@sakilacustomer.org')
# (18432, 589, 'tracy.herrmann@sakilacustomer.org')
# (18433, 590, 'seth.hannon@sakilacustomer.org')
# (18434, 590, 'seth.hannon@sakilacustomer.org')
# (18435, 590, 'seth.hannon@sakilacustomer.org')
# (18436, 590, 'seth.hannon@sakilacustomer.org')
# (18437, 590, 'seth.hannon@sakilacustomer.org')
# (18438, 591, 'kent.arsenault@sakilacustomer.org')
# (18439, 591, 'kent.arsenault@sakilacustomer.org')
# (18440, 591, 'kent.arsenault@sakilacustomer.org')
# (18441, 592, 'terrance.roush@sakilacustomer.org')
# (18442, 592, 'terrance.roush@sakilacustomer.org')
# (18443, 592, 'terrance.roush@sakilacustomer.org')
# (18444, 592, 'terrance.roush@sakilacustomer.org')
# (18445, 592, 'terrance.roush@sakilacustomer.org')
# (18446, 593, 'rene.mcalister@sakilacustomer.org')
# (18447, 593, 'rene.mcalister@sakilacustomer.org')
# (18448, 593, 'rene.mcalister@sakilacustomer.org')
# (18449, 593, 'rene.mcalister@sakilacustomer.org')
# (18450, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18451, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18452, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18453, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18454, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18455, 594, 'eduardo.hiatt@sakilacustomer.org')
# (18456, 595, 'terrence.gunderson@sakilacustomer.org')
# (18457, 595, 'terrence.gunderson@sakilacustomer.org')
# (18458, 596, 'enrique.forsythe@sakilacustomer.org')
# (18459, 596, 'enrique.forsythe@sakilacustomer.org')
# (18460, 597, 'freddie.duggan@sakilacustomer.org')
# (18461, 597, 'freddie.duggan@sakilacustomer.org')
# (18462, 597, 'freddie.duggan@sakilacustomer.org')
# (18463, 598, 'wade.delvalle@sakilacustomer.org')
# (18464, 599, 'austin.cintron@sakilacustomer.org')
# (18465, 599, 'austin.cintron@sakilacustomer.org')
# (18466, 599, 'austin.cintron@sakilacustomer.org')
# (18467, 599, 'austin.cintron@sakilacustomer.org')
# (18468, 202, 'carla.gutierrez@sakilacustomer.org')
# (18469, 202, 'carla.gutierrez@sakilacustomer.org')
# (18470, 202, 'carla.gutierrez@sakilacustomer.org')
# (18471, 202, 'carla.gutierrez@sakilacustomer.org')
# (18472, 203, 'tara.ryan@sakilacustomer.org')
# (18473, 203, 'tara.ryan@sakilacustomer.org')
# (18474, 203, 'tara.ryan@sakilacustomer.org')
# (18475, 203, 'tara.ryan@sakilacustomer.org')
# (18476, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18477, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18478, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18479, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18480, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18481, 204, 'rosemary.schmidt@sakilacustomer.org')
# (18482, 205, 'eileen.carr@sakilacustomer.org')
# (18483, 205, 'eileen.carr@sakilacustomer.org')
# (18484, 205, 'eileen.carr@sakilacustomer.org')
# (18485, 205, 'eileen.carr@sakilacustomer.org')
# (18486, 206, 'terri.vasquez@sakilacustomer.org')
# ...
# (31771, 254, 'maxine.silva@sakilacustomer.org')
# (31772, 254, 'maxine.silva@sakilacustomer.org')
# (31773, 254, 'maxine.silva@sakilacustomer.org')
# (31774, 254, 'maxine.silva@sakilacustomer.org')
# (31775, 254, 'maxine.silva@sakilacustomer.org')
# (31776, 254, 'maxine.silva@sakilacustomer.org')
# (31777, 254, 'maxine.silva@sakilacustomer.org')
# (31778, 254, 'maxine.silva@sakilacustomer.org')
# (31779, 254, 'maxine.silva@sakilacustomer.org')
# (31780, 254, 'maxine.silva@sakilacustomer.org')
# (31781, 254, 'maxine.silva@sakilacustomer.org')
# (31782, 254, 'maxine.silva@sakilacustomer.org')
# (31783, 255, 'irma.pearson@sakilacustomer.org')
# (31784, 255, 'irma.pearson@sakilacustomer.org')
# (31785, 255, 'irma.pearson@sakilacustomer.org')
# (31786, 255, 'irma.pearson@sakilacustomer.org')
# (31787, 255, 'irma.pearson@sakilacustomer.org')
# (31788, 255, 'irma.pearson@sakilacustomer.org')
# (31789, 255, 'irma.pearson@sakilacustomer.org')
# (31790, 256, 'mabel.holland@sakilacustomer.org')
# (31791, 256, 'mabel.holland@sakilacustomer.org')
# (31792, 256, 'mabel.holland@sakilacustomer.org')
# (31793, 256, 'mabel.holland@sakilacustomer.org')
# (31794, 256, 'mabel.holland@sakilacustomer.org')
# (31795, 256, 'mabel.holland@sakilacustomer.org')
# (31796, 257, 'marsha.douglas@sakilacustomer.org')
# (31797, 257, 'marsha.douglas@sakilacustomer.org')
# (31798, 257, 'marsha.douglas@sakilacustomer.org')
# (31799, 257, 'marsha.douglas@sakilacustomer.org')
# (31800, 257, 'marsha.douglas@sakilacustomer.org')
# (31801, 257, 'marsha.douglas@sakilacustomer.org')
# (31802, 257, 'marsha.douglas@sakilacustomer.org')
# (31803, 257, 'marsha.douglas@sakilacustomer.org')
# (31804, 257, 'marsha.douglas@sakilacustomer.org')
# (31805, 257, 'marsha.douglas@sakilacustomer.org')
# (31806, 257, 'marsha.douglas@sakilacustomer.org')
# (31807, 257, 'marsha.douglas@sakilacustomer.org')
# (31808, 257, 'marsha.douglas@sakilacustomer.org')
# (31809, 257, 'marsha.douglas@sakilacustomer.org')
# (31810, 257, 'marsha.douglas@sakilacustomer.org')
# (31811, 257, 'marsha.douglas@sakilacustomer.org')
# (31812, 257, 'marsha.douglas@sakilacustomer.org')
# (31813, 257, 'marsha.douglas@sakilacustomer.org')
# (31814, 258, 'myrtle.fleming@sakilacustomer.org')
# (31815, 258, 'myrtle.fleming@sakilacustomer.org')
# (31816, 258, 'myrtle.fleming@sakilacustomer.org')
# (31817, 258, 'myrtle.fleming@sakilacustomer.org')
# (31818, 258, 'myrtle.fleming@sakilacustomer.org')
# (31819, 258, 'myrtle.fleming@sakilacustomer.org')
# (31820, 258, 'myrtle.fleming@sakilacustomer.org')
# (31821, 258, 'myrtle.fleming@sakilacustomer.org')
# (31822, 258, 'myrtle.fleming@sakilacustomer.org')
# (31823, 258, 'myrtle.fleming@sakilacustomer.org')
# (31824, 259, 'lena.jensen@sakilacustomer.org')
# (31825, 259, 'lena.jensen@sakilacustomer.org')
# (31826, 259, 'lena.jensen@sakilacustomer.org')
# (31827, 259, 'lena.jensen@sakilacustomer.org')
# (31828, 259, 'lena.jensen@sakilacustomer.org')
# (31829, 259, 'lena.jensen@sakilacustomer.org')
# (31830, 259, 'lena.jensen@sakilacustomer.org')
# (31831, 259, 'lena.jensen@sakilacustomer.org')
# (31832, 259, 'lena.jensen@sakilacustomer.org')
# (31833, 259, 'lena.jensen@sakilacustomer.org')
# (31834, 546, 'kelly.knott@sakilacustomer.org')
# (31835, 260, 'christy.vargas@sakilacustomer.org')
# (31836, 260, 'christy.vargas@sakilacustomer.org')
# (31837, 260, 'christy.vargas@sakilacustomer.org')
# (31838, 260, 'christy.vargas@sakilacustomer.org')
# (31839, 260, 'christy.vargas@sakilacustomer.org')
# (31840, 260, 'christy.vargas@sakilacustomer.org')
# (31841, 260, 'christy.vargas@sakilacustomer.org')
# (31842, 260, 'christy.vargas@sakilacustomer.org')
# (31843, 260, 'christy.vargas@sakilacustomer.org')
# (31844, 260, 'christy.vargas@sakilacustomer.org')
# (31845, 260, 'christy.vargas@sakilacustomer.org')
# (31846, 260, 'christy.vargas@sakilacustomer.org')
# (31847, 261, 'deanna.byrd@sakilacustomer.org')
# (31848, 261, 'deanna.byrd@sakilacustomer.org')
# (31849, 261, 'deanna.byrd@sakilacustomer.org')
# (31850, 261, 'deanna.byrd@sakilacustomer.org')
# (31851, 261, 'deanna.byrd@sakilacustomer.org')
# (31852, 261, 'deanna.byrd@sakilacustomer.org')
# (31853, 261, 'deanna.byrd@sakilacustomer.org')
# (31854, 262, 'patsy.davidson@sakilacustomer.org')
# (31855, 262, 'patsy.davidson@sakilacustomer.org')
# (31856, 262, 'patsy.davidson@sakilacustomer.org')
# (31857, 262, 'patsy.davidson@sakilacustomer.org')
# (31858, 262, 'patsy.davidson@sakilacustomer.org')
# (31859, 262, 'patsy.davidson@sakilacustomer.org')
# (31860, 262, 'patsy.davidson@sakilacustomer.org')
# (31861, 262, 'patsy.davidson@sakilacustomer.org')
# (31862, 262, 'patsy.davidson@sakilacustomer.org')
# (31863, 262, 'patsy.davidson@sakilacustomer.org')
# (31864, 262, 'patsy.davidson@sakilacustomer.org')
# (31865, 263, 'hilda.hopkins@sakilacustomer.org')
# (31866, 263, 'hilda.hopkins@sakilacustomer.org')
# (31867, 263, 'hilda.hopkins@sakilacustomer.org')
# (31868, 263, 'hilda.hopkins@sakilacustomer.org')
# (31869, 263, 'hilda.hopkins@sakilacustomer.org')
# (31870, 263, 'hilda.hopkins@sakilacustomer.org')
# (31871, 263, 'hilda.hopkins@sakilacustomer.org')
# (31872, 263, 'hilda.hopkins@sakilacustomer.org')
# (31873, 263, 'hilda.hopkins@sakilacustomer.org')
# (31874, 263, 'hilda.hopkins@sakilacustomer.org')
# (31875, 263, 'hilda.hopkins@sakilacustomer.org')
# (31876, 263, 'hilda.hopkins@sakilacustomer.org')
# (31877, 263, 'hilda.hopkins@sakilacustomer.org')
# (31878, 264, 'gwendolyn.may@sakilacustomer.org')
# (31879, 264, 'gwendolyn.may@sakilacustomer.org')
# (31880, 264, 'gwendolyn.may@sakilacustomer.org')
# (31881, 264, 'gwendolyn.may@sakilacustomer.org')
# (31882, 264, 'gwendolyn.may@sakilacustomer.org')
# (31883, 264, 'gwendolyn.may@sakilacustomer.org')
# (31884, 264, 'gwendolyn.may@sakilacustomer.org')
# (31885, 264, 'gwendolyn.may@sakilacustomer.org')
# (31886, 264, 'gwendolyn.may@sakilacustomer.org')
# (31887, 264, 'gwendolyn.may@sakilacustomer.org')
# (31888, 264, 'gwendolyn.may@sakilacustomer.org')
# (31889, 264, 'gwendolyn.may@sakilacustomer.org')
# (31890, 265, 'jennie.terry@sakilacustomer.org')
# (31891, 265, 'jennie.terry@sakilacustomer.org')
# (31892, 265, 'jennie.terry@sakilacustomer.org')
# (31893, 265, 'jennie.terry@sakilacustomer.org')
# (31894, 265, 'jennie.terry@sakilacustomer.org')
# (31895, 265, 'jennie.terry@sakilacustomer.org')
# (31896, 265, 'jennie.terry@sakilacustomer.org')
# (31897, 265, 'jennie.terry@sakilacustomer.org')
# (31898, 265, 'jennie.terry@sakilacustomer.org')
# (31899, 265, 'jennie.terry@sakilacustomer.org')
# (31900, 265, 'jennie.terry@sakilacustomer.org')
# (31901, 265, 'jennie.terry@sakilacustomer.org')
# (31902, 265, 'jennie.terry@sakilacustomer.org')
# (31903, 265, 'jennie.terry@sakilacustomer.org')
# (31904, 265, 'jennie.terry@sakilacustomer.org')
# (31905, 265, 'jennie.terry@sakilacustomer.org')
# (31906, 266, 'nora.herrera@sakilacustomer.org')
# (31907, 266, 'nora.herrera@sakilacustomer.org')
# (31908, 266, 'nora.herrera@sakilacustomer.org')
# (31909, 266, 'nora.herrera@sakilacustomer.org')
# (31910, 266, 'nora.herrera@sakilacustomer.org')
# (31911, 267, 'margie.wade@sakilacustomer.org')
# (31912, 267, 'margie.wade@sakilacustomer.org')
# (31913, 267, 'margie.wade@sakilacustomer.org')
# (31914, 267, 'margie.wade@sakilacustomer.org')
# (31915, 267, 'margie.wade@sakilacustomer.org')
# (31916, 267, 'margie.wade@sakilacustomer.org')
# (31917, 267, 'margie.wade@sakilacustomer.org')
# (31918, 267, 'margie.wade@sakilacustomer.org')
# (31919, 269, 'cassandra.walters@sakilacustomer.org')
# (31920, 269, 'cassandra.walters@sakilacustomer.org')
# (31921, 274, 'naomi.jennings@sakilacustomer.org')
# (31922, 279, 'dianne.shelton@sakilacustomer.org')
# (31923, 282, 'jenny.castro@sakilacustomer.org')
# (31924, 284, 'sonia.gregory@sakilacustomer.org')
# (31925, 284, 'sonia.gregory@sakilacustomer.org')
# (31926, 287, 'becky.miles@sakilacustomer.org')
# (31927, 295, 'daisy.bates@sakilacustomer.org')
# (31928, 296, 'ramona.hale@sakilacustomer.org')
# (31929, 300, 'john.farnsworth@sakilacustomer.org')
# (31930, 315, 'kenneth.gooden@sakilacustomer.org')
# (31931, 317, 'edward.baugh@sakilacustomer.org')
# (31932, 324, 'gary.coy@sakilacustomer.org')
# (31933, 327, 'larry.thrasher@sakilacustomer.org')
# (31934, 330, 'scott.shelley@sakilacustomer.org')
# (31935, 334, 'raymond.mcwhorter@sakilacustomer.org')
# (31936, 335, 'gregory.mauldin@sakilacustomer.org')
# (31937, 336, 'joshua.mark@sakilacustomer.org')
# (31938, 337, 'jerry.jordon@sakilacustomer.org')
# (31939, 349, 'joe.gilliland@sakilacustomer.org')
# (31940, 352, 'albert.crouse@sakilacustomer.org')
# (31941, 354, 'justin.ngo@sakilacustomer.org')
# (31942, 354, 'justin.ngo@sakilacustomer.org')
# (31943, 355, 'terry.grissom@sakilacustomer.org')
# (31944, 359, 'willie.markham@sakilacustomer.org')
# (31945, 361, 'lawrence.lawton@sakilacustomer.org')
# (31946, 361, 'lawrence.lawton@sakilacustomer.org')
# (31947, 366, 'brandon.huey@sakilacustomer.org')
# (31948, 369, 'fred.wheat@sakilacustomer.org')
# (31949, 373, 'louis.leone@sakilacustomer.org')
# (31950, 374, 'jeremy.hurtado@sakilacustomer.org')
# (31951, 388, 'craig.morrell@sakilacustomer.org')
# (31952, 394, 'chris.brothers@sakilacustomer.org')
# (31953, 405, 'leonard.schofield@sakilacustomer.org')
# (31954, 410, 'curtis.irby@sakilacustomer.org')
# (31955, 411, 'norman.currier@sakilacustomer.org')
# (31956, 412, 'allen.butterfield@sakilacustomer.org')
# (31957, 417, 'travis.estep@sakilacustomer.org')
# (31958, 421, 'lee.hawks@sakilacustomer.org')
# (31959, 422, 'melvin.ellington@sakilacustomer.org')
# (31960, 424, 'kyle.spurlock@sakilacustomer.org')
# (31961, 431, 'joel.francisco@sakilacustomer.org')
# (31962, 438, 'barry.lovelace@sakilacustomer.org')
# (31963, 440, 'bernard.colby@sakilacustomer.org')
# (31964, 441, 'mario.cheatham@sakilacustomer.org')
# (31965, 448, 'miguel.betancourt@sakilacustomer.org')
# (31966, 448, 'miguel.betancourt@sakilacustomer.org')
# (31967, 450, 'jay.robb@sakilacustomer.org')
# (31968, 452, 'tom.milner@sakilacustomer.org')
# (31969, 457, 'bill.gavin@sakilacustomer.org')
# (31970, 457, 'bill.gavin@sakilacustomer.org')
# (31971, 472, 'greg.robins@sakilacustomer.org')
# (31972, 474, 'dustin.gillette@sakilacustomer.org')
# (31973, 476, 'derrick.bourque@sakilacustomer.org')
# (31974, 479, 'zachary.hite@sakilacustomer.org')
# (31975, 493, 'brent.harkins@sakilacustomer.org')
# (31976, 495, 'charlie.bess@sakilacustomer.org')
# (31977, 496, 'tyler.wren@sakilacustomer.org')
# (31978, 497, 'gilbert.sledge@sakilacustomer.org')
# (31979, 505, 'rafael.abney@sakilacustomer.org')
# (31980, 508, 'milton.howland@sakilacustomer.org')
# (31981, 512, 'cecil.vines@sakilacustomer.org')
# (31982, 516, 'elmer.noe@sakilacustomer.org')
# (31983, 516, 'elmer.noe@sakilacustomer.org')
# (31984, 521, 'roland.south@sakilacustomer.org')
# (31985, 525, 'adrian.clary@sakilacustomer.org')
# (31986, 527, 'cory.meehan@sakilacustomer.org')
# (31987, 530, 'darryl.ashcraft@sakilacustomer.org')
# (31988, 532, 'neil.renner@sakilacustomer.org')
# (31989, 533, 'jessie.milam@sakilacustomer.org')
# (31990, 534, 'christian.jung@sakilacustomer.org')
# (31991, 537, 'clinton.buford@sakilacustomer.org')
# (31992, 548, 'allan.cornish@sakilacustomer.org')
# (31993, 550, 'guy.brownlee@sakilacustomer.org')
# (31994, 557, 'felix.gaffney@sakilacustomer.org')
# (31995, 560, 'jordan.archuleta@sakilacustomer.org')
# (31996, 560, 'jordan.archuleta@sakilacustomer.org')
# (31997, 561, 'ian.still@sakilacustomer.org')
# (31998, 568, 'alberto.henning@sakilacustomer.org')
# (31999, 570, 'ivan.cromwell@sakilacustomer.org')
# (32000, 576, 'morris.mccarter@sakilacustomer.org')
# (32001, 576, 'morris.mccarter@sakilacustomer.org')
# (32002, 579, 'daryl.larue@sakilacustomer.org')
# (32003, 582, 'andy.vanhorn@sakilacustomer.org')
# (32004, 585, 'perry.swafford@sakilacustomer.org')
# (32005, 587, 'sergio.stanfield@sakilacustomer.org')
# (32006, 590, 'seth.hannon@sakilacustomer.org')
# (32007, 592, 'terrance.roush@sakilacustomer.org')
# (32008, 596, 'enrique.forsythe@sakilacustomer.org')
# (32009, 597, 'freddie.duggan@sakilacustomer.org')
# (32010, 5, 'elizabeth.brown@sakilacustomer.org')
# (32011, 9, 'margaret.moore@sakilacustomer.org')
# (32012, 11, 'lisa.anderson@sakilacustomer.org')
# (32013, 14, 'betty.white@sakilacustomer.org')
# (32014, 15, 'helen.harris@sakilacustomer.org')
# (32015, 15, 'helen.harris@sakilacustomer.org')
# (32016, 21, 'michelle.clark@sakilacustomer.org')
# (32017, 22, 'laura.rodriguez@sakilacustomer.org')
# (32018, 23, 'sarah.lewis@sakilacustomer.org')
# (32019, 28, 'cynthia.young@sakilacustomer.org')
# (32020, 29, 'angela.hernandez@sakilacustomer.org')
# (32021, 33, 'anna.hill@sakilacustomer.org')
# (32022, 41, 'stephanie.mitchell@sakilacustomer.org')
# (32023, 42, 'carolyn.perez@sakilacustomer.org')
# (32024, 42, 'carolyn.perez@sakilacustomer.org')
# (32025, 43, 'christine.roberts@sakilacustomer.org')
# (32026, 43, 'christine.roberts@sakilacustomer.org')
# (32027, 44, 'marie.turner@sakilacustomer.org')
# (32028, 52, 'julie.sanchez@sakilacustomer.org')
# (32029, 53, 'heather.morris@sakilacustomer.org')
# (32030, 53, 'heather.morris@sakilacustomer.org')
# (32031, 56, 'gloria.cook@sakilacustomer.org')
# (32032, 58, 'jean.bell@sakilacustomer.org')
# (32033, 60, 'mildred.bailey@sakilacustomer.org')
# (32034, 60, 'mildred.bailey@sakilacustomer.org')
# (32035, 64, 'judith.cox@sakilacustomer.org')
# (32036, 69, 'judy.gray@sakilacustomer.org')
# (32037, 73, 'beverly.brooks@sakilacustomer.org')
# (32038, 75, 'tammy.sanders@sakilacustomer.org')
# (32039, 75, 'tammy.sanders@sakilacustomer.org')
# (32040, 75, 'tammy.sanders@sakilacustomer.org')
# (32041, 80, 'marilyn.ross@sakilacustomer.org')
# (32042, 83, 'louise.jenkins@sakilacustomer.org')
# (32043, 87, 'wanda.patterson@sakilacustomer.org')
# (32044, 91, 'lois.butler@sakilacustomer.org')
# (32045, 94, 'norma.gonzales@sakilacustomer.org')
# (32046, 99, 'emily.diaz@sakilacustomer.org')
# (32047, 100, 'robin.hayes@sakilacustomer.org')
# (32048, 101, 'peggy.myers@sakilacustomer.org')
# (32049, 107, 'florence.woods@sakilacustomer.org')
# (32050, 107, 'florence.woods@sakilacustomer.org')
# (32051, 108, 'tracy.cole@sakilacustomer.org')
# (32052, 111, 'carmen.owens@sakilacustomer.org')
# (32053, 114, 'grace.ellis@sakilacustomer.org')
# (32054, 115, 'wendy.harrison@sakilacustomer.org')
# (32055, 120, 'sylvia.ortiz@sakilacustomer.org')
# (32056, 135, 'juanita.mason@sakilacustomer.org')
# (32057, 142, 'april.burns@sakilacustomer.org')
# (32058, 152, 'alicia.mills@sakilacustomer.org')
# (32059, 155, 'gail.knight@sakilacustomer.org')
# (32060, 155, 'gail.knight@sakilacustomer.org')
# (32061, 162, 'lauren.hudson@sakilacustomer.org')
# (32062, 163, 'cathy.spencer@sakilacustomer.org')
# (32063, 163, 'cathy.spencer@sakilacustomer.org')
# (32064, 168, 'regina.berry@sakilacustomer.org')
# (32065, 175, 'annette.olson@sakilacustomer.org')
# (32066, 175, 'annette.olson@sakilacustomer.org')
# (32067, 178, 'marion.snyder@sakilacustomer.org')
# (32068, 180, 'stacy.cunningham@sakilacustomer.org')
# (32069, 181, 'ana.bradley@sakilacustomer.org')
# (32070, 186, 'holly.fox@sakilacustomer.org')
# (32071, 188, 'melanie.armstrong@sakilacustomer.org')
# (32072, 190, 'yolanda.weaver@sakilacustomer.org')
# (32073, 191, 'jeanette.greene@sakilacustomer.org')
# (32074, 192, 'laurie.lawrence@sakilacustomer.org')
# (32075, 193, 'katie.elliott@sakilacustomer.org')
# (32076, 199, 'beth.franklin@sakilacustomer.org')
# (32077, 200, 'jeanne.lawson@sakilacustomer.org')
# (32078, 208, 'lucy.wheeler@sakilacustomer.org')
# (32079, 208, 'lucy.wheeler@sakilacustomer.org')
# (32080, 211, 'stacey.montgomery@sakilacustomer.org')
# (32081, 213, 'gina.williamson@sakilacustomer.org')
# (32082, 214, 'kristin.johnston@sakilacustomer.org')
# (32083, 215, 'jessie.banks@sakilacustomer.org')
# (32084, 216, 'natalie.meyer@sakilacustomer.org')
# (32085, 216, 'natalie.meyer@sakilacustomer.org')
# (32086, 219, 'willie.howell@sakilacustomer.org')
# (32087, 227, 'colleen.burton@sakilacustomer.org')
# (32088, 228, 'allison.stanley@sakilacustomer.org')
# (32089, 228, 'allison.stanley@sakilacustomer.org')
# (32090, 229, 'tamara.nguyen@sakilacustomer.org')
# (32091, 234, 'claudia.fuller@sakilacustomer.org')
# (32092, 236, 'marcia.dean@sakilacustomer.org')
# (32093, 244, 'viola.hanson@sakilacustomer.org')
# (32094, 245, 'courtney.day@sakilacustomer.org')
# (32095, 251, 'vickie.brewer@sakilacustomer.org')
# (32096, 252, 'mattie.hoffman@sakilacustomer.org')
# (32097, 263, 'hilda.hopkins@sakilacustomer.org')
# (32098, 264, 'gwendolyn.may@sakilacustomer.org')

# %% [markdown]
# #### FULL OUTER JOIN clause

# %%
# Get data (set of records / rows) that is present in tables together
# All the payments are associated with the current customer and all customers are associated with some historical payments
select_records = """
SELECT *
FROM customer
FULL OUTER JOIN payment
ON customer.customer_id = payment.customer_id
WHERE customer.customer_id IS null OR payment.payment_id IS null
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful

# %% [markdown]
# #### LEFT OUTER JOIN clause

# %%
# Get all data (set of records / rows) that is present in the LEFT table
# Show the film that you have information about, but they are not in the inventory
select_records = """
SELECT film.film_id, title, inventory_id, store_id
FROM film
LEFT OUTER JOIN inventory
ON film.film_id = inventory.film_id
WHERE inventory.film_id IS null
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# (14, 'Alice Fantasia', None, None)
# (33, 'Apollo Teen', None, None)
# (36, 'Argonauts Town', None, None)
# (38, 'Ark Ridgemont', None, None)
# (41, 'Arsenic Independence', None, None)
# (87, 'Boondock Ballroom', None, None)
# (108, 'Butch Panther', None, None)
# (128, 'Catch Amistad', None, None)
# (144, 'Chinatown Gladiator', None, None)
# (148, 'Chocolate Duck', None, None)
# (171, 'Commandments Express', None, None)
# (192, 'Crossing Divorce', None, None)
# (195, 'Crowds Telemark', None, None)
# (198, 'Crystal Breaking', None, None)
# (217, 'Dazed Punk', None, None)
# (221, 'Deliverance Mulholland', None, None)
# (318, 'Firehouse Vietnam', None, None)
# (325, 'Floats Garden', None, None)
# (332, 'Frankenstein Stranger', None, None)
# (359, 'Gladiator Westward', None, None)
# (386, 'Gump Date', None, None)
# (404, 'Hate Handicap', None, None)
# (419, 'Hocus Frida', None, None)
# (495, 'Kentuckian Giant', None, None)
# (497, 'Kill Brotherhood', None, None)
# (607, 'Muppet Mile', None, None)
# (642, 'Order Betrayed', None, None)
# (669, 'Pearl Destiny', None, None)
# (671, 'Perdition Fargo', None, None)
# (701, 'Psycho Shrunk', None, None)
# (712, 'Raiders Antitrust', None, None)
# (713, 'Rainbow Shock', None, None)
# (742, 'Roof Champion', None, None)
# (801, 'Sister Freddy', None, None)
# (802, 'Sky Miracle', None, None)
# (860, 'Suicides Silence', None, None)
# (874, 'Tadpole Park', None, None)
# (909, 'Treasure Command', None, None)
# (943, 'Villain Desperate', None, None)
# (950, 'Volume House', None, None)
# (954, 'Wake Jaws', None, None)
# (955, 'Walls Artist', None, None)

# %% [markdown]
# #### EXISTS operator

# %%
# Test for existence of rows in subquery
# Find all customers who have at least one payment whose amount is greater than 11 been returned between 2005-05-29 and 2005-05-30?
select_records = """
SELECT first_name, last_name
FROM customer AS c
WHERE EXISTS (SELECT *
    FROM payment AS p
    WHERE p.customer_id = c.customer_id
    AND amount > 11)
"""

# %%
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name, db_port)

# Execute read query
results = read_query(connection, select_records)

for result in results:
    print(result)
# Out:
# PostgreSQL Database connection successful
# ('Karen', 'Jackson')
# ('Victoria', 'Gibson')
# ('Vanessa', 'Sims')
# ('Rosemary', 'Schmidt')
# ('Tanya', 'Gilbert')
# ('Nicholas', 'Barfield')
# ('Kent', 'Arsenault')
# ('Terrance', 'Roush')

# %% [markdown]
# ### 8. Drop Database

# %%
'''
# Remove created PosgtreSQL database
remove_dvdrental_database = """
DROP DATABASE dvdrental
"""
'''
# Out:
# '\n# Remove created PosgtreSQL database\nremove_dvdrental_database = """\nDROP DATABASE dvdrental\n"""\n'

# %%
'''
# Create connection to PosgtreSQL database
connection = create_db_connection("localhost", "postgres", db_pass, db_name)

# Execute read query
results = read_query(connection, remove_dvdrental_database)
'''
# Out:
# '\n# Create connection to PosgtreSQL database\nconnection = create_db_connection("localhost", "postgres", db_pass, db_name)\n\n# Execute read query\nresults = read_query(connection, remove_dvdrental_database)\n'
